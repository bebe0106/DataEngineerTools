# %% [markdown]
# # Introduction
#
# [Scrapy](https://scrapy.org/) est un framework permettant de crawler des
# sites web et d'en extraire les données de façon structurée.
#
# ## Installation
#
# Nous travaillerons dans un environnement
# [Anaconda](https://www.anaconda.com/download/), déjà présent sur les
# machines de l'ESIEE. Sur vos machines personnelles, télécharger la
# distribution correspondant à la version la plus récente de Python.
#
# [Scrapy](https://scrapy.org/) ne fait pas partie de la distribution par
# défaut de Python et doit être installé manuellement. Ici, le package est
# déjà installé grâce à Pipenv.
#
# Si vous avez besoin d'installer dans un autre cadre.
#
# -   Avec **Pipenv** : `pipenv install scrapy`
# -   Avec **Anaconda** : `conda install -c conda-forge scrapy`
#
# Tester la réussite de l'opération dans un interpréteur Python. Avant
# installation:

# %%
# !pip install scrapy
# Out:
# Requirement already satisfied: scrapy in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (2.11.0)
# Requirement already satisfied: Twisted<23.8.0,>=18.9.0 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from scrapy) (22.10.0)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from scrapy) (41.0.5)
# Requirement already satisfied: cssselect>=0.9.1 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from scrapy) (1.2.0)
# Requirement already satisfied: itemloaders>=1.0.1 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from scrapy) (1.1.0)
# Requirement already satisfied: parsel>=1.5.0 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from scrapy) (1.8.1)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from scrapy) (23.3.0)
# Requirement already satisfied: queuelib>=1.4.2 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from scrapy) (1.6.2)
# Requirement already satisfied: service-identity>=18.1.0 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from scrapy) (23.1.0)
# Requirement already satisfied: w3lib>=1.17.0 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from scrapy) (2.1.2)
# Requirement already satisfied: zope.interface>=5.1.0 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from scrapy) (6.1)
# Requirement already satisfied: protego>=0.1.15 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from scrapy) (0.3.0)
# Requirement already satisfied: itemadapter>=0.1.0 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from scrapy) (0.8.0)
# Requirement already satisfied: setuptools in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from scrapy) (65.5.1)
# Requirement already satisfied: packaging in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from scrapy) (23.2)
# Requirement already satisfied: tldextract in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from scrapy) (5.1.0)
# Requirement already satisfied: lxml>=4.4.1 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from scrapy) (4.9.3)
# Requirement already satisfied: PyDispatcher>=2.0.5 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from scrapy) (2.0.7)
# Requirement already satisfied: cffi>=1.12 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from cryptography>=36.0.0->scrapy) (1.16.0)
# Requirement already satisfied: jmespath>=0.9.5 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from itemloaders>=1.0.1->scrapy) (1.0.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from service-identity>=18.1.0->scrapy) (23.1.0)
# Requirement already satisfied: pyasn1 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.5.0)
# Requirement already satisfied: pyasn1-modules in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from service-identity>=18.1.0->scrapy) (0.3.0)
# Requirement already satisfied: constantly>=15.1 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (23.10.4)
# Requirement already satisfied: incremental>=21.3.0 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: Automat>=0.8.0 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (22.10.0)
# Requirement already satisfied: hyperlink>=17.1.1 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (21.0.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (4.8.0)
# Requirement already satisfied: twisted-iocpsupport<2,>=1.0.2 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (1.0.4)
# Requirement already satisfied: idna in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from tldextract->scrapy) (3.4)
# Requirement already satisfied: requests>=2.1.0 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from tldextract->scrapy) (2.31.0)
# Requirement already satisfied: requests-file>=1.4 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from tldextract->scrapy) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from tldextract->scrapy) (3.13.1)
# Requirement already satisfied: six in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from Automat>=0.8.0->Twisted<23.8.0,>=18.9.0->scrapy) (1.16.0)
# Requirement already satisfied: pycparser in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->scrapy) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\march\pycharmprojects\dataengineertools\venv\lib\site-packages (from requests>=2.1.0->tldextract->scrapy) (2023.7.22)
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import scrapy

# %% [markdown]
# ## Architecture
#
# [Scrapy](https://scrapy.org/) est un framework comportant plusieurs
# composants.
#
# <img src="images/architecture.png" alt="image" class="align-center" />
#
# L'ensemble du processus est contrôlé par l'**engine** (les termes anglo
# saxons ont été retenus pour un meilleur référencement dans la
# [documentation officielle](https://docs.scrapy.org/en/latest/)).
#
# Le framework est articulé avec plusieurs composants qui gèrent chacun un
# rôle différent. Nous allons les détailler.
#
# -   Les **Spiders** : permettent de naviguer sur un site et de
#     référencer les règles d'extraction de la donnée.
# -   Les **Pipelines** : font le lien entre la donnée brute et des objets
#     structurés
# -   Les **Middlewares** : permettent d'effectuer des transformations sur
#     les objets ou sur les requêtes exécutées par l'engine.
# -   Le **Scheduler** : gère l'ordre et le timing des requêtes
#     effectuées.
#
# ## Fonctionnement
#
# [Scrapy](https://scrapy.org/) est entièrement organisé autour d'un
# composant central : l'*engine*.
#
# Le rôle de l'*engine* est de contrôler le flux de données entre les
# différents composants du système.
#
# 1.  En particulier, il est chargé de récupérer les *requests* définies
#     dans les *spiders*
# 2.  Ces *requests* sont ensuite fournies au *scheduler* qui se charge de
#     leur ordonnancement
# 3.  Les *requests* sont présentées selon cet ordonnancement à
#     l'*engine*...
# 4.  ... qui les transmet au *downloader*
# 5.  Le *downloader* effectue la *request* et transmet la *response* (le
#     contenu de la page web) à l'*engine*...
# 6.  ... puis l'envoie au *spider* pour traitement
# 7.  Le *spider* génére des *items* qui sont transmis à l'*engine*
# 8.  Les *items* sont ensuite poussés dans un pipeline pour nettoyage,
#     validation et stockage
#
# Ce processus est répété jusqu'à épuisement des requêtes.
#
# [Scrapy](https://scrapy.org/) est un [framework orienté
# événements](https://en.wikipedia.org/wiki/Event-driven_architecture)
# (basé sur [Twisted](https://twistedmatrix.com/)) permettant une
# programmation asynchrone (non bloquante). C'est particulièrement
# intéressant dans les opérations de scraping, puisque **le programme
# n'attend pas le résultat d'une requête pour en lancer une autre**.
#
# En effet, lorsque l'on sollicite une ressource (requête réseau, système
# de fichier, etc.) en mode bloquant, l'exécution du programme est
# suspendue le temps que la transaction avec la ressource se termine (par
# exemple le temps qu'une page web soit complètement téléchargée).
# L'intérêt de faire des appels non bloquants, c'est que l'on peut gérer
# de multiples téléchargements en parallèle, et que le programme peut
# continuer à tourner pendant ce temps.

# %% [markdown]
# # Un scraping élémentaire
#
# Avant de rentrer dans les détails du framework, nous allons mettre en
# oeuvre un premier script permettant de récupérer l'information présente
# sur [la page web](http://evene.lefigaro.fr/citations/winston-churchill)
# recensant les citations de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill).
#
# **Exercice**
#
# Examiner le code source de cette page avec l'inspecteur de votre
# navigateur. Identifier les éléments contenant l'information recherchée,
# ici la chaîne de caractères contenant la citation proprement dite.
#
# ## Le code source
#
# Le code utilisé est le suivant:

# %%
# %load citations_churchill_spider1.py

import scrapy

class ChurchillQuotesSpider(scrapy.Spider):
    name = "citations de Churchill"
    start_urls = ["http://evene.lefigaro.fr/citations/winston-churchill",]

    def parse(self, response):
        for cit in response.xpath('//div[@class="figsco__quote__text"]'):
            text_value = cit.xpath('a/text()').extract_first()
            yield { 'text' : text_value }

# %% [markdown]
# ## Le fonctionnement
#
# Le fonctionnement est le suivant:
#
# -   On importe le module [Scrapy](https://scrapy.org/) (3)
# -   et on définit une sous classe de `scrapy.Spider` (5)
# -   la variable `start_urls` contient la liste des pages à scraper (7)
# -   On redéfinit la méthode $parse$ dont la signature est définie dans
#     la classe mère (9)
# -   L'objet
#     [response](https://docs.scrapy.org/en/latest/topics/request-response.html#response-objects)
#     représente la réponse à la requête HTTP (l'attribut $text$ permet
#     d'accéder à son contenu). On recherche ensuite tous les containers
#     `<div>` identifiés dans l'exercice précédent. Ici la page est
#     particulièrement bien structurée et les citations disposent de leur
#     propre container, identifié par l'attribut `class` de valeur
#     `figsco__quote__text`. La sélection se fait par une expression
#     [XPath](https://en.wikipedia.org/wiki/XPath), un langage de
#     sélection de noeud dans un document XML (10). En langage naturel, la
#     requête pourrait se formuler : "On recherche tous les containers
#     `<div>` dont la valeur de l'attribut `class` est égal à
#     `figsco__quote__text`".
# -   Pour chaque résultat, on construit un dictionnaire dont la clé est
#     `text` et la valeur le contenu du lien `<a>`. Ce résultat est fourni
#     par un générateur ($yield$) (12).
#
# On lance le scraping depuis un terminal:

# %%
# !scrapy runspider citations_churchill_spider1.py
# Out:
# 2023-11-28 13:32:22 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrapybot)
# 2023-11-28 13:32:22 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Windows-10-10.0.22621-SP0
# 2023-11-28 13:32:22 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-11-28 13:32:23 [py.warnings] WARNING: C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-11-28 13:32:23 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-11-28 13:32:23 [scrapy.extensions.telnet] INFO: Telnet Password: d0a65617537bfdf8
# 2023-11-28 13:32:23 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-11-28 13:32:23 [scrapy.crawler] INFO: Overridden settings:
# {'SPIDER_LOADER_WARN_ONLY': True}
# 2023-11-28 13:32:23 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-11-28 13:32:23 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-11-28 13:32:23 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-11-28 13:32:23 [scrapy.core.engine] INFO: Spider opened
# 2023-11-28 13:32:23 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-11-28 13:32:23 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-11-28 13:32:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://evene.lefigaro.fr/citations/winston-churchill> (referer: None)
# 2023-11-28 13:32:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Le vice inhérent au capitalisme consiste en une répartition inégale des richesses. La vertu inhérente au socialisme consiste en une égale répartition de la misère.”'}
# 2023-11-28 13:32:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Un conciliateur c'est quelqu'un qui nourrit un crocodile en espérant qu'il sera le dernier à être mangé.”"}
# 2023-11-28 13:32:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Il est une bonne chose de lire des livres de citations, car les citations lorsqu’elles sont gravées dans la mémoire vous donnent de bonnes pensées.”'}
# 2023-11-28 13:32:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Je suis toujours prêt à apprendre, bien que je n'aime pas toujours qu'on me donne des leçons.”"}
# 2023-11-28 13:32:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“C'est une belle chose d'être honnête, mais il est également important d'avoir raison.”"}
# 2023-11-28 13:32:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“J’ai retiré plus de choses de l’alcool que l’alcool ne m’en a retirées.”'}
# 2023-11-28 13:32:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Pour s'améliorer, il faut changer. Donc, pour être parfait, il faut avoir changé souvent.”"}
# 2023-11-28 13:32:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“On considère le chef d'entreprise comme un homme à abattre, ou une vache à traire. Peu voient en lui le cheval qui tire le char.”"}
# 2023-11-28 13:32:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“En Angleterre, tout est permis, sauf ce qui est interdit. En Allemagne, tout est interdit, sauf ce qui est permis. En France, tout est permis, même ce qui est interdit. En U.R.S.S., tout est interdit, même ce qui est permis.”'}
# 2023-11-28 13:32:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“On vit de ce que l’on obtient.\rOn construit sa vie sur ce que l’on donne.”'}
# 2023-11-28 13:32:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Si deux hommes ont toujours la même opinion, l'un d'eux est de trop.”"}
# 2023-11-28 13:32:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Plus vous saurez regarder loin dans le passé, plus vous verrez loin dans le futur.”'}
# 2023-11-28 13:32:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“L’Angleterre s’écroule dans l’ordre, et la France se relève dans le désordre.”'}
# 2023-11-28 13:32:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“En avalant les méchantes paroles qu'on ne profère pas, on ne s'est jamais abîmé l'estomac.”"}
# 2023-11-28 13:32:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Comité : Un groupe de personnes incapables de faire quoi que ce soit par elles-mêmes qui décident collectivement que rien ne peut être fait !”'}
# 2023-11-28 13:32:25 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "Rien de plus arrogant qu'un timide qui a vaincu sa timidité."}
# 2023-11-28 13:32:25 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-11-28 13:32:25 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 245,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 14833,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 1.69366,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 11, 28, 12, 32, 25, 351230, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 84994,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 16,
#  'log_count/DEBUG': 18,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2023, 11, 28, 12, 32, 23, 657570, tzinfo=datetime.timezone.utc)}
# 2023-11-28 13:32:25 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On y trouve des informations sur les paramètres
# utilisés:

# %%
# 2018-01-10 17:21:05 [scrapy.utils.log] INFO: Scrapy 1.4.0 started (bot: scrapybot)
# 2018-01-10 17:21:05 [scrapy.utils.log] INFO: Overridden settings: {'SPIDER_LOADER_WARN_ONLY': True}

# %% [markdown]
# les
# [extensions](https://docs.scrapy.org/en/latest/topics/extensions.html)
# ...:

# %%
# 2018-01-10 17:21:05 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# 'scrapy.extensions.telnet.TelnetConsole',
# 'scrapy.extensions.logstats.LogStats']

# %% [markdown]
# [Les composants middleware
# downloader](https://docs.scrapy.org/en/latest/topics/downloader-middleware.html)
# ... :

# %%
# 2018-01-10 17:21:05 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
# 'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
# 'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
# 'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
# 'scrapy.downloadermiddlewares.retry.RetryMiddleware',
# 'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
# 'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
# 'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
# 'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
# 'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
# 'scrapy.downloadermiddlewares.stats.DownloaderStats']

# %% [markdown]
# Idem pour [les composants middleware
# spider](https://docs.scrapy.org/en/latest/topics/spider-middleware.html)
# ...:

# %%
# 2018-01-10 17:21:05 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
# 'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
# 'scrapy.spidermiddlewares.referer.RefererMiddleware',
# 'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
# 'scrapy.spidermiddlewares.depth.DepthMiddleware']

# %% [markdown]
# Aucun
# [pipeline](https://docs.scrapy.org/en/latest/topics/item-pipeline.html)
# n'est activé :

# %%
# 2018-01-10 17:21:05 [scrapy.middleware] INFO: Enabled item pipelines:
# []

# %% [markdown]
# **Exercice**
#
# Identifier la position des [composants middleware
# downloader](https://docs.scrapy.org/en/latest/topics/downloader-middleware.html),
# des [composants middleware
# spider](https://docs.scrapy.org/en/latest/topics/spider-middleware.html)
# et du
# [pipeline](https://docs.scrapy.org/en/latest/topics/item-pipeline.html)
# dans $l'architecture <Introduction>$
#
# L'exécution du scraping proprement dit débute :

# %%
# 2018-01-10 17:21:05 [scrapy.core.engine] INFO: Spider opened
# 2018-01-10 17:21:05 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-01-10 17:21:05 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023

# %% [markdown]
# La première URL est poussée par le scheduler:

# %%
# 2018-01-10 17:21:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://evene.lefigaro.fr/citations/winston-churchill> (referer: None)

# %% [markdown]
# ## Les résultats
#
# Les résultats sont fournis par le générateur défini dans la méthode
# $parse$ dans un dictionnaire. Ils contiennent le texte des citations
# dans la valeur de la clé `text` :

# %%
# 2018-01-10 17:21:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': '“Le vice inhérent au capitalisme consiste en une répartition inégale des richesses. La vertu inhérente au socialisme consiste en une égale répartition de la misère.”'}
# 2018-01-10 17:21:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': "Faire le bien, éviter le mal, c'est ça le paradis."}

# %% [markdown]
# ## Les statistiques
#
# Une fois le scraping effectué, quelques statistiques sont affichées sur
# le terminal:

# %%
# 2018-01-10 17:21:05 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-01-10 17:21:05 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 242,
# 'downloader/request_count': 1,
# 'downloader/request_method_count/GET': 1,
# 'downloader/response_bytes': 17435,
# 'downloader/response_count': 1,
# 'downloader/response_status_count/200': 1,
# 'finish_reason': 'finished',
# 'finish_time': datetime.datetime(2018, 1, 10, 16, 21, 5, 858347),
# 'item_scraped_count': 16,
# 'log_count/DEBUG': 18,
# 'log_count/INFO': 7,
# 'response_received_count': 1,
# 'scheduler/dequeued': 1,
# 'scheduler/dequeued/memory': 1,
# 'scheduler/enqueued': 1,
# 'scheduler/enqueued/memory': 1,
# 'start_time': datetime.datetime(2018, 1, 10, 16, 21, 5, 645347)}
# 2018-01-10 17:21:05 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On observe notamment que notre code permet de récupérer la taille de la
# page web (17435 bytes), le temps d'exécution à partir des valeurs
# `finish_time` et `start_time`, le nombre d'items scrapés (16), etc...
#
# **Exercice**
#
# Les citations extraites sont elles toutes de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill) ? Il sera
# peut être nécessaire de modifier le sélecteur XPath. Nous verrons ça
# lorsque il faudra récupérer les données relative à l'auteur.
#
# ## Modifier les données
#
# Il est parfois nécessaire de faire un traitement sur les données
# scrapées, pour ajouter ou retirer de l'information.
#
# **Exercice**
#
# Retirer les caractères `“` et `”` qui délimitent la citation. Ces
# caractères sont identifiés en Unicode comme [LEFT DOUBLE QUOTATION
# MARK](http://www.fileformat.info/info/unicode/char/201c/index.htm) et
# [RIGHT DOUBLE QUOTATION
# MARK](http://www.fileformat.info/info/unicode/char/201d/index.htm).
#
# ## Plus de données
#
# Il est souvent nécessaire de récupérer plusieurs informations relatives
# à un même item. Dans cet exemple, il est judicieux d'associer à la
# citation le nom de son auteur, en allant chercher cette information au
# plus près du texte lui même.
#
# **Exercice**
#
# Examiner le code source de la page web et identifier la structuration de
# la donnée associée à l'auteur. En déduire l'expression XPath permettant
# de la récupérer. S'assurer que seules les citations de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill) sont
# extraites. Ajouter une clé `author` au dictionnaire retourné par le
# $yield$ dont la valeur est précisément la chaîne de caractères contenant
# l'auteur.
#
# Un exemple de dictionnaire retourné:

# %%
{   'text': "“Si deux hommes ont toujours la même opinion, l'un d'eux est de trop.”", 
    'author': 'Winston Churchill'}

# %% [markdown]
# Pour lancer l'exécution de la spider :
#
# > \$ scrapy runspider spiders/citations\_churchill\_spider2.py
#
# On peut aussi vouloir stocker les données extraites :
#
# > \$ scrapy runspider spiders/citations\_churchill\_spider2.py -o
# > data/citation.json -t json

# %%
# Exercices
import scrapy

class ChurchillQuotesSpider(scrapy.Spider):
    name = "citations de Churchill"
    start_urls = ["http://evene.lefigaro.fr/citations/winston-churchill",]

    def parse(self, response):
        for cit in response.xpath('//div[@class="figsco__quote__text"]'):
            text_value = cit.xpath('a/text()').extract_first()
            yield { 'text' : text_value }
# Out:
# “ ”
# Comité : Un groupe de personnes incapables de faire quoi que ce soit par elles-mêmes qui décident collectivement que rien ne peut être fait !”

# %%
# !scrapy runspider citations_churchill_spider1.py
# Out:
# 2023-11-28 14:05:13 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: scrapybot)
# 2023-11-28 14:05:13 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Windows-10-10.0.22621-SP0
# 2023-11-28 14:05:13 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-11-28 14:05:13 [py.warnings] WARNING: C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-11-28 14:05:13 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-11-28 14:05:13 [scrapy.extensions.telnet] INFO: Telnet Password: 32bd2010e5d45dc6
# 2023-11-28 14:05:13 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-11-28 14:05:13 [scrapy.crawler] INFO: Overridden settings:
# {'SPIDER_LOADER_WARN_ONLY': True}
# 2023-11-28 14:05:14 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-11-28 14:05:14 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-11-28 14:05:14 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-11-28 14:05:14 [scrapy.core.engine] INFO: Spider opened
# 2023-11-28 14:05:14 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-11-28 14:05:14 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-11-28 14:05:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://evene.lefigaro.fr/citations/winston-churchill> (referer: None)
# 2023-11-28 14:05:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Le vice inhérent au capitalisme consiste en une répartition inégale des richesses. La vertu inhérente au socialisme consiste en une égale répartition de la misère.”'}
# 2023-11-28 14:05:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Un conciliateur c'est quelqu'un qui nourrit un crocodile en espérant qu'il sera le dernier à être mangé.”"}
# 2023-11-28 14:05:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Il est une bonne chose de lire des livres de citations, car les citations lorsqu’elles sont gravées dans la mémoire vous donnent de bonnes pensées.”'}
# 2023-11-28 14:05:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Je suis toujours prêt à apprendre, bien que je n'aime pas toujours qu'on me donne des leçons.”"}
# 2023-11-28 14:05:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“C'est une belle chose d'être honnête, mais il est également important d'avoir raison.”"}
# 2023-11-28 14:05:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“J’ai retiré plus de choses de l’alcool que l’alcool ne m’en a retirées.”'}
# 2023-11-28 14:05:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Pour s'améliorer, il faut changer. Donc, pour être parfait, il faut avoir changé souvent.”"}
# 2023-11-28 14:05:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“On considère le chef d'entreprise comme un homme à abattre, ou une vache à traire. Peu voient en lui le cheval qui tire le char.”"}
# 2023-11-28 14:05:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“En Angleterre, tout est permis, sauf ce qui est interdit. En Allemagne, tout est interdit, sauf ce qui est permis. En France, tout est permis, même ce qui est interdit. En U.R.S.S., tout est interdit, même ce qui est permis.”'}
# 2023-11-28 14:05:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“On vit de ce que l’on obtient.\rOn construit sa vie sur ce que l’on donne.”'}
# 2023-11-28 14:05:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Si deux hommes ont toujours la même opinion, l'un d'eux est de trop.”"}
# 2023-11-28 14:05:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Plus vous saurez regarder loin dans le passé, plus vous verrez loin dans le futur.”'}
# 2023-11-28 14:05:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“L’Angleterre s’écroule dans l’ordre, et la France se relève dans le désordre.”'}
# 2023-11-28 14:05:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“En avalant les méchantes paroles qu'on ne profère pas, on ne s'est jamais abîmé l'estomac.”"}
# 2023-11-28 14:05:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Comité : Un groupe de personnes incapables de faire quoi que ce soit par elles-mêmes qui décident collectivement que rien ne peut être fait !”'}
# 2023-11-28 14:05:14 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "Rien de plus arrogant qu'un timide qui a vaincu sa timidité."}
# 2023-11-28 14:05:14 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-11-28 14:05:14 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 245,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 14832,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.200762,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 11, 28, 13, 5, 14, 452425, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 84994,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 16,
#  'log_count/DEBUG': 18,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2023, 11, 28, 13, 5, 14, 251663, tzinfo=datetime.timezone.utc)}
# 2023-11-28 14:05:14 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# # Votre premier projet
#
#
# Dans un premier temps vous devez créer un projet Scrapy avec la commande
# :

# %%
# !scrapy startproject newscrawler
# Out:
# Error: scrapy.cfg already exists in C:\Users\march\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler

# %% [markdown]
# Cette commande va créer un dossier `monprojet` contenant les éléments
# suivants correspondant au squelette :

# %%
# newscrawler/
#     scrapy.cfg            # Options de déploiement
#
#     newscrawler/             # Le module Python contenant les informations
#         __init__.py
#
#         items.py          # Fichier contenant les items
#
#         middlewares.py    # Fichier contenant les middlewares
#
#         pipelines.py      # Fichier contenant les pipelines
#
#         settings.py       # Fichier contenant les paramètres du projet
#
#         spiders/          # Dossier contenant toutes les spiders
#             __init__.py

# %% [markdown]
# # Votre première Spider
#
# Une Spider est une classe Scrapy qui permet de mettre en place toute
# l'architecture complexe vue dans l'introduction. Pour définir une
# spider, il vous faut hériter de la classe $scrapy.Spider$. La seule
# chose à faire est de définir la première requête à effectuer et comment
# suivre les liens. La Spider s'arrêtera lorsqu'elle aura parcouru tous
# les liens qu'on lui a demandé de suivre.
#
# Pour créer une Spider on utilise la syntaxe:

# %%
# !scrapy genspider <SPIDER_NAME> <DOMAIN_NAME>
# Out:
# < ‚tait inattendu.

# %% [markdown]
# Par exemple,

# %%
# !cd newscrawler && scrapy genspider lemonde lemonde.fr
# Out:
# Spider 'lemonde' already exists in module:
#   newscrawler.spiders.lemonde

# %% [markdown]
# Cette commande permet de créer une spider appelée `lemonde` pour scraper
# le domaine `lemonde.fr`. Cela crée le fichier Python
# `spiders/lemonde.py` suivant :

# %%
# %load newscrawler/newscrawler/spiders/lemonde.py
import scrapy


class LemondeSpider(scrapy.Spider):
    name = 'lemonde'
    allowed_domains = ['lemonde.fr']
    start_urls = ['http://lemonde.fr/']

    def parse(self, response):
        pass

# %% [markdown]
# Une bonne pratique pour commencer à développer une Spider est de passer
# par l'interface Shell proposée par Scrapy. Elle permet de récupérer un
# objet `Response` et de tester les méthodes de récupération des données.

# %% [markdown]
# # ATTENTION : Les commandes scrapy shell doivent être lancées dans un terminal

# %%
# scrapy shell 'http://lemonde.fr'

# %% [markdown]
# Pour les utilisateurs de windows il vous faut mettre des doubles quotes
# :

# %%
# scrapy shell "http://lemonde.fr"

# %% [markdown]
# Scrapy lance un kernel Python

# %%
# 2018-12-02 16:05:50 [scrapy.utils.log] INFO: Scrapy 1.3.3 started (bot: newscrawler)
# 2018-12-02 16:05:50 [scrapy.utils.log] INFO: Overridden settings: {'BOT_NAME': 'newscrawler', 'DUPEFILTER_CLASS': 'scrapy.dupefilters.BaseDupeFilter', 'LOGSTATS_INTERVAL': 0, 'NEWSPIDER_MODULE': 'newscrawler.spiders', 'ROBOTSTXT_OBEY': True, 'SPIDER_MODULES': ['newscrawler.spiders']}
# 2018-12-02 16:05:50 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# 'scrapy.extensions.telnet.TelnetConsole']
# 2018-12-02 16:05:50 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
# 'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
# 'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
# 'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
# 'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
# 'scrapy.downloadermiddlewares.retry.RetryMiddleware',
# 'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
# 'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
# 'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
# 'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
# 'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2018-12-02 16:05:50 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
# 'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
# 'scrapy.spidermiddlewares.referer.RefererMiddleware',
# 'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
# 'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2018-12-02 16:05:50 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2018-12-02 16:05:50 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2018-12-02 16:05:50 [scrapy.core.engine] INFO: Spider opened
# 2018-12-02 16:05:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2018-12-02 16:05:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/> (referer: None)
# 2018-12-02 16:05:54 [traitlets] DEBUG: Using default logger
# 2018-12-02 16:05:54 [traitlets] DEBUG: Using default logger
# [s] Available Scrapy objects:
# [s]   scrapy     scrapy module (contains scrapy.Request, scrapy.Selector, etc)
# [s]   crawler    <scrapy.crawler.Crawler object at 0x10fc38c18>
# [s]   item       {}
# [s]   request    <GET https://www.lemonde.fr/>
# [s]   response   <200 https://www.lemonde.fr/>
# [s]   settings   <scrapy.settings.Settings object at 0x113bb0898>
# [s]   spider     <DefaultSpider 'default' at 0x113e60cc0>
# [s] Useful shortcuts:
# [s]   fetch(url[, redirect=True]) Fetch URL and update local objects (by default, redirects are followed)
# [s]   fetch(req)                  Fetch a scrapy.Request and update local objects
# [s]   shelp()           Shell help (print this help)
# [s]   view(response)    View response in a browser

# %% [markdown]
# Grâce à cette interface, vous avez accès à plusieurs objets comme la
# `Response`, la `Request`, la `Spider` par exemple. Vous pouvez aussi
# exécuter `view(response)` pour afficher ce que Scrapy récupère dans un
# navigateur.

# %%
# In [1]: response
# Out[1]: <200 https://www.lemonde.fr/>
#
# In [3]: request
# Out[3]: <GET https://www.lemonde.fr/>
#
# In [4]: type(request)
# Out[4]: scrapy.http.request.Request
#
# In [5]: spider
# Out[5]: <LemondeSpider 'lemonde' at 0x1080fccc0>
#
# In [6]: type(spider)
# Out[6]: monprojet.spiders.lemonde.LeMondeSpider

# %% [markdown]
# Ici on voit que la Spider est une instance de LemondeSpider. Lorsqu'on
# lance le $scrapy shell$ scrapy va chercher dans les spiders si une
# correspond au lien passé en paramètre, si oui , il l'utilise sinon une
# $DefaultSpider$ est instanciée.
#
# ## Vos premières requêtes
#
# On peut commencer à regarder comment extraire les données de la page web
# en utilisant le langage de requêtes proposé par Scrapy. Il existe deux
# types de requêtes : les requêtes `css` et `xpath`. Les requêtes `xpath`
# sont plus complexes mais plus puissantes que les requêtes `css`. Dans le
# cadre de ce tutorial, nous allons uniquement aborder les requêtes `css`,
# elles nous suffiront pour extraire les données dont nous avons besoin
# (en interne, Scrapy transforme les requêtes `css`en requêtes `xpath`.
#
# Que ce soit les requêtes `css` ou `xpath`, elles crééent des sélecteurs
# de différents types. Quelques exemples :
#
# Pour récupérer le titre d'une page :

# %%
# In [1]: response.css('title')
# Out[1]: [<Selector xpath='descendant-or-self::title' data='<title>Le Monde.fr - Actualités et Infos'>]

# %% [markdown]
# On récupère une liste de sélecteurs correspondant à la requête `css`
# appelée. La requête précédente était unique, d'autres requêtes moins
# restrictives permettent de récupérer plusieurs résultats. Par exemple
# pour rechercher l'ensemble des liens présents sur la page, on va
# rechercher les balises HTML `<a></a>`

# %%
# In [5]: response.css("a")[0:10]
# Out[5]:
# [<Selector xpath='descendant-or-self::a' data='<a target="_blank" data-target="jelec-he'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/"> <div class="logo__lemonde l'>,
# <Selector xpath='descendant-or-self::a' data='<a href="https://secure.lemonde.fr/sfuse'>,
# <Selector xpath='descendant-or-self::a' data='<a href="https://abo.lemonde.fr/#xtor=CS'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/" class="Burger__right-arrow j'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/" class="Burger__right-arrow j'>,
# <Selector xpath='descendant-or-self::a' data='<a href="#" class="js-dropdown Burger__r'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/mouvement-des-gilets-jaunes/" '>,
# <Selector xpath='descendant-or-self::a' data='<a href="/carlos-ghosn/" data-suggestion'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/implant-files/" data-suggestio'>]

# %% [markdown]
# Pour récupérer le texte contenu dans les balises, on passe le paramètre
# `<TAG>::text`. Par exemple :

# %%
# In [6]: response.css("title::text")
# Out[6]: [<Selector xpath='descendant-or-self::title/text()' data='Le Monde.fr - Actualités et Infos en Fra'>]

# %% [markdown]
# ### Exercice
#
#   Comparer les résultats des deux requêtes `response.css('title')` et
# `response.css('title::text')`.
#
# Maintenant pour extraire les données des selecteurs on utilise l'une des
# deux méthodes suivantes : - `extract()` permet de récupérer une liste
# des données extraites de tous les sélecteurs - `extract_first()` permet
# de récupérer une `String` provenant du premier sélecteur de la liste.

# %%
# In [7]: response.css('title::text').extract_first()
# Out[7]: 'Le Monde.fr - Actualités et Infos en France et dans le monde'

# %% [markdown]
# On peut récupérer un attribut d'une balise avec la syntaxe
# `<TAG>::attr(<ATTRIBUTE_NAME>)` :
#
# Par exemple, les liens sont contenus dans un attribut `href`.

# %%
# In [9]: response.css('a::attr(href)')[0:10]
# Out[9]:
# [<Selector xpath='descendant-or-self::a/@href' data='https://journal.lemonde.fr'>,
# <Selector xpath='descendant-or-self::a/@href' data='/'>,
# <Selector xpath='descendant-or-self::a/@href' data='https://secure.lemonde.fr/sfuser/connexi'>,
# <Selector xpath='descendant-or-self::a/@href' data='https://abo.lemonde.fr/#xtor=CS1-454[CTA'>,
# <Selector xpath='descendant-or-self::a/@href' data='/'>,
# <Selector xpath='descendant-or-self::a/@href' data='/'>,
# <Selector xpath='descendant-or-self::a/@href' data='#'>,
# <Selector xpath='descendant-or-self::a/@href' data='/mouvement-des-gilets-jaunes/'>,
# <Selector xpath='descendant-or-self::a/@href' data='/carlos-ghosn/'>,
# <Selector xpath='descendant-or-self::a/@href' data='/implant-files/'>]

# %% [markdown]
# Comme vu précédemment, si on veut récupérer la liste des liens de la page on applique la méthode $extract()$

# %%
# In [11]: response.css('a::attr(href)').extract()[0:10]
# Out[11]:
# ['https://journal.lemonde.fr',
# '/',
# 'https://secure.lemonde.fr/sfuser/connexion',
# 'https://abo.lemonde.fr/#xtor=CS1-454[CTA_LMFR]-[HEADER]-5-[Home]',
# '/',
# '/',
# '#',
# '/mouvement-des-gilets-jaunes/',
# '/carlos-ghosn/',
# '/implant-files/']

# %% [markdown]
# Les liens dans une page HTML sont souvent codés de manière relative par
# rapport à la page courante. La méthode de l'objet `Response` peut être
# utilisée pour recréer l'url complet.
#
# Un exemple sur le 4e élément :

# %%
# In [14]: response.urljoin(response.css('a::attr(href)').extract()[8])
# Out[14]: 'https://www.lemonde.fr/carlos-ghosn/'

# %% [markdown]
# alors que

# %%
# In [15]: response.css('a::attr(href)').extract()[8]
# Out[15]: '/carlos-ghosn/'

# %% [markdown]
# ### Exercice :
#
# Utiliser une liste compréhension pour transformer les 10
# premiers liens relatifs récupérés par la méthode `extract()` en liens
# absolus.
#
# Le résultat doit ressembler à :

# %%
# Out[23]:
# ['https://journal.lemonde.fr',
# 'https://www.lemonde.fr/',
# 'https://secure.lemonde.fr/sfuser/connexion',
# 'https://abo.lemonde.fr/#xtor=CS1-454[CTA_LMFR]-[HEADER]-5-[Home]',
# 'https://www.lemonde.fr/',
# 'https://www.lemonde.fr/',
# 'https://www.lemonde.fr/',
# 'https://www.lemonde.fr/mouvement-des-gilets-jaunes/',
# 'https://www.lemonde.fr/carlos-ghosn/',
# 'https://www.lemonde.fr/implant-files/']

# %% [markdown]
# ## Des requêtes plus complexes
#
# On peut créer des requêtes plus complexes en utilisant à la fois la
# structuration HTML du document mais également la couche de présentation
# CSS. On utilise l'inspecteur de `Google Chrome` pour identifier le type
# et l'identifiant de la balise contenant les informations.
#
# Il y a au moins deux choses à savoir en `css` :
#
# -   Les `.` représentent les classes
# -   Les `#` représentent les id
#
# On se propose de récupérer toutes les sous-catégories de news dans la
# catégorie **Actualités**. On remarque en utilisant l'inspecteur
# d'élement de Chrome que toutes les catégories sont rangées dans une
# balise avec l'id $#nav-markup$ ensuite dans les classes $Nav__item$.
#
# A partir de cette structure HTML on peut construire la requête suivante
# pour récupérer la barre de navigation:

# %%
In [19]: response.css("#nav-markup")
Out[19]: [<Selector xpath="descendant-or-self::*[@id = 'nav-markup']" data='<ul id="nav-markup"> <li class="Nav__ite'>]

# %% [markdown]
# Ensuite pour récupérer les différentes catégories :

# %%
In [24]: response.css("#nav-markup .Nav__item")
Out[24]:
[<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item js-burger-to-show N'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item Nav__item--home Nav'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="/" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="/recherc'>]

# %% [markdown]
# On veut maintenant retourner tous les liens présents dans cette
# catégorie. On remarque qu'elle apparait à la 4eme position.

# %%
In [34]: response.css("#nav-markup .Nav__item")[3]
Out[34]: <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>

# %% [markdown]
# Maintenant pour récupérer tous les liens on peut chainer les requêtes.
# On accède alors à toutes les balises $a$.

# %%
In [35]: response.css("#nav-markup .Nav__item")[3].css("a")
Out[35]:
[<Selector xpath='descendant-or-self::a' data='<a href="#" class="js-dropdown Burger__r'>,
<Selector xpath='descendant-or-self::a' data='<a href="/mouvement-des-gilets-jaunes/" '>,
<Selector xpath='descendant-or-self::a' data='<a href="/carlos-ghosn/" data-suggestion'>,
<Selector xpath='descendant-or-self::a' data='<a href="/implant-files/" data-suggestio'>,
<Selector xpath='descendant-or-self::a' data='<a href="/climat/" data-suggestion>Clima'>,
<Selector xpath='descendant-or-self::a' data='<a href="/affaire-khashoggi/" data-sugge'>,
<Selector xpath='descendant-or-self::a' data='<a href="/emmanuel-macron/" data-suggest'>,
<Selector xpath='descendant-or-self::a' data='<a href="/ukraine/" data-suggestion>Ukra'>,
<Selector xpath='descendant-or-self::a' data='<a href="/russie/" data-suggestion>Russi'>,
<Selector xpath='descendant-or-self::a' data='<a href="/referendum-sur-le-brexit/" dat'>,
<Selector xpath='descendant-or-self::a' data='<a href="/harcelement-sexuel/" data-sugg'>,
<Selector xpath='descendant-or-self::a' data='<a href="/actualite-en-continu/" data-su'>,
<Selector xpath='descendant-or-self::a' data='<a href="/international/">International<'>,
<Selector xpath='descendant-or-self::a' data='<a href="/politique/">Politique</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/societe/">Société</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/les-decodeurs/">Les Décodeurs<'>,
<Selector xpath='descendant-or-self::a' data='<a href="/sport/">Sport</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/planete/">Planète</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/sciences/">Sciences</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/campus/">M Campus</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/afrique/">Le Monde Afrique</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/pixels/">Pixels</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/actualite-medias/">Médias</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/sante/">Santé</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/big-browser/">Big Browser</a>'>,
<Selector xpath='descendant-or-self::a' data='<a href="/disparitions/">Disparitions</a'>]

# %% [markdown]
# Et pour récupérer les titres :

# %%
In [37]: response.css("#nav-markup .Nav__item")[3].css("a::text").extract()
Out[37]:
['Actualités',
'Mouvement des "gilets jaunes"',
'Carlos Ghosn',
'Implant Files',
'Climat',
'Affaire Khashoggi',
'Emmanuel Macron',
'Ukraine',
'Russie',
'Brexit',
'Harcèlement sexuel',
'Toute l’actualité en continu',
'International',
'Politique',
'Société',
'Les Décodeurs',
'Sport',
'Planète',
'Sciences',
'M Campus',
'Le Monde Afrique',
'Pixels',
'Médias',
'Santé',
'Big Browser',
'Disparitions']

# %% [markdown]
# Le shell Scrapy permet de définir la structure des requêtes et de
# s'assurer de la pertinence du résultat retourné. Pour automatiser le
# processus, il faut intégrer cette syntaxe au code Python des modules de
# spider définis dans la structure du projet.
#
# ## Intégration des requêtes
#
# Le squelette de la classe `LeMondeSpider` généré lors de la création du
# projet doit maintenant être enrichi. Par défaut 3 attributs et une
# méthode `parse()` ont été créés :
#
# -   `name` permet d'identifier sans ambiguïté la spider dans le code.
# -   `allowed_domain` permet de filtrer les requêtes et forcer la spider
#     à rester sur une liste de domaines.
# -   `starts_urls` est la liste des urls d'où la spider va partir pour
#     commencer son scraping.
# -   `parse()` est une méthode héritée de la classe `scrapy.Spider`. Elle
#     doit être redéfinie selon les requêtes que l'on doit effectuer et
#     sera appelée sur l'ensemble des urls contenus dans la liste
#     `starts_urls`.
#
# `parse()` est une fonction `callback` qui sera appelée automatiquement
# sur chaque objet `Response` retourné par la requête. Cette fonction est
# appelée de manière asynchrone. Plusieurs requêtes peuvent ainsi être
# lancées en parallèles sans bloquer le thread principal. L'objet
# `Response` passé en paramètre est le même que celui mis à disposition
# lors de l'exécution du Scrapy Shell.

# %%
def parse(self, response):
    title = response.css('title::text').extract_first()
    all_links = {
        name:response.urljoin(url) for name, url in zip(
        response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
        response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
    }
    yield {
        "title":title,
        "all_links":all_links
    }

# %% [markdown]
# La fonction est un générateur (`yield`) et retourne un dictionnaire
# composé de deux éléments :
#
# -   Le titre de la page;
# -   La liste des liens sortants sous forme de String.
#
# Pour le moment cette spider ne parcourt que la page d'accueil, ce qui
# n'est pas très productif.
#
# ## Votre premier scraper
#
# Récupérer les données sur un ensemble de pages webs nécessite d'explorer
# en profondeur la structure du site en suivant tout ou partie des liens
# rencontrés.
#
# La spider peut se `balader` sur un site assez efficacement. Il suffit de
# lui indiquer comment faire. Il faut spécifier à Scrapy de générer une
# requête vers une nouvelle page en construisant l'objet `Request`
# correspondant. Ce nouvel objet `Request` est alors inséré dans le
# scheduler de Scrapy. On peut évidemment générer plusieurs `Request`
# simultanément, correspondant par exemple, à différents liens sur la page
# courante. Ils sont insérés séquentiellement dans le scheduler.
#
# Pour cela on modifie la méthode `parse()` de façon à ce qu'elle retourne
# un objet `Request` pour chaque nouveau lien rencontré. On associe
# également à cet objet une fonction de callback qui déterminera la
# manière dont cette nouvelle page doit être extraite.
#
# Par exemple, pour que la spider continue dans les liens des différentes
# régions (pour l'instant la fonction de callback ne fait rien) :

# %%
# %load newscrawler/newscrawler/spiders/lemonde_v2.py
import scrapy
from scrapy import Request


class LemondeSpider(scrapy.Spider):
    name = "lemondev2"
    allowed_domains = ["www.lemonde.fr"]
    start_urls = ['https://www.lemonde.fr']

    def parse(self, response):
        title = response.css('title::text').extract_first()
        all_links = {
            name:response.urljoin(url) for name, url in zip(
            response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
            response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
        }
        yield {
            "title":title,
            "all_links":all_links
        }

# %% [markdown]
# Pour lancer la spider

# %%
# !cd newscrawler && scrapy crawl lemondev2
# Out:
# C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\spiderloader.py:49: UserWarning: There are several spiders with the same name:
#
#   LemondeSpider named 'lemondev2' (in newscrawler.spiders.lemonde)
#
#   LemondeSpider named 'lemondev2' (in newscrawler.spiders.lemonde_v2)
#
#   This can cause unexpected behavior.
#   warnings.warn(
# 2023-11-28 15:22:58 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: newscrawler)
# 2023-11-28 15:22:58 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Windows-10-10.0.22621-SP0
# 2023-11-28 15:22:58 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-11-28 15:22:58 [py.warnings] WARNING: C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-11-28 15:22:58 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-11-28 15:22:58 [scrapy.extensions.telnet] INFO: Telnet Password: 3835ff2f2bd2f1b0
# 2023-11-28 15:22:58 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-11-28 15:22:58 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2023-11-28 15:22:58 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-11-28 15:22:58 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-11-28 15:22:58 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-11-28 15:22:58 [scrapy.core.engine] INFO: Spider opened
# 2023-11-28 15:22:58 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-11-28 15:22:58 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2023-11-28 15:22:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-11-28 15:22:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: None)
# 2023-11-28 15:22:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr>
#
# {'title': 'Le Monde.fr - Actualités et Infos en France et dans le monde', 'all_links': {'Actualités': 'https://www.lemonde.fr', 'Guerre Israël-Hamas': 'https://www.lemonde.fr/attaque-du-hamas-contre-israel/', 'Guerre en Ukraine': 'https://www.lemonde.fr/crise-ukrainienne/', 'Antisémitisme': 'https://www.lemonde.fr/antisemitisme/', "Procès d'Éric Dupond-Moretti": 'https://www.lemonde.fr/proces-eric-dupond-moretti/', 'Immigration et diversité': 'https://www.lemonde.fr/immigration-et-diversite/', 'Jeux olympiques de Paris 2024': 'https://www.lemonde.fr/jeux-olympiques-2024/', 'Tempêtes et ouragans': 'https://www.lemonde.fr/ouragans/', 'Inflation': 'https://www.lemonde.fr/inflation/', 'Chine': 'https://www.lemonde.fr/chine/', 'Toute l’actualité en continu': 'https://www.lemonde.fr/actualite-en-continu/', 'International': 'https://www.lemonde.fr/international/', 'Politique': 'https://www.lemonde.fr/politique/', 'Société': 'https://www.lemonde.fr/societe/', 'Planète': 'https://www.lemonde.fr/planete/', 'Climat': 'https://www.lemonde.fr/climat/', 'Le Monde Afrique': 'https://www.lemonde.fr/afrique/', 'Les Décodeurs': 'https://www.lemonde.fr/les-decodeurs/', 'Sport': 'https://www.lemonde.fr/sport/', 'Education': 'https://www.lemonde.fr/education/', 'M Campus': 'https://www.lemonde.fr/campus/', 'Santé': 'https://www.lemonde.fr/sante/', 'Intimités': 'https://www.lemonde.fr/intimites/', 'Sciences': 'https://www.lemonde.fr/sciences/', 'Pixels': 'https://www.lemonde.fr/pixels/', 'Disparitions': 'https://www.lemonde.fr/disparitions/', 'Le Fil Good': 'https://www.lemonde.fr/le-fil-good/', 'Podcasts': 'https://www.lemonde.fr/podcasts/', 'Le Monde & Vous': 'https://www.lemonde.fr/le-monde-et-vous/'}}
# 2023-11-28 15:22:59 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-11-28 15:22:59 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 440,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 81268,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 0.419015,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 11, 28, 14, 22, 59, 167434, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 298927,
#  'httpcompression/response_count': 2,
#  'item_scraped_count': 1,
#  'log_count/DEBUG': 4,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2023, 11, 28, 14, 22, 58, 748419, tzinfo=datetime.timezone.utc)}
# 2023-11-28 15:22:59 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On veut ensuite *entrer* dans les liens des différentes sous-catégories
# pour récupérer les articles. Pour cela, nous créons une méthode
# `parse_category()` prend en argument un objet `Response` qui sera la
# réponse correspondant aux liens des régions. On peut comme ceci
# traverser un site en définissant des méthodes différentes en fonction du
# type de contenu.
#
# Si la structure du site est plus profonde, on peut empiler autant de
# couches que souhaité.
#
# Quand on arrive sur une page d'une sous-catégorie, on peut vouloir
# récupérer tous les éléments de la page. Pour cela, on réutilise le
# scrapy Shell pour commencer le développement de la nouvelle méthode
# d'extraction.
#
# Par exemple pour la page `https://www.lemonde.fr/international/` :

# %%
scrapy shell 'https://www.lemonde.fr/international/'
# Out:
#   Cell In[38], line 1
#     scrapy shell 'https://www.lemonde.fr/international/'
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# Le fil des articles est stocké dans une balise avec la classe
# `class=river`.

# %%
In [3]: response.css(".river")
Out[3]:
[<Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' fleuve ')]" data='<div class="fleuve">\n   <section>\n      '>,
<Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' fleuve ')]" data='<div class="fleuve">\n</div>'>]

# %% [markdown]
# Pour récupérer chacun des articles, il faut adresser les balises
# `<article>` contenues dans le sélecteur:

# %%
In [4]: response.css(".river")[0].css(".teaser")
Out[4]:
[<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi mg'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>]

# %% [markdown]
# Comme précédemment, on peut empiler les sélecteurs `css` pour créer des
# requêtes plus complexes.
#
# Par exemple, pour récupérer tous les titres des différents articles :

# %%
In [8]: response.css(".river")[0].css(".teaser h3::text").extract()
Out[8]:
['Des dizaines de milliers de Géorgiens contestent dans la rue l’élection de Salomé Zourabichvili\r\n\r\n\r\n',
'A Budapest en Hongrie, un îlot décroissant pour favoriser la transition\r\n\r\n\r\n',
'En Israël, la police recommande l’inculpation de Nétanyahou dans une troisième enquête\r\n\r\n\r\n',
'Donald Trump veut «\xa0mettre fin\xa0» à l’Aléna rapidement\r\n\r\n\r\n',
'Le cauchemar de la «\xa0rééducation\xa0» des musulmans en Chine\r\n\r\n',
'\r\n',
'«\xa0AMLO\xa0» lance sa transformation du Mexique\r\n\r\n\r\n',
'«\xa0Paris brûle\xa0»\xa0: les médias étrangers relatent le «\xa0chaos\xa0» en marge des défilés des «\xa0gilets jaunes\xa0»\r\n\r\n\r\n',
'Andrés Manuel Lopez Obrador intronisé président du Mexique\r\n\r\n\r\n']

# %% [markdown]
# En HTML les données sont souvent de très mauvaise qualité. Il faut
# définir des méthodes permettant de les nettoyer pour être intégrées dans
# des bases de données.
#
# Par exemple, pour supprimer tous les espaces superflus :

# %%
def clean_spaces(string_):
    if string_ is not None: 
        return " ".join(string_.split())

# %% [markdown]
# Pour l'appliquer à tous les titres récupérés, on peut faire une list
# comprehension :

# %%
In [11]: [clean_spaces(article) for article in response.css(".river")[0].css(".teaser h3::text").extract()]  

Out[11]: ['Des dizaines de milliers de Géorgiens contestent dans la rue l’élection de Salomé Zourabichvili',
          'A Budapest en Hongrie, un îlot décroissant pour favoriser la transition', 
          'En Israël, la police recommande l’inculpation de Nétanyahou dans une troisième enquête',
          'Donald Trump veut « mettre fin » à l’Aléna rapidement', 
          'Le cauchemar de la « rééducation » des musulmans en Chine',
          '',
          '« AMLO » lance sa transformation du Mexique', 
          '« Paris brûle » : les médias étrangers relatent le « chaos » en marge des défilés des « gilets jaunes »',
          'Andrés Manuel Lopez Obrador intronisé président du Mexique'
         ]

# %% [markdown]
# La méthode précédente est intéressante si l'on ne recherche qu'une seule
# information par article.
#
# Par contre si l'on veut récupérer d'autres caractéristiques comme
# l'image ou la description par exemple, il est plus intéressant et plus
# efficace de récupérer l'objet et d'effectuer plusieurs traitements sur
# ce dernier.
#
# Chaque objet retourné par les requêtes `css` est un selecteur avec
# lequel on peut interagir.
#
# Par exemple pour récupérer le titre et le prix

# %%
In [20]: for article in response.css(".river")[0].css(".teaser"):
    ...:     title = clean_spaces(article.css("h3::text").extract_first())
    ...:     image = article.css("img::attr(data-src)").extract_first()
    ...:     description = article.css("p::text").extract_first()
    ...:     print(f"Title {title} \nImage {image}\nDescription {description}\n ----")

# %%
# Title Des dizaines de milliers de Géorgiens contestent dans la rue l’élection de Salomé Zourabichvili
# Image https://s1.lemde.fr/image/2018/12/02/147x97/5391641_7_5874_les-partisans-de-l-opposant-grigol-vashadze_20d2e8693a49b83fd3c5578f7799ae9c.jpg
# Description Elue présidente (un rôle essentiellement symbolique en Géorgie), l’ex-diplomate française, candidate du pouvoir, est contestée par l’opposition.
# ----
# Title A Budapest en Hongrie, un îlot décroissant pour favoriser la transition
# Image https://img.lemde.fr/2018/12/01/10/0/4214/2809/147/97/60/0/15b32ca_1EY4qISQ_BP4kPAh1fozJdXZ.jpg
# Description Le centre logistique Cargonomia sert de matrice aux coopératives de l’économie durable et solidaire hongroise.
# ----
# Title En Israël, la police recommande l’inculpation de Nétanyahou dans une troisième enquête
# Image https://img.lemde.fr/2018/12/02/167/0/4207/2804/147/97/60/0/9e02c9b_3580d043ebc94b48b0f2cfef4e9a21e7-3580d043ebc94b48b0f2cfef4e9a21e7-0.jpg
# Description Le premier ministre est soupçonné de corruption, fraude et abus de pouvoir, dans une affaire impliquant le groupe de télécoms israélien Bezeq.
# ----
# Title Donald Trump veut « mettre fin » à l’Aléna rapidement
# Image https://img.lemde.fr/2018/11/30/0/0/4861/3240/147/97/60/0/8b87184_5826023-01-06.jpg
# Description Le président américain souhaite voir disparaître l’accord de libre-échange remontant à 1994 avec le Mexique et le Canada, qu’il qualifie régulièrement de « pire accord jamais signé », en faveur du nouveau traité négocié difficilement avec ses voisins nord-américains ces derniers mois.
# ----
# Title Le cauchemar de la « rééducation » des musulmans en Chine
# Image https://img.lemde.fr/2018/11/15/151/0/5000/3333/147/97/60/0/118c78f_248b226e6b91450aa8a68bd0ea5525a8-248b226e6b91450aa8a68bd0ea5525a8-0.jpg
# Description Ouïgours et Kazakhs du Xinjiang... C’est toute une population musulmane que Pékin veut « rééduquer » en internant des centaines de milliers d’entre eux dans des camps.
# ----
# Title « AMLO » lance sa transformation du Mexique
# Image https://img.lemde.fr/2018/12/02/45/0/1497/998/147/97/60/0/a33c174_GGGTBR84_MEXICO-POLITICS-_1202_11.JPG
# Description Education et santé gratuites, hausse du salaire minimum, bourses scolaires : à peine investi, le président Andres Manuel Lopez Obrador a listé les mesures qu’il entend prendre pour redresser le pays.
# ----
# Title « Paris brûle » : les médias étrangers relatent le « chaos » en marge des défilés des « gilets jaunes »
# Image https://img.lemde.fr/2018/12/02/361/0/598/396/147/97/60/0/ba46a6e_XVIt1Ffwm50iYBheccVieUQQ.jpg
# Description Les images de destructions, d’échauffourées ou de voitures enflammées s’affichaient samedi soir en « une » de nombreux sites d’actualité internationaux.
# ----
# Title Andrés Manuel Lopez Obrador intronisé président du Mexique
# Image https://img.lemde.fr/2018/12/02/91/145/1346/897/147/97/60/0/877cd51_a4618baa8da2414bb62bab28a6d4c745-a4618baa8da2414bb62bab28a6d4c745-0.jpg
# Description Le nouveau chef d’Etat a promis de lutter contre la corruption en menant une transformation « profonde et radicale » du pays.
# ----

# %% [markdown]
# ## Persistence des données
#
# Pour pouvoir stocker les informations que l'on récupère en parcourant un
# site il faut pouvoir les stocker. On utilise soit de simples
# dictionnaires Python, ou mieux des `scrapy.Item` qui sont des
# dictionnaires améliorés.
#
# Nous allons voir les deux façons de faire. On peut réécrire la méthode
# `parse_category()` pour lui faire retourner un dictionnaire
# correspondant à chaque offre rencontrée.

# %%
def parse_category(self, response):
    for article in response.css(".fleuve")[0].css("article"):
        title = self.clean_spaces(article.css("h3 a::text").extract_first())
        image = article.css("img::attr(data-src)").extract_first()
        description = article.css(".txt3::text").extract_first()
        yield {
            "title":title,
            "image":image,
            "description":description
        }

# %% [markdown]
# Si on combine tout dans la spider :

# %%
# %load newscrawler/newscrawler/spiders/lemonde_v3.py
import scrapy
from scrapy import Request


class LemondeSpider(scrapy.Spider):
    name = "lemondev3"
    allowed_domains = ["www.lemonde.fr"]
    start_urls = ['https://www.lemonde.fr']

    def parse(self, response):
        title = response.css('title::text').extract_first()
        all_links = {
            name:response.urljoin(url) for name, url in zip(
            response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
            response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
        }
        for link in all_links.values():
            yield Request(link, callback=self.parse_category)
            
    def parse_category(self, response):
        for article in response.css(".river")[0].css(".teaser"):
            title = self.clean_spaces(article.css("h3::text").extract_first())
            image = article.css("img::attr(data-src)").extract_first()
            description = article.css(".txt3::text").extract_first()
            yield {
                "title":title,
                "image":image,
                "description":description
            }

    def clean_spaces(self, string):
        if string:
            return " ".join(string.split())

# %% [markdown]
# On peut maintenant lancer notre spider avec la commande suivante :

# %%
scrapy crawl <NAME>
# Out:
#   Cell In[41], line 1
#     scrapy crawl <NAME>
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# `scrapy crawl` permet de démarrer le processus en allant chercher la
# classe `scrapy.Spider` dont l'attribut `name` = &lt;NAME&gt;.
#
# Par exemple, pour la spider `LeMondeSpider` :

# %%
# !cd newscrawler && scrapy crawl lemondev3
# Out:
# 2023-11-28 16:25:31 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: newscrawler)
# 2023-11-28 16:25:31 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Windows-10-10.0.22621-SP0
# 2023-11-28 16:25:31 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-11-28 16:25:31 [py.warnings] WARNING: C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-11-28 16:25:31 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-11-28 16:25:31 [scrapy.extensions.telnet] INFO: Telnet Password: af981f40908f2267
# 2023-11-28 16:25:31 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-11-28 16:25:31 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2023-11-28 16:25:31 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-11-28 16:25:31 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-11-28 16:25:31 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-11-28 16:25:31 [scrapy.core.engine] INFO: Spider opened
# 2023-11-28 16:25:31 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-11-28 16:25:31 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-11-28 16:25:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-11-28 16:25:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: None)
# 2023-11-28 16:25:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sante/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/campus/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:31 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde_v3.py", line 21, in parse_category
#     for article in response.css(".river")[0].css(".teaser"):
#                    ~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:25:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/le-monde-et-vous/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sciences/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/disparitions/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/podcasts/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/le-fil-good/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/intimites/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/education/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/pixels/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Agnès Buzyn : « Qui peut penser qu’un hypothétique refus de soins décourage l’immigration clandestine ? »', 'image': 'https://img.lemde.fr/2023/11/28/0/0/4678/3118/110/73/60/0/7abdabb_1701183281750-000-33qz69b.jpg', 'description': 'Voulue par le Sénat, la transformation de l’aide médicale d’Etat revient à faire peser la lutte contre l’immigration clandestine sur le budget des hôpitaux et sa responsabilité sur les médecins hospitaliers, en espérant qu’ils oublieront le serment d’Hippocrate, déplore, dans une tribune au «\xa0Monde\xa0», l’ancienne ministre de la santé.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Tabagisme : « Il faut avancer sur la voie de la réduction des risques »', 'image': 'https://img.lemde.fr/2023/04/27/0/0/4253/2835/110/73/60/0/a40be1e_1682585330590-2d85c17-1680106845701-le-monde-tribune-def-01.jpg', 'description': 'Alors que les politiques publiques semblent perdre en efficacité avec le temps, des spécialistes des addictions appellent, dans une tribune au «\xa0Monde\xa0», à tenter une nouvelle stratégie d’accompagnement des fumeurs.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Narcotrafic : devant le Sénat, le portrait d’une France où « aucun territoire n’est épargné »', 'image': 'https://img.lemde.fr/2023/11/28/0/0/5722/3814/110/73/60/0/3b1a4e5_1701167982825-953661.jpg', 'description': 'Les premières auditions de la commission d’enquête sur l’impact du narcotrafic ont eu lieu lundi. Les faits d’homicides ou de tentatives d’homicides liés aux trafics de stupéfiants ont augmenté de 57\xa0% depuis le début de l’année 2023, par rapport à 2022.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Hausse modérée du prix des cigarettes, plus de lieux publics sans tabac, interdiction des puffs : le gouvernement présente son plan contre le tabagisme', 'image': 'https://img.lemde.fr/2023/11/17/0/0/5860/3906/110/73/60/0/5b10d1d_1700234764531-940190.jpg', 'description': 'L’objectif est d’atteindre un prix du paquet de cigarettes à 13\xa0euros à l’horizon 2027, avec une étape à 12\xa0euros en\xa02025, a annoncé le ministre de la santé. Les «\xa0espaces sans tabac\xa0» vont être généralisés aux plages, forêts et parcs publics, ainsi qu’aux abords des établissements scolaires.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Les Assises de la pédiatrie, attendues depuis un an, désormais annoncées pour janvier', 'image': 'https://img.lemde.fr/2023/11/27/0/0/4644/3096/110/73/60/0/cda3db3_1701067752039-000-336c2ep.jpg', 'description': 'Une rencontre préparatoire a eu lieu avec le ministre de la santé, Aurélien Rousseau, vendredi 24 novembre. La pression monte de nouveau dans les hôpitaux.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': '« Que sait-on du travail ? » : des pistes de soutenabilité pour travailler à tout âge', 'image': 'https://img.lemde.fr/2023/11/24/0/139/832/555/110/73/60/0/450c6ec_1700845387440-media-appel-soutenabilite-travail-3x.png', 'description': 'Près d’un actif sur deux de 55\xa0à 61\xa0ans, ni à la retraite ni en emploi, est dans cette situation pour raison de santé. Dans le cadre du projet de médiation scientifique «\xa0Que sait-on du travail\xa0? \xa0», lancé au mois de mai par le Laboratoire interdisciplinaire d’évaluation des politiques publiques (Liepp) de Sciences Po, et diffusé en collaboration avec «\xa0Le Monde\xa0», l’ergonome Catherine Delgoulet développe une nouvelle approche de la relation entre santé et travail.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'A l’hôpital Necker-Enfants malades, temple de l’excellence de la pédiatrie à l’épreuve de la crise', 'image': 'https://img.lemde.fr/2023/11/26/0/0/4999/3333/110/73/60/0/8e51232_1701026946389-ad008necker-dsc02502.jpg', 'description': 'Dans cet établissement pédiatrique de l’Assistance publique-Hôpitaux de Paris où exercent les meilleurs spécialistes du pays, des lits sont fermés, comme ailleurs, par manque de personnels. Avec parfois des conséquences dramatiques, quand des opérations doivent être reportées.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': '« Les Français fument bien plus que leurs voisins, même si le prix de leurs cigarettes est jusqu’à deux fois plus onéreux »', 'image': 'https://img.lemde.fr/2023/11/24/517/0/3100/2066/110/73/60/0/314c407_1700817522253-pns-4683842.jpg', 'description': 'Dans le cadre du mois de novembre désigné mois sans tabac, l’économiste Jérôme Mathis rappelle, dans une tribune au «\xa0Monde\xa0», que le tabac est un fléau contre lequel la France s’empêche de lutter efficacement.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Accouchement à domicile : un drame relance le débat entre soignants', 'image': 'https://img.lemde.fr/2023/11/24/230/0/1654/1102/110/73/60/0/c9bc881_1700868388944-2023-11-24-colcanopa.jpeg', 'description': 'Une semaine après le décès, en Ille-et-Vilaine, d’une femme qui avait décidé d’accoucher à domicile, le débat est vif sur cette pratique marginale mais qui interroge l’encadrement des accouchements.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Les pneumopathies infantiles connaissent une forte recrudescence en France', 'image': 'https://img.lemde.fr/2023/11/25/0/0/6000/4000/110/73/60/0/6542660_1700902652239-000-32v7277.jpg', 'description': 'Pour expliquer le regain épidémique, les médecins évoquent le retour d’une bactérie peu active ces dernières années. Certains font aussi l’hypothèse d’un effet de rattrapage après la pandémie de Covid-19.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'La PMA, un parcours du combattant ?', 'image': 'https://img.lemde.fr/2023/10/31/500/0/3001/2000/110/73/60/0/6b5ce3e_1698743727754-4.jpg', 'description': '«\xa0(In)fertile\xa0» (4/10). Dans les parcours de procréation médicalement assistée (PMA), plusieurs techniques sont possibles, notamment la fécondation in vitro. Une pratique chirurgicale qui peut faire peur.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Violences conjugales : les professionnels de santé questionnent trop peu leurs patientes, selon la Haute Autorité de santé', 'image': 'https://img.lemde.fr/2023/11/22/1/0/6000/4000/110/73/60/0/9756064_5941042-01-06.jpg', 'description': '«\xa0Contrairement aux craintes de certains professionnels, 96\xa0% des femmes interrogées considèrent qu’un questionnement systématique est une bonne chose\xa0», note la HAS, dont les recommandations visent à «\xa0faciliter la parole des victimes\xa0».'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': '« Psychiatre est un métier d’engagement, de valeurs, de passion et pourtant méconnu »', 'image': 'https://img.lemde.fr/2023/04/27/0/0/4253/2835/110/73/60/0/a40be1e_1682585330590-2d85c17-1680106845701-le-monde-tribune-def-01.jpg', 'description': 'Alors que les maladies mentales touchent un Français sur cinq, et que la psychiatrie est une discipline en pleine mutation, des spécialistes et des étudiants déplorent, dans une tribune au «\xa0Monde\xa0», le manque d’attractivité de leur profession.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Vaccination contre le papillomavirus : pas de « dysfonctionnement » identifié après la mort d’un collégien', 'image': 'https://img.lemde.fr/2023/11/24/0/0/664/442/110/73/60/0/241e627_1700821729925-25daa07-1692200901929-epa-10665477.jpg', 'description': 'L’autopsie a confirmé que le décès du jeune homme était dû à un traumatisme crânio-cérébral, selon le procureur de la République.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Dans le nord de la Chine, les hôpitaux débordés par une flambée de cas de maladies respiratoires', 'image': 'https://img.lemde.fr/2023/11/23/0/6/5503/3669/110/73/60/0/3c3295b_1700753795243-977983.jpg', 'description': 'Alors que les services d’urgence sont pris d’assaut, notamment pour des cas de pneumonie, la Chine indique qu’«\xa0aucun pathogène nouveau\xa0» n’a été détecté.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Pourquoi une nouvelle loi sur la fin de vie ? Comprendre en trois minutes', 'image': 'https://img.lemde.fr/2023/11/21/0/0/1023/682/110/73/60/0/4c73d15_1700586786323-000-336g9u2.jpg', 'description': 'VIDÉO - La loi Claeys-Leonetti, le dernier texte sur la question, date de 2016\xa0et avait été votée à une large majorité. Alors que le gouvernement s’apprête à présenter un nouveau texte sur la fin de vie, de nombreux acteurs pensent qu’un changement de cadre est urgent. Explications.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Pourquoi le sport devrait être remboursé comme un médicament', 'image': 'https://img.lemde.fr/2023/10/13/0/0/1800/1200/110/73/60/0/fcaa0e1_1697197668043-sport.png', 'description': 'Les bénéfices de l’activité physique sont prouvés, tant en prévention qu’en traitement, mais son remboursement à l’échelle nationale n’est toujours pas à l’ordre du jour. Explications en podcast avec Sandrine Cabut et Pascale Santi, spécialistes des questions de santé au «\xa0Monde\xa0».'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Flambée de maladies respiratoires : la Chine ne signale « aucun pathogène nouveau ou inhabituel », selon l’OMS', 'image': 'https://img.lemde.fr/2023/11/23/0/6/5851/3901/110/73/60/0/afc231d_5950106-01-06.jpg', 'description': 'L’Organisation mondiale de la santé avait demandé au pays «\xa0des informations détaillées sur une augmentation des maladies respiratoires et des foyers de pneumonie\xa0».'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': '« Bien vieillir » : « Les vieux méritent mieux qu’un empilement de mesurettes »', 'image': 'https://img.lemde.fr/2023/11/22/0/0/5000/3333/110/73/60/0/211de03_1700664550821-pns-6741041.jpg', 'description': 'Alors que la ministre des solidarités, Aurore Bergé, vient de présenter sa stratégie pour le grand âge, Yann Lasnier, délégué général des Petits Frères des pauvres, regrette, dans une tribune au «\xa0Monde\xa0», que les travaux menés dans le cadre du Conseil national de la refondation n’aient servi à rien ou presque. En particulier sur la question de l’isolement social.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'L’Organisation mondiale de la santé s’inquiète d’une hausse des maladies respiratoires en Chine', 'image': 'https://img.lemde.fr/2023/01/19/0/0/4000/2666/110/73/60/0/6095dda_5247753-01-06.jpg', 'description': 'L’organisation onusienne, qui a indiqué que les autorités chinoises attribuaient cette augmentation à la levée des restrictions liées au Covid-19 et à la circulation d’agents pathogènes connus, demande à Pékin d’appliquer un train de mesures.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': '« Supprimer l’aide médicale d’Etat serait une faute grave »', 'image': 'https://img.lemde.fr/2023/11/14/0/0/5410/3607/110/73/60/0/63be61d_5872065-01-06.jpg', 'description': 'Soignants et travailleurs sociaux ne sont pas «\xa0pour\xa0» ou «\xa0contre\xa0» l’aide médicale d’Etat, mais ils savent qu’avec leurs patients les plus vulnérables les services d’urgence paieraient les pots cassés de sa suppression, affirment, dans une tribune au «\xa0Monde\xa0», Xavier Emmanuelli, président du Samusocial international, et la psychiatre Sylvie Quesemand Zucca.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Trafic de drogue et d’armes : procès requis contre d’importants trafiquants de Saint-Ouen', 'image': 'https://img.lemde.fr/2023/11/21/0/0/8256/5504/110/73/60/0/2fc5b07_1700583031891-ad43d87-1694187639971-000-33mg2hg.jpg', 'description': 'Au terme de trois ans et demi d’enquête, la justice demande le renvoi devant le tribunal de plusieurs membres d’un groupe francilien qui convoyait du cannabis vers des points de deal en banlieue, chez lesquels un véritable arsenal militaire avait été retrouvé.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Paludisme : la vaccination à grande échelle en Afrique « va bientôt commencer », affirme l’Alliance du vaccin', 'image': 'https://img.lemde.fr/2023/11/22/729/819/4467/2978/110/73/60/0/d81f3a0_1700663155898-000-33ar69z.jpg', 'description': 'Plus de 300\xa0000\xa0doses du RTS,S sont arrivés au Cameroun. Le Burkina Faso, le Liberia, le Niger et la Sierra Leone devraient en recevoir 1,7\xa0million dans les semaines qui viennent.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Déserts médicaux : l’UFC-Que choisir attaque l’Etat en justice pour « inaction »', 'image': 'https://img.lemde.fr/2023/05/23/0/0/5733/3822/110/73/60/0/aade3c3_1684846729586-pns-4090142.jpg', 'description': 'Une dizaine de membres de l’UFC-Que choisir se sont rassemblés silencieusement, mardi, devant le ministère de la santé, brandissant des pancartes et accrochant autour d’eux du ruban de chantier, pour symboliser «\xa0l’impossible accès\xa0» aux soins.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'L’ordre des médecins exprime « sa profonde inquiétude » sur le projet d’installation d’espaces de télémédecine dans les gares SNCF', 'image': 'https://img.lemde.fr/2019/10/22/0/128/4543/3029/110/73/60/0/230d9ac_LR249d0s4052-Jt8rN9dMidB.jpg', 'description': 'La SNCF a déclaré, vendredi, vouloir déployer des espaces de télémédecine pour lutter contre les déserts médicaux dans environ trois cents gares d’ici à 2028.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Loi « bien vieillir » : les députés adoptent des propositions pour le grand âge mais demandent des « moyens »', 'image': 'https://img.lemde.fr/2023/07/20/0/0/4387/2924/110/73/60/0/69714fa_1689868918566-abacanewsroy-861217-008.jpg', 'description': 'Les députés reprendront, mardi, par l’examen d’autres amendements sur les Ehpad, visant à tirer des leçons du scandale Orpea.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Abandons de poste : entre faux licenciement et vraie démission, le flou juridique demeure', 'image': 'https://img.lemde.fr/2023/11/20/1039/0/3778/2518/110/73/60/0/fc145dd_1700490463083-pns-5651568.jpg', 'description': 'S’il est désormais inscrit dans la loi qu’un abandon de poste correspond non plus à un licenciement pour faute, mais à une démission, rappelle le juriste Jean-Emmanuel Ray dans sa chronique, il est encore théoriquement possible pour un employeur de licencier son salarié, pour qu’il puisse notamment bénéficier des allocations-chômage.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Ces vingtenaires qui se détournent de l’alcool : « Tu as l’impression que c’est un anxiolytique rapide, mais, le lendemain, tu doubles ton angoisse »', 'image': 'https://img.lemde.fr/2023/11/20/90/0/7543/5028/110/73/60/0/95c0deb_1700474360004-sobriei-tei-clr.jpg', 'description': 'Alors que la vie étudiante et les premières années de vie active sont associées aux sorties où l’alcool semble central, certains jeunes décident de ne plus boire. Ils explorent les effets bénéfiques d’une sobriété qui leur permet de se reconnecter à eux-mêmes et aux autres.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Les pharmaciens alertent sur le malaise de l’officine', 'image': 'https://img.lemde.fr/2023/11/20/0/0/5439/3626/110/73/60/0/3e91b03_1700463729972-000-32lp7vb.jpg', 'description': 'L’intersyndicale, qui réunit pharmaciens et étudiants en pharmacie, appelle à une journée de mobilisation nationale le 21\xa0novembre. La profession veut mettre la pression sur le gouvernement, alors que doivent prochainement s’ouvrir des négociations sur les conditions d’exercice et de rémunération du réseau.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'La députée Sandrine Josso veut sensibiliser au « fléau » de la soumission chimique après avoir été droguée à son insu', 'image': 'https://img.lemde.fr/2023/11/20/0/0/4828/3219/110/73/60/0/9f14962_1700511004161-000-33y33gm.jpg', 'description': '«\xa0On ne peut plus détourner le regard\xa0», a déclaré la députée de Loire-Atlantique. Elle a porté plainte la semaine dernière contre le sénateur Joël Guerriau, mis en examen pour «\xa0administration de substance afin de commettre un viol ou une agression sexuelle\xa0».'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'La proposition de loi « bien vieillir » revient à l’Assemblée avec la promesse d’une loi de programmation sur le grand âge', 'image': 'https://img.lemde.fr/2023/11/20/1/0/8192/5461/110/73/60/0/bf77199_1700463152513-943741.jpg', 'description': 'Après un début de lecture interrompu en avril, la proposition de loi macroniste est de retour à l’Assemblée nationale lundi 20\xa0novembre. Le gouvernement a annoncé vendredi qu’il s’engageait à traduire en actes un amendement adopté au printemps et prévoyant une loi de programmation pluriannuelle sur le sujet, sans toutefois répondre à la question de son financement.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Soigner ou ne pas soigner ? Dans les coulisses du Centre d’éthique clinique de l’AP-HP', 'image': 'https://img.lemde.fr/2023/11/18/0/0/2125/1417/110/73/60/0/4e3075d_1700299539461-le-monde-comite-ethique-hd.jpg', 'description': 'Depuis plus de vingt\xa0ans, au sein du Centre d’éthique clinique parisien de l’AP-HP, un groupe pluridisciplinaire, constitué de médecins, de juristes ou de philosophes, tous issus de la société civile, travaille à éclairer les dilemmes éthiques qui opposent parfois les soignants et les proches attachés à un patient.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': '« Travailleurs du soin, unissons-nous contre la suppression programmée de l’aide médicale d’Etat »', 'image': 'https://img.lemde.fr/2022/12/19/0/0/2500/1666/110/73/60/0/0c3d6a7_1671491838785-eleonora-strano-covid-nice-fin2020-20.jpg', 'description': 'Dans une tribune au «\xa0Monde\xa0», le médecin Philippe Bizouarn s’indigne de la suppression de l’aide médicale d’Etat, destinée aux sans-papiers, votée par le Sénat le 7\xa0novembre. Le supposé tourisme médical n’existe pas, rappelle-t-il.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Assurance santé : puis-je garder ma mutuelle d’entreprise à la retraite ?', 'image': 'https://img.lemde.fr/2023/04/18/0/0/3000/2000/110/73/60/0/a61890c_1681830091357-hjuy.jpg', 'description': 'Le nouveau retraité a le droit de conserver sa complémentaire santé, mais ne pourra bénéficier des tarifs négociés par l’entreprise que durant un an, explique Olivier Moustacakis, cofondateur d’Assurland.com.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Comment le ministre de la santé, Aurélien Rousseau, tente d’imprimer sa marque', 'image': 'https://img.lemde.fr/2023/11/17/0/0/6328/4219/110/73/60/0/6e3e30f_1700234567165-940271.jpg', 'description': 'Aide médicale d’Etat, «\xa0doublement\xa0» des franchises, pénuries de médicaments, système de soin sous tension… Quatre mois après son installation Avenue de Ségur, le ministre de la santé doit se positionner sur des dossiers sensibles. Après une rentrée discrète, il défend son cap.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Les « patients partenaires », quand les malades du cancer deviennent experts', 'image': 'https://img.lemde.fr/2023/11/16/212/0/3500/2333/110/73/60/0/9127c10_1700128162636-pink-vill0331513.jpg', 'description': 'Les «\xa0pairs aidants\xa0», apparus au Canada, se développent en France depuis la fin des années 1990. Leur présence dans les services hospitaliers ou associations a contribué à parfaire les rapports entre médecins et patients.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Prévention : les « bilans » de santé aux âges-clés de la vie se font attendre', 'image': 'https://img.lemde.fr/2023/11/17/0/0/5860/3906/110/73/60/0/5b10d1d_1700234764531-940190.jpg', 'description': 'La mesure, inscrite dans le précédent budget de la Sécurité sociale, n’est pas encore en place.\xa0Le gouvernement a souhaité commencer par une expérimentation.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'De nouvelles pistes de traitement contre la tuberculose', 'image': 'https://img.lemde.fr/2023/11/17/0/34/4380/2920/110/73/60/0/b18ccac_1700239273625-000-13e35c.jpg', 'description': 'Présentées cette semaine à Paris, des combinaisons de médicaments et une molécule encore en développement pourraient alléger les traitements des personnes atteintes des formes les plus sévères de la maladie.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Quand on n’arrive pas à faire un bébé, on fait quoi ?', 'image': 'https://img.lemde.fr/2023/10/30/72/0/3004/2002/110/73/60/0/874c3ca_1698676158545-3.jpg', 'description': '«\xa0(In)fertile\xa0» (3/10). Lorsque les couples ne parviennent pas à concevoir naturellement, des techniques médicales existent pour les aider. A l’instar de la PMA.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Cancer : le temps des témoignages, sur les réseaux, sur scène ou dans des podcasts', 'image': 'https://img.lemde.fr/2023/11/03/136/133/3341/2227/110/73/60/0/4a3bfd6_1699029585419-patients-partenaires-2.jpg', 'description': 'Ces dernières années, des personnalités ont contribué à lever le tabou sur la maladie. Entraînant dans leur sillage de jeunes anonymes qui partagent le récit de leur combat, du diagnostic aux traitements.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Face à la résistance aux antibiotiques, la France présente une évolution contrastée', 'image': 'https://img.lemde.fr/2023/11/17/269/279/4365/2910/110/73/60/0/6677a17_1700240333143-000-1qf31a.jpg', 'description': 'L’Hexagone reste l’un des mauvais élèves de l’Europe sur le plan de la consommation humaine, avec des prescriptions en médecine de ville qui sont reparties à la hausse, en\xa02022, au sortir du Covid-19. L’exposition des animaux, elle, poursuit sa baisse.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Déserts médicaux : la SNCF annonce l’installation de centres de télémédecine dans environ 300 gares', 'image': 'https://img.lemde.fr/2016/05/29/0/0/5184/3456/110/73/60/0/2c9e0d0_5962920-01-06.jpg', 'description': 'L’entreprise ferroviaire précise que ces centres seront implantés dans les zones où l’offre de soin est insuffisante. Un partenariat qui nécessitera de trouver des infirmiers et des médecins libéraux disponibles pour participer au dispositif.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': '« La décision du Sénat de supprimer l’AME ne correspond à aucune logique médicale, budgétaire ou de lutte contre la fraude »', 'image': 'https://img.lemde.fr/2023/11/14/0/0/5855/3903/110/73/60/0/59f5dd4_5871354-01-06.jpg', 'description': 'Les médecins Bernard Basset, Amine Benyamina et François Bourdillon estiment, dans une tribune au «\xa0Monde\xa0», que le vote des sénateurs le 7\xa0novembre de la suppression de l’Aide médicale d’Etat constitue un moment noir pour la santé publique et les valeurs humanistes de la France.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Du cartel mexicain de Sinaloa aux rues de New York : au cœur du business du fentanyl', 'image': 'https://img.lemde.fr/2023/11/01/0/150/1620/1080/110/73/60/0/c5f2dd8_1698857249755-sei-quence-03-01-37-14-13-still136.jpg', 'description': 'Pendant deux ans, Bertrand Monnet, professeur à l’Edhec et spécialiste de l’économie du crime, a filmé pour «\xa0Le Monde\xa0» toutes les étapes du «\xa0business model\xa0» du cartel de Sinaloa, au Mexique. Dans ce deuxième épisode, zoom sur l’organisation bien huilée du cartel pour vendre le fentanyl, des clans du Culiacan aux dealeurs de New York.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Pour lutter contre les rendez-vous médicaux non honorés, le Sénat vote le principe d’une taxe forfaitaire', 'image': 'https://img.lemde.fr/2023/07/10/0/0/5149/3433/110/73/60/0/69f166f_1688973943036-000-1r56f0.jpeg', 'description': 'Entre 6\xa0% et 10\xa0% des patients ne se présenteraient pas à leurs rendez-vous. Le gouvernement se montre «\xa0très sensible\xa0» sur la question, mais il a rendu un avis défavorable concernant le mécanisme proposé et pourra le rejeter à l’Assemblée nationale grâce à l’article\xa049.3.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Santé : « La prévention des cancers ORL doit être considérée comme un véritable enjeu de santé publique »', 'image': 'https://img.lemde.fr/2023/11/16/0/10/5595/3730/110/73/60/0/84f096b_1700141015525-pns-2090328.jpg', 'description': 'Sabrina Le Bars, présidente de l’association de patients Corasso, et François Blot, président du comité d’éthique à l’Institut Gustave-Roussy, proposent, dans une tribune au «\xa0Monde\xa0», que l’on lance un projet de grande ambition afin de mieux lutter contre les cancers ORL.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Toques en stock aux fourneaux contre les inégalités nutritionnelles', 'image': 'https://img.lemde.fr/2023/11/13/0/0/1500/1000/110/73/60/0/7985a3c_310144-3347048.jpg', 'description': 'Depuis deux ans, l’association organise des ateliers de cuisine et de diététique à destination des publics défavorisés. Car la précarité alimentaire signifie aussi un accès plus difficile à une nourriture saine.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'La puff va-t-elle faire pschitt ?', 'image': 'https://img.lemde.fr/2023/11/15/1248/0/2292/1528/110/73/60/0/31a7f25_1700047804299-635-sem-objet.jpg', 'description': 'Grâce à la mobilisation des associations contre le tabagisme, la cigarette électronique jetable, très prisée des jeunes, pourrait faire l’objet d’une interdiction en France.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'La régulation de la charge de travail, grande oubliée du management', 'image': 'https://img.lemde.fr/2023/11/15/0/0/4612/3075/110/73/60/0/de36a0a_1700059785788-000-33w83kz.jpg', 'description': 'Bien définir et réguler la quantité de travail de chaque salarié de l’entreprise contribue à optimiser la productivité tout en réduisant l’inconfort ou le désengagement des employés comme des manageurs, voire à éviter les burn-out.'}
# 2023-11-28 16:25:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Fin de vie : que dit la loi actuelle ? Comprendre en trois minutes', 'image': 'https://img.lemde.fr/2023/11/14/0/42/456/304/110/73/60/0/aa651f0_1699981768484-findevie.jpg', 'description': 'VIDÉO - Quatorze mois après le débat national sur la fin de vie, le texte promis par Emmanuel Macron alors qu’il était candidat ne devrait être débattu à l’Assemblée nationale qu’en\xa02024. Mais que dit la loi actuelle, que ce nouveau projet veut modifier\xa0?'}
# 2023-11-28 16:25:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Le « Lancet Countdown » mesure les effets alarmants du changement climatique sur la santé', 'image': 'https://img.lemde.fr/2023/11/14/0/0/3000/2000/110/73/60/0/4837187_1699971667412-903042.jpg', 'description': 'Un rapport issu des travaux de 114\xa0experts établit l’impact du réchauffement en matière de mortalité, d’insécurité alimentaire et de transmission des maladies.'}
# 2023-11-28 16:25:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Fin de vie : Emmanuel Macron tarde à trancher certains points du projet de loi', 'image': 'https://img.lemde.fr/2023/11/14/267/0/4000/2666/110/73/60/0/cd3a7b3_1699952000167-kzihnioglu-macron-armistice-11092023-07.JPG', 'description': 'La question de l’«\xa0exception d’euthanasie\xa0» doit encore être arbitrée par le chef de l’Etat qui doit recevoir les ministres concernés par le sujet prochainement. L’hypothèse de faire voter le texte par référendum fait aussi débat.'}
# 2023-11-28 16:25:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Des soignants racontent comment ils se sont forgé une conviction sur l’euthanasie : « C’est moi qui vais m’en rappeler tous les jours de ma vie »', 'image': 'https://img.lemde.fr/2023/11/10/390/0/4480/2986/110/73/60/0/f4d36a6_1699628779166-231030jbalague-monde-findevie-025.jpg', 'description': 'Alors que le gouvernement peaufine son projet d’évolution de la loi, des praticiens racontent comment leur pratique auprès des malades, leurs dilemmes et des histoires intimes leur ont permis de se forger une opinion. Certains estiment que leur rôle est d’accompagner leurs patients jusqu’à répondre à leur demande de mourir, d’autres s’y opposent.'}
# 2023-11-28 16:25:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Impact des écrans sur les enfants : une méta-analyse fait état d’effets d’intensité « faible à modérée »', 'image': 'https://img.lemde.fr/2023/11/13/0/4/4920/3280/110/73/60/0/78b05e9_1699869905398-000-par7656082.jpg', 'description': 'Les auteurs d’une vaste revue de la littérature scientifique estiment que les recommandations sanitaires ne devraient pas concerner uniquement la durée d’exposition aux écrans, mais aussi le contexte d’utilisation.'}
# 2023-11-28 16:25:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Au Liberia, la jeunesse ravagée par la drogue', 'image': 'https://img.lemde.fr/2023/11/03/4/0/4464/2976/110/73/60/0/c17576b_1699020677961-fumei-e.jpg', 'description': 'Dans ce pays d’Afrique de l’Ouest marqué par quatorze années de guerre civile (1990-2003), la consommation de stupéfiants a explosé. Si les autorités commencent à mesurer l’ampleur du phénomène, le manque de structures sanitaires grève la prise en charge des consommateurs.'}
# 2023-11-28 16:25:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Fin de vie : « Mesure-t-on le risque d’ouvrir le chantier vertigineux de la légitimité de la demande d’accéder à la mort ? »', 'image': 'https://img.lemde.fr/2023/06/21/0/100/5041/3361/110/73/60/0/aa362f2_1687363479139-pns-4714163.jpg', 'description': 'Loin de la mort douce promise, à l’abri du tumulte extérieur et des incertitudes, la création d’un droit à l’aide au suicide pourrait engendrer une multitude de situations problématiques, souligne, dans une tribune au «\xa0Monde\xa0», la juriste Marie Grosset.'}
# 2023-11-28 16:25:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Un quatrième mort dans un Ehpad d’Ille-et-Vilaine, après une probable intoxication alimentaire', 'image': 'https://img.lemde.fr/2023/10/23/0/0/5860/3907/110/73/60/0/0ac1c14_1698072441024-hanslucas-hl-aboureau-2138702.jpg', 'description': 'Selon le quotidien «\xa0Ouest-France\xa0», la direction de la résidence Les Marais, de Pleine-Fougères, a confirmé que «\xa0l’origine alimentaire\xa0» de la pathologie était «\xa0aujourd’hui avérée\xa0»'}
# 2023-11-28 16:25:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': '« Si nous n’agissons pas, les changements climatiques conduiront bientôt à la submersion des systèmes de santé du monde entier »', 'image': 'https://img.lemde.fr/2022/03/30/216/0/5184/3456/110/73/60/0/f88a43e_1648623765275-pns-3924713.jpg', 'description': 'Le directeur général de l’OMS, le président de la COP28 et l’envoyée spéciale de l’OMS pour les changements climatiques et la santé alertent, dans une tribune au «\xa0Monde\xa0», sur l’impact majeur que les changements climatiques pourraient avoir sur la santé et appellent à prendre des mesures fortes lors de la Journée de la santé, qui se tiendra le 3\xa0décembre.'}
# 2023-11-28 16:25:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Suppression de l’AME : 3 500 médecins menacent de désobéir si l’aide médicale d’Etat disparaît', 'image': 'https://img.lemde.fr/2020/10/16/0/0/3500/2333/110/73/60/0/386c1f3_gggpr05-health-coronavirus-france-hospital-1016-11.JPG', 'description': 'Ces professionnels de santé s’engagent à «\xa0continuer de soigner gratuitement\xa0» les malades sans papiers si le dispositif devait disparaître, comme le souhaite une partie de la classe politique.'}
# 2023-11-28 16:25:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Etre un père présent à l’accouchement, oui, mais comment ?', 'image': 'https://img.lemde.fr/2023/10/09/0/378/1961/1307/110/73/60/0/b235177_1696845556808-s3-eu-west-1-wellcomecollection-storage-digitised-b12025069-v1-data-objects-v0017247-ra-ra-jp2.jpg', 'description': '«\xa0Mon père, ce héros\xa0». Un récit intime de paternité, par Gabriel Coutagne. Tout a commencé à la maternité des Bluets, à Paris, un après-midi de décembre\xa02022.'}
# 2023-11-28 16:25:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/international/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/afrique/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Les difficultés des étudiants souffrant d’un trouble de l’attention : « Pourquoi j’ai cette impression de ne pas fonctionner comme les autres ? »', 'image': 'https://img.lemde.fr/2023/11/27/181/0/7543/5028/110/73/60/0/96a9a0e_1701081415992-tdah-clr.jpg', 'description': 'Le nombre de jeunes atteints d’un TDAH est en hausse dans l’enseignement supérieur. Une meilleure reconnaissance qui pourrait s’expliquer par la libération de la parole sur les troubles cognitifs et les effets de la loi de 2005\xa0sur l’inclusion des élèves en situation de handicap.'}
# 2023-11-28 16:25:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sport/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/societe/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/les-decodeurs/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/climat/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/planete/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:25:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Education : « Pourquoi n’envisageons-nous pas que les élèves les plus avancés puissent sauter la classe de CM2 ou la 6\u1d49 ? »', 'image': 'https://img.lemde.fr/2023/03/02/0/0/6000/4000/110/73/60/0/4656cf5_1677770202773-000-9m34fn.jpg', 'description': 'Alors que le ministre de l’éducation nationale, Gabriel Attal, s’apprête à annoncer des mesures pour «\xa0élever le niveau\xa0» scolaire, Ali Saïb et Baptiste Larseneur, experts à l’Institut Montaigne, plaident, dans une tribune au «\xa0Monde\xa0», pour l’aménagement du collège unique.'}
# 2023-11-28 16:25:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Pourquoi les groupes de niveau au collège pourraient accroître les inégalités sans élever le niveau général', 'image': 'https://img.lemde.fr/2023/11/27/57/0/7268/4845/110/73/60/0/afda881_1701097189279-000-33rb7jh.jpg', 'description': 'Le ministre de l’éducation nationale, Gabriel Attal, réfléchit à la création de groupes de niveau au collège pour améliorer les résultats. Une mesure qui risque, selon les chercheurs, d’accroître les inégalités sans élever le niveau général.'}
# 2023-11-28 16:25:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': '« Finale des championnats d’Europe. Arrivée au milieu, je déchire mon dossard. Le début d’une descente aux enfers »', 'image': 'https://img.lemde.fr/2023/10/26/0/0/3543/2362/110/73/60/0/d12e60a_1698331746805-premiei-re-fois-lemonde-01.jpg', 'description': '«\xa0Premières fois\xa0»\xa0: récits de moments charnières autour du passage à l’âge adulte. Cette semaine, Claire Palou, 21\xa0ans, ex-espoir de l’athlétisme français, raconte comment le monde du sport de haut niveau a causé sa dépression.'}
# 2023-11-28 16:25:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Dominique Méda, sociologue : « Cessons de répéter que les jeunes ne veulent plus travailler »', 'image': 'https://img.lemde.fr/2023/11/23/1/0/6000/4000/110/73/60/0/b01418e_5945822-01-06.jpg', 'description': 'Enquêtes et sondages démontrent l’inanité des jugements portés sur «\xa0la jeunesse\xa0», dont les attentes et les opinions sont aussi diverses que celles des autres générations, affirme la professeure de sociologie dans sa chronique.'}
# 2023-11-28 16:25:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Déçus par Parcoursup, comment avez-vous rebondi ?', 'image': 'https://img.lemde.fr/2023/05/22/0/0/2125/1417/110/73/60/0/c9aa0cb_1684760189910-parcoursup-choix2-exe.jpg', 'description': 'Vous n’avez pas obtenu la formation que vous désiriez lors d’une précédente session de la procédure d’admission postbac, mais avez finalement découvert ou trouvé une voie qui vous convient. Racontez-nous.'}
# 2023-11-28 16:25:32 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# ...
#
# {'title': 'Le Qatar, acteur-clé dans les discussions entre Israël et le Hamas', 'image': 'https://img.lemde.fr/2023/11/22/0/0/3193/2129/110/73/60/0/e607779_1700671913337-000-33zu7qj.jpg', 'description': 'L’émirat s’est imposé depuis une dizaine d’années comme le médiateur privilégié entre l’Etat hébreu et le mouvement islamiste, qu’il finance en partie dans la bande de Gaza avec l’accord des autorités israéliennes.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : ce que l’on sait de l’accord conclu pour la libération d’otages', 'image': 'https://img.lemde.fr/2023/11/22/0/0/6000/4000/110/73/60/0/5e763a2_1700618223301-asurp-israel-107136.jpg', 'description': 'Les otages concernés par l’accord sont des femmes et des enfants enlevés par le Hamas lors de l’attaque du 7\xa0octobre. Les premières libérations\xa0et le début de la trêve de quatre jours sont intervenus vendredi.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : à Rafah, des rescapés de Gaza sous le choc et des tonnes d’aide humanitaire en attente', 'image': 'https://img.lemde.fr/2023/11/22/0/0/5961/3974/110/73/60/0/cb25a43_5942271-01-06.jpg', 'description': 'Depuis le 21\xa0octobre, près de 9\xa0000\xa0personnes ont été évacuées par le poste-frontière avec l’Egypte, unique échappatoire de l’enclave palestinienne.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'A São Paulo, la concorde entre juifs et musulmans ébranlée', 'image': 'https://img.lemde.fr/2023/11/21/0/0/1500/1000/110/73/60/0/830b0a0_313932-3348232.jpg', 'description': 'Le modèle brésilien de coexistence pacifique entre les religions est mis à mal par la guerre entre le Hamas et Israël. Face à l’essor des actes antisémites et islamophobes, les clercs tentent de préserver le dialogue interreligieux.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : tout comprendre à l’accord sur les otages', 'image': 'https://img.lemde.fr/2023/11/22/0/0/1800/1200/110/73/60/0/9653e6f_1700646514333-photo-accord-otage3.png', 'description': 'Après des semaines de négociations, le gouvernement israélien et le mouvement islamiste ont conclu, mercredi, un accord prévoyant la libération de 50\xa0otages en échange d’une trêve limitée et de prisonniers palestiniens. Quelles sont les modalités de ce texte\xa0? Comment les deux camps sont-ils parvenus à cet accord\xa0? Réponses dans ce podcast avec Benjamin Barthe, journaliste au «\xa0Monde\xa0».'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'A Tel-Aviv, les espoirs et les craintes des familles d’otages du Hamas dans l’attente des premières libérations', 'image': 'https://img.lemde.fr/2023/11/22/0/0/6000/4000/110/73/60/0/02cc707_1700666626393-asurp-israel-108198.jpg', 'description': 'Le chef du Conseil national de sécurité israélien, Tzachi Hanegbi, a déclaré que les libérations n’interviendraient «\xa0pas avant vendredi\xa0» et que les négociations «\xa0se\xa0poursuivaient sans cesse\xa0».'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Les Etats-Unis ont intercepté des drones d’attaque lancés depuis le Yémen', 'image': 'https://img.lemde.fr/2021/04/03/0/3/3493/2329/110/73/60/0/fbe6a46_navy-ho-001-egypt-suezcanal-ship-us-navy-0403-11.JPG', 'description': '«\xa0Le “USS Thomas Hudner” a tiré et détruit de nombreux drones d’attaque lancés depuis la région du Yémen contrôlée par les houthistes\xa0» a expliqué le commandement militaire américain au Moyen-Orient.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'A Paris, une instagrameuse jugée pour apologie du terrorisme', 'image': 'https://img.lemde.fr/2023/11/22/0/0/5229/3486/110/73/60/0/360464d_1700667986630-000-33yl7gq.jpg', 'description': 'Dans deux vidéos devenues virales, Warda\xa0A. avait ironisé sur la mort d’un bébé israélien et affirmé que le Hamas «\xa0n’est pas un mouvement terroriste\xa0». Le procureur a requis dix mois d’emprisonnement avec sursis.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : quatre Libanais, dont deux journalistes, tués dans des frappes israéliennes', 'image': 'https://img.lemde.fr/2023/11/22/0/85/5638/3759/110/73/60/0/bc0d068_1700641183480-220460.jpg', 'description': 'Depuis le 7\xa0octobre, cinquante-trois professionnels des médias ont été tués. Parmi eux figurent trois Libanais, quatre Israéliens et quarante-six Palestiniens.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : récit des cinq semaines de discussions qui ont abouti à un accord pour des premières libérations d’otages', 'image': 'https://img.lemde.fr/2023/11/22/0/0/6000/4000/110/73/60/0/5e763a2_1700618223301-asurp-israel-107136.jpg', 'description': 'Cinquante femmes et enfants détenus par le Hamas à Gaza devraient être libérés en échange de cent cinquante prisonniers palestiniens et d’une trêve limitée.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Les BRICS+ ne parviennent pas à s’accorder sur la guerre à Gaza face à l’Occident', 'image': 'https://img.lemde.fr/2023/11/22/0/46/3039/2026/110/73/60/0/4082b6e_1700640604803-921861.jpg', 'description': 'Aucune déclaration commune n’est sortie du sommet par visioconférence des dirigeants du forum de pays émergents, qui s’est contenté d’appeler à une «\xa0trêve humanitaire immédiate\xa0» conduisant à un cessez-le-feu et à «\xa0la protection des civils et la fourniture d’aide humanitaire\xa0» dans l’enclave.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'A Tel-Aviv, l’insupportable attente des familles d’otages', 'image': 'https://img.lemde.fr/2023/11/22/0/0/6000/4000/110/73/60/0/dff4a1e_1700618171413-asurp-israel-107086.jpg', 'description': 'Hadas Kalderon, mère de deux enfants enlevés par le Hamas le 7\xa0octobre, ignore s’ils feront partie des otages qui seront libérés dans le cadre de l’accord voté mercredi par le gouvernement de Benyamin Nétanyahou.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Joe Biden et Israël : une amitié à l’épreuve du feu', 'image': 'https://img.lemde.fr/2023/11/21/0/0/1800/1200/110/73/60/0/f8a1c2d_1700564532431-biden-et-israel.png', 'description': 'Depuis le 7\xa0octobre, le président américain a fait preuve d’un soutien indéfectible à Israël. Une position critiquée depuis que l’Etat hébreu bombarde sans relâche la bande de Gaza au prix de nombreuses vies civiles. Piotr Smolar est le correspondant du «\xa0Monde\xa0» à Washington, il explique la position de Joe Biden et ses répercussions politiques possibles.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': 'Des étoiles de David taguées en Ile-de-France : enquête ouverte, Elisabeth Borne dénonce des « agissements ignobles »', 'image': 'https://img.lemde.fr/2023/10/31/0/39/6418/4279/110/73/60/0/943e035_1698753367286-873033.jpg', 'description': 'La mairie du 14e arrondissement de Paris a dénoncé des «\xa0actes antisémites\xa0». Des tags semblables sont apparus ces derniers jours dans les Hauts-de-Seine et en Seine-Saint-Denis.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': 'Guerre Israël-Hamas : l’inquiétude de la communauté juive de France face à la recrudescence des actes antisémites', 'image': 'https://img.lemde.fr/2023/10/25/0/0/5328/3552/110/73/60/0/9eaa885_1698240852359-773594.jpg', 'description': 'Si aucun fait d’agression violente n’est à déplorer, le ministère de l’intérieur a recensé 501\xa0actes antisémites depuis l’attaque du Hamas en Israël le 7\xa0octobre. Une situation qui pousse certains à retirer tout signe extérieur de judéité.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': 'Gérald Darmanin demande aux préfets d’interdire toutes les « manifestations propalestiniennes »', 'image': 'https://img.lemde.fr/2023/10/12/0/0/5875/3916/110/73/60/0/3ce0310_1697123277113-773593.jpg', 'description': 'Les autorités redoutent plus que jamais l’émergence, en France, de tensions liées au conflit. En cinq jours, la plate-forme Pharos a enregistré le quart des signalements pour provocations à la discrimination raciale, ethnique ou religieuse enregistrés pour l’ensemble de l’année 2022.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/antisemitisme/>
#
# {'title': '« Plus d’une centaine d’actes antisémites » signalés en France depuis l’attaque d’Israël par le Hamas, selon Gérald Darmanin', 'image': 'https://img.lemde.fr/2023/10/09/0/0/8256/5504/110/73/60/0/a4b6d8a_5527515-01-06.jpg', 'description': 'Il s’agit, selon le ministère de l’intérieur, de tags ou d’insultes à la communauté juive. Il a répété qu’il n’y avait pas de signe d’importation du conflit ou de «\xa0menace terroriste islamiste\xa0» en France.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : la question des prisonniers palestiniens au cœur du conflit', 'image': 'https://img.lemde.fr/2023/11/19/387/0/4628/3085/110/73/60/0/fb3dea9_1700389582890-13112023-l3140238.jpg', 'description': 'L’accord validé, dans la nuit de mardi à mercredi, par Israël impliquerait la libération de 150\xa0prisonniers palestiniens en échange de celle de 50\xa0femmes et enfants otages du Hamas. Au total, 6\xa0700\xa0Palestiniens seraient en prison dans l’Etat hébreu, plusieurs d’entre eux y sont morts depuis l’attaque du 7\xa0octobre.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'L’Union européenne poursuit son aide au développement en faveur de la Palestine', 'image': 'https://img.lemde.fr/2023/11/21/0/0/5472/3648/110/73/60/0/91576ca_1700590530398-000-344a3em.jpg', 'description': 'La Commission européenne a donné son aval après avoir procédé, depuis le 7\xa0octobre, à une analyse du mécanisme d’aide au développement. Elle estime qu’aucun élément n’indique que des fonds de l’UE auraient bénéficié au Hamas.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Au Maroc, les groupes Carrefour et McDonald’s ciblés par un boycott sur fond de guerre à Gaza', 'image': 'https://img.lemde.fr/2023/11/21/0/0/1024/682/110/73/60/0/b355ed2_1700575647391-000-app2003052684484.jpg', 'description': 'Les deux enseignes sont accusées de soutenir l’armée israélienne, notamment par des dons alimentaires, ou de commercer dans les colonies.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : suspendues aux négociations, les familles d’otages entre angoisse et colère', 'image': 'https://img.lemde.fr/2023/11/21/0/126/5874/3916/110/73/60/0/429c885_1700555544965-asurp-israel-105335.jpg', 'description': 'Les tractations pour récupérer une cinquantaine d’otages kidnappés par le Hamas en échange d’une trêve de quelques jours et de la libération de prisonniers palestiniens détenus en Israël seraient sur le point d’aboutir. Leurs proches, comme la Franco-Israélienne Hadas Kalderon, attendent des nouvelles, rassemblés sur une place de Tel-Aviv.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : « Il nous faut désormais résister au vertige et à l’ivresse de la vengeance »', 'image': 'https://img.lemde.fr/2023/11/20/0/190/3189/2126/110/73/60/0/38bae52_5926154-01-06.jpg', 'description': 'L’ancien ministre chargé de l’eau de l’Autorité palestinienne Shaddad Attili répond, dans une tribune au «\xa0Monde\xa0», au président du Forum international pour la paix et la réconciliation au Moyen-Orient, Ofer Bronchtein, auteur d’une «\xa0lettre à un ami palestinien\xa0» publiée le 23\xa0octobre dans laquelle il déplorait l’absence de compassion de certains militants pacifistes à l’égard des victimes israéliennes du Hamas.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Sommet des BRICS : l’Afrique du Sud accuse Israël de « crimes de guerre » et « génocide » à Gaza', 'image': 'https://img.lemde.fr/2023/11/21/0/0/3868/2578/110/73/60/0/c2d0783_1700577056273-000-344839t.jpg', 'description': 'Le président Ramaphosa demande, en plus d’un cessez-le-feu, le déploiement d’une force rapide de l’ONU pour «\xa0surveiller la cessation des hostilités\xa0» et «\xa0protéger les civils\xa0».'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : à Paris, le drame personnel de l’ambassadrice palestinienne, Hala Abou Hassira', 'image': 'https://img.lemde.fr/2023/11/21/507/0/7613/5075/110/73/60/0/df45b2e_1700555810159-ll-hala-abou-hassira-02.jpg', 'description': 'Native de Gaza, la représentante en France de l’Autorité palestinienne depuis deux ans a perdu soixante membres de sa famille dans les bombardements israéliens.'}
# 2023-11-28 16:25:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Vidéo : les rebelles houthistes du Yémen se sont emparés d’un navire en mer Rouge', 'image': 'https://img.lemde.fr/2023/11/21/0/0/1620/1080/110/73/60/0/daa324e_ae4d7f9f6cad407da609d926fe2c14cc-0-160067ee41d849bbad582ec10ba3da44.jpg', 'description': 'Les houthistes ont affirmé avoir saisi ce navire, propriété d’un homme d’affaires israélien, en représailles à la guerre menée par l’Etat hébreu contre le Hamas dans la bande de Gaza.'}
# 2023-11-28 16:25:33 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-11-28 16:25:33 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 12252,
#  'downloader/request_count': 31,
#  'downloader/request_method_count/GET': 31,
#  'downloader/response_bytes': 2538783,
#  'downloader/response_count': 31,
#  'downloader/response_status_count/200': 31,
#  'elapsed_time_seconds': 2.310409,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 11, 28, 15, 25, 33, 760445, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 10096385,
#  'httpcompression/response_count': 31,
#  'item_scraped_count': 1522,
#  'log_count/DEBUG': 1554,
#  'log_count/ERROR': 3,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'request_depth_max': 1,
#  'response_received_count': 31,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 30,
#  'scheduler/dequeued/memory': 30,
#  'scheduler/enqueued': 30,
#  'scheduler/enqueued/memory': 30,
#  'spider_exceptions/IndexError': 3,
#  'start_time': datetime.datetime(2023, 11, 28, 15, 25, 31, 450036, tzinfo=datetime.timezone.utc)}
# 2023-11-28 16:25:33 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On peut exporter les résultats de ces retours dans différents formats de
# fichiers.
#
# -   CSV : `scrapy crawl lemonde -o lbc.csv`
# -   JSON : `scrapy crawl lemonde -o lbc.json`
# -   JSONLINE : `scrapy crawl lemonde -o lbc.jl`
# -   XML : `scrapy crawl lemonde -o lbc.xml`
#
# ### Exercice :
#
# Exécuter la spider avec les différents formats de stockage.
# Explorer ensuite le contenu des fichiers ainsi créés.

# %%
# !cd newscrawler && scrapy crawl lemondev3 -o ../data/lbc.csv
# Out:
# 2023-11-28 16:37:25 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: newscrawler)
# 2023-11-28 16:37:25 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.5, Platform Windows-10-10.0.22621-SP0
# 2023-11-28 16:37:25 [scrapy.addons] INFO: Enabled addons:
# []
# 2023-11-28 16:37:25 [py.warnings] WARNING: C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-11-28 16:37:25 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-11-28 16:37:25 [scrapy.extensions.telnet] INFO: Telnet Password: 4333b417d2e12cc1
# 2023-11-28 16:37:25 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2023-11-28 16:37:25 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2023-11-28 16:37:25 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-11-28 16:37:25 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-11-28 16:37:25 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-11-28 16:37:25 [scrapy.core.engine] INFO: Spider opened
# 2023-11-28 16:37:25 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-11-28 16:37:25 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-11-28 16:37:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2023-11-28 16:37:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: None)
# 2023-11-28 16:37:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: https://www.lemonde.fr)
# 2023-11-28 16:37:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/pixels/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:37:25 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\spidermiddlewares\offsite.py", line 28, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\2Scrapy\newscrawler\newscrawler\spiders\lemonde_v3.py", line 21, in parse_category
#     for article in response.css(".river")[0].css(".teaser"):
#                    ~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "C:\Users\march\PycharmProjects\DataEngineerTools\venv\Lib\site-packages\parsel\selector.py", line 143, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2023-11-28 16:37:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sante/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:37:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/le-fil-good/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:37:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/intimites/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:37:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/le-monde-et-vous/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:37:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/disparitions/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:37:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sciences/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': '« Une brève histoire des hackeurs russes » : éclairage des fantassins virtuels du Kremlin', 'image': 'https://img.lemde.fr/2023/11/27/251/0/489/326/110/73/60/0/7aac4cd_1701071673178-9782330184339.jpg', 'description': 'Devenus dès les années 1990\xa0des virtuoses du piratage bancaire, des jeunes russophones férus d’informatique ont peu à peu été mis à contribution par le pouvoir pour attaquer des cibles géostratégiques.'}
# 2023-11-28 16:37:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/campus/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Au procès des cyberharceleurs de Magali Berdah : « Se faire menacer d’être décapitée et violée, cela ne fait partie d’aucun métier »', 'image': 'https://img.lemde.fr/2023/11/25/0/0/8256/5504/110/73/60/0/f16afa9_1700911582669-000-33er3k2.jpg', 'description': 'Treize prévenus sont jugés à partir de ce lundi pour avoir harcelé l’agente d’influenceurs sur Internet. Lors du premier jour d’audience, elle a raconté le flot de messages haineux qui ont fait irruption dans sa vie à partir de mai\xa02022. Le tout en l’absence de son principal contempteur\xa0: le rappeur Booba.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': '« Renoncer à un encadrement juridique ambitieux de l’intelligence artificielle affaiblirait la position historique de l’Europe »', 'image': 'https://img.lemde.fr/2023/11/27/0/0/4999/3333/110/73/60/0/56f6b24_5975579-01-06.jpg', 'description': 'Un collectif de quatorze spécialistes de l’intelligence artificielle, parmi lesquels Yoshua Bengio, Raja Chatila et Nicolas Miailhe, détaille, dans une tribune au «\xa0Monde\xa0», les enjeux cruciaux des négociations en cours au sein de l’Union européenne pour encadrer juridiquement l’IA générative.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Intelligence artificielle : « Le fait de s’éloigner de l’idéalisme académique et de se tourner vers le pragmatisme commercial a dû créer le conflit chez OpenAI »', 'image': 'https://img.lemde.fr/2023/11/22/0/0/4999/3333/110/73/60/0/f230654_2023-11-22t185141z-2061880129-rc2ne4aqyil4-rtrmadp-3-openai-ceo-governance-analysis-pix.JPG', 'description': 'La crise autour de la vraie-fausse éviction de Sam Altman à la tête d’OpenAI illustre la bataille entre les «\xa0décélérationnistes\xa0» et les «\xa0accélérationnistes\xa0», explique, dans une tribune au «\xa0Monde\xa0», l’expert des technologies Georges Nahon.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': '« L’IA générative est une affaire trop sérieuse pour la laisser dans les seules mains du capital »', 'image': 'https://img.lemde.fr/2023/11/22/0/0/6000/4000/110/73/60/0/8565c91_5941766-01-06.jpg', 'description': 'La crise de gouvernance que vient de connaître OpenAI montre que les bonnes intentions éthiques ne seront pas suffisantes pour encadrer les avancées de l’intelligence artificielle. Il y a urgence à mettre en place une régulation capable de borner les ambitions des apprentis sorciers, affirme Stéphane Lauer, éditorialiste au «\xa0Monde\xa0», dans sa chronique.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Meta accusé d’inaction face au nombre de mineurs âgés de moins de 13 ans sur Instagram et Facebook', 'image': 'https://img.lemde.fr/2023/11/27/0/0/5100/3400/110/73/60/0/aa6cbb7_3de8b461f19c457da58e1f6e2c9039fb-0-cf249c4a9a68482599bdfd35db8b2d07.jpg', 'description': 'Selon des documents internes à l’entreprise produits dans le cadre d’une plainte aux Etats-Unis, le groupe de Mark Zuckerberg ne se donnerait pas les moyens d’empêcher les plus jeunes d’utiliser ses plates-formes. Pire\xa0: elle aurait délibérément ignoré les signalements et continué à collecter leurs données.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Anne Hidalgo : « Pour rester fidèle à mes convictions et à mon engagement, je quitte aujourd’hui X »', 'image': 'https://img.lemde.fr/2023/11/27/0/13/504/336/110/73/60/0/bc4b28b_1701076062815-hidalgo-twitter.png', 'description': 'Dans une tribune au «\xa0Monde\xa0», la maire de Paris explique pourquoi elle vient de supprimer son compte. Selon elle, le réseau social X (ex-Twitter), propriété du milliardaire Elon Musk est devenu un outil de déstabilisation de la démocratie.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Rashid Ismailov, ancien ministre des télécoms en Russie : « Le modèle actuel de la gouvernance d’Internet est désuet »', 'image': 'https://img.lemde.fr/2023/11/24/0/0/4744/3162/110/73/60/0/d0a551b_1700834676425-ap22269472416341.jpg', 'description': 'Dans un entretien au «\xa0Monde\xa0», le candidat malheureux au poste de secrétaire général de l’agence onusienne Union internationale des télécoms estime qu’une nouvelle approche est nécessaire pour relever les défis de la révolution numérique et défend, dans le même temps, la censure russe.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Pourquoi la quête de souveraineté numérique sur Internet menace l’hégémonie américaine', 'image': 'https://img.lemde.fr/2023/11/23/1/0/4000/2666/110/73/60/0/b5f2d87_1700737916618-051-xxjpbee007172-20231108-pepfn0a001.jpg', 'description': 'Les rivalités autour de la gouvernance d’Internet s’exacerbent dans le monde. Face à la société Icann (Internet Corporation for Assigned Names and Numbers), créée par les Etats-Unis il y a vingt-cinq ans pour gérer les noms de domaine, les Nations unies et la Chine veulent avoir leur mot à dire sur l’avenir du «\xa0réseau des réseaux\xa0».'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'L’intelligence artificielle pour fouiller la mémoire de Notre-Dame de Paris', 'image': 'https://img.lemde.fr/2023/11/20/0/513/4765/3177/110/73/60/0/401c420_1700478991442-mac230090d00581.jpg', 'description': 'Un programme expérimental, mis au point dans un laboratoire de la Sorbonne, permet de parcourir les délibérations des chanoines du chapitre tout au long du Moyen Age.'}
# 2023-11-28 16:37:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/les-decodeurs/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Intelligence artificielle : le monde de la culture redoute une spoliation massive', 'image': 'https://img.lemde.fr/2023/11/22/121/0/2185/1456/110/73/60/0/db91a1e_1700693887533-illustration-sans-titre.jpg', 'description': 'Le secteur de la culture, qui réclame qu’une réelle transparence des données utilisées par les IA génératives soit assurée, s’agace de la position de la France au niveau européen sur cette question.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'La justice monténégrine approuve l’extradition du Sud-Coréen Do Kwon, fondateur de la cryptomonnaie terra', 'image': 'https://img.lemde.fr/2023/11/21/0/0/4246/2831/110/73/60/0/96ada93_2023-11-21t194510z-2122604007-rc2uh4ahmkt2-rtrmadp-3-fintech-crypto-ceos-regulators.JPG', 'description': 'Séoul et Washington réclament tous deux cet entrepreneur pour son rôle dans la fraude liée à l’effondrement de son entreprise, en\xa02022, qui a fait perdre quelque 40\xa0milliards de dollars aux investisseurs.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': '« L’industrie de la cybersurveillance s’est adaptée sur toute la chaîne de valeur pour répondre au marché à la fois intérieur et à l’export »', 'image': 'https://img.lemde.fr/2019/06/21/0/102/726/484/110/73/60/0/1b936be_xaIOSHJ2DSCvws80fv-Nk-J4.PNG', 'description': 'Les logiciels développés par l’industrie de la surveillance et utilisés par les Etats peuvent entraîner une remise en question de la vie privée, souligne l’expert en cybersécurité Jean-Philippe Commeignes, dans une tribune au «\xa0Monde\xa0».'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Intelligence artificielle : derrière la fortune de l’île d’Anguilla et de son « .ai », une forme de « néocolonialisme numérique »', 'image': 'https://img.lemde.fr/2023/11/24/0/0/3000/2000/110/73/60/0/161b91f_1700821575398-illu-anguilla.jpg', 'description': 'Propriétaire de l’extension de nom de domaine «\xa0.ai\xa0», cette île des Caraïbes a vu les demandes d’enregistrement exploser depuis le succès de ChatGPT. Mais sa «\xa0success story\xa0» fait exception, la spoliation des terminaisons par des entrepreneurs opportunistes étant bien souvent la règle.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Gouvernance d’Internet : la Chine promeut sa propre norme pour gagner en « maîtrise »', 'image': 'https://img.lemde.fr/2023/11/24/25/0/7821/5214/110/73/60/0/8e447d0_1700834337999-000-32kc7mt.jpg', 'description': 'A l’unisson de l’Union internationale des télécommunications (UIT), une agence des Nations unies, Pékin prône un système de régulation «\xa0tripartite\xa0» (gouvernements, secteur privé et société civile), où les Etats auraient plus la main sur «\xa0leur\xa0» réseau.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': '« Black Friday sur les gosses » : l’étrange théorie du complot d’enfants vendus sur Vinted', 'image': 'https://img.lemde.fr/2023/11/23/0/0/5472/3648/110/73/60/0/50f138c_1700769051862-sipa-shutterstock40914534-000006.jpg', 'description': 'Selon une rumeur inspirée des Etats-Unis, des pédocriminels dissimuleraient un trafic de mineurs derrière des annonces de jouets ou de vêtements. La plate-forme de revente n’a pas trouvé trace d’activité criminelle.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'OpenAI : aux sources de l’affaire Sam Altman', 'image': 'https://img.lemde.fr/2023/11/24/12/0/4837/3224/110/73/60/0/ad21f36_1700812400740-gettyimages-1257892751.jpg', 'description': 'La séquence qui a vu, en cinq jours, le patron star d’OpenAI limogé de sa propre entreprise, puis réintégré, a fasciné le monde. Retour aux sources d’une crise qui mélange querelles de «\xa0nerds\xa0», débats messianiques, coups bas et milliards de dollars.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Anthony Babkine, Diversidays : « Le secteur du numérique est l’ascenseur social du XXI\u1d49 siècle »', 'image': 'https://img.lemde.fr/2022/08/08/2/0/5600/3733/110/73/60/0/7791654_1659945658149-pns-703220575.jpg', 'description': '«\xa0Rebond, vivre avec le handicap\xa0» (5/5). Le secteur du numérique est en plein boom et, pourtant, il manque de candidats et pourrait être une opportunité pour des personnes en situation de handicap.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Vidéosurveillance algorithmique : une communauté de communes sommée de supprimer des données personnelles', 'image': 'https://img.lemde.fr/2018/07/27/47/0/551/366/110/73/60/0/b28e0e4_4843-7fsgto.lzq3p.jpg', 'description': 'La communauté de communes normande de Cœur Côte Fleurie, qui comprend notamment Deauville et Trouville, a cinq jours pour se débarrasser des données collectées grâce au logiciel de vidéosurveillance algorithmique BriefCam.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Philippe Trotin, Microsoft : « La France est un élève moyen en termes d’accessibilité numérique »', 'image': 'https://img.lemde.fr/2022/11/29/0/0/6720/4480/110/73/60/0/e957a93_1669715824484-pns-6302071.jpg', 'description': '«\xa0Rebond, vivre avec le handicap\xa0» (4/5). Sites Web, applications mobiles, logiciels… les Gafam sont au premier plan pour favoriser l’accessibilité numérique. A l’image de Microsoft.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': '« C’est comme mettre une caméra dans toutes les maisons » : le patron de WhatsApp défend le chiffrement des messages face à un projet de loi européen', 'image': 'https://img.lemde.fr/2023/07/11/0/18/2955/1970/110/73/60/0/dae0b1d_1689093747494-andia-abc-brpaphotos20201229-053.jpg', 'description': 'L’Union européenne travaille actuellement à un règlement pour lutter contre la pédopornographie\xa0: dans certaines versions du texte, les messageries auraient l’obligation d’inspecter tous les messages envoyés par leurs utilisateurs.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': '« Nvidia est aujourd’hui le seul à gagner de l’argent dans la ruée vers l’intelligence artificielle »', 'image': 'https://img.lemde.fr/2023/11/21/0/0/4299/2866/110/73/60/0/cbadebf_2023-11-21t205617z-1328885767-rc2koz9pxcrm-rtrmadp-3-nvidia-results-etfs.JPG', 'description': 'L’électronicien américain affiche des résultats vertigineux pour le troisième trimestre 2023, son fondateur ayant su bâtir tout un écosystème indispensable à la construction de serveurs informatiques. Mais la ruée vers l’or a aussi appris aux Américains que la roue tourne parfois, rappelle Philippe Escande, éditorialiste économique au «\xa0Monde\xa0».'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Sam Altman revient à la tête d’OpenAI avec le soutien de Microsoft', 'image': 'https://img.lemde.fr/2023/11/22/0/0/4999/3333/110/73/60/0/36b03f5_1700642890184-208760.jpg', 'description': 'Le psychodrame au sein de l’inventeur de ChatGPT vient de connaître un nouveau tournant\xa0: limogé vendredi, le cofondateur d’OpenAI est de retour dans l’entreprise, et un conseil d’administration intérimaire est désigné.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Cryptomonnaies : une amende colossale pour Binance et son patron, Changpeng Zhao', 'image': 'https://img.lemde.fr/2023/11/21/0/0/2043/1362/110/73/60/0/17c16ac_5936784-01-06.jpg', 'description': 'L’entrepreneur sino-canadien Changpeng Zhao et la principale plate-forme d’échange de cryptodevises ont été condamnés à payer un total de 3,9\xa0milliards d’euros d’amendes pour avoir violé les lois antiblanchiment américaines.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'OpenAI annonce le retour à sa tête de Sam Altman', 'image': 'https://img.lemde.fr/2023/11/21/0/0/4999/3333/110/73/60/0/26ad00e_2023-11-21t235532z-1291111748-rc2ne4asgk1t-rtrmadp-3-openai-altman-legal.JPG', 'description': 'Star de la Silicon Valley, Sam Altman avait été évincé de sa propre start-up OpenAI, créatrice de ChatGPT, puis embauché par Microsoft. Près de\xa0700 des 770\xa0salariés d’OpenAI avaient menacé de démissionner si Sam Altman ne revenait pas.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Luce Carevic, experte en accessibilité numérique : « Les sites et logiciels ont un niveau d’accessibilité déplorable »', 'image': 'https://img.lemde.fr/2023/09/14/0/0/5599/3733/110/73/60/0/1f1ac73_1694706457924-pns-703223634.jpg', 'description': '«\xa0Rebond, vivre avec le handicap\xa0» (3/5). En entreprise, faciliter l’usage des outils numériques par les salariés en situation de handicap est essentiel pour permettre plus d’inclusion, constate Luce Carevic, directrice de production et experte en accessibilité numérique chez Access42. Mais entre la théorie et la pratique, le fossé est grand.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': '« Extimité » : dévoiler son espace intime sur les réseaux sociaux, une affirmation de soi ?', 'image': 'https://img.lemde.fr/2023/11/21/0/5/5622/3748/110/73/60/0/a8670bc_1700565368053-000-33uh79j.jpg', 'description': 'S’exhiber sur Instagram ou TikTok peut revêtir des aspects thérapeutiques pour assumer sa personnalité face aux normes sociales. Tant que la quête d’authenticité ne tombe pas dans l’artificialité.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': '« The Legend of Zelda : Ocarina of Time » a 25 ans : quel héritage pour l’un des meilleurs jeux vidéo de tous les temps ?', 'image': 'https://img.lemde.fr/2023/11/21/93/87/498/332/110/73/60/0/3ca3ced_1700572483743-the-legend-of-zelda-ocarina-of-time-screenshot-097.jpg', 'description': 'Sorti le 21\xa0novembre\xa01998, ce premier opus en trois dimensions de la saga «\xa0Zelda\xa0» reste considéré comme une révolution majeure dans l’histoire du jeu vidéo. Nos journalistes ont échangé avec vous sur l’héritage de ce titre et les évolutions de la série.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'La société X Corp. intente une action en justice contre l’ONG Media Matters, pour avoir détourné des annonceurs', 'image': 'https://img.lemde.fr/2023/11/20/0/0/5500/3666/110/73/60/0/93f1e00_2023-11-20t232815z-1906522788-rc2b44abn4ak-rtrmadp-3-twitter-legal-media-matters.JPG', 'description': 'Apple, Comcast, NBCUniversal et IBM figurent parmi les marques qui ont interrompu la diffusion de leur publicité sur X la semaine dernière, après que Media Matters a signalé avoir trouvé des publicités affichées avec du contenu pronazi.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Handicap : l’accessibilité numérique, un tremplin pour l’emploi ?', 'image': 'https://img.lemde.fr/2023/11/17/0/0/2803/1869/110/73/60/0/9da13a4_1700221947948-plainpicture-p300m2490480.jpg', 'description': 'La Semaine européenne pour l’emploi des personnes handicapées, qui se tient jusqu’au 26\xa0novembre, se penche cette année sur les espoirs portés par la transition numérique. En France aujourd’hui, si 1,1 million de personnes handicapées travaillent, plus de 450\xa0000\xa0autres restent sans emploi.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'OpenAI : Microsoft tente de retourner la crise à son avantage', 'image': 'https://img.lemde.fr/2023/11/20/0/88/4269/2846/110/73/60/0/b6f3435_5927259-01-06.jpg', 'description': 'Le géant des logiciels, partenaire et actionnaire de l’entreprise créatrice de ChatGPT, se dit prêt à embaucher le cofondateur d’OpenAI limogé, Sam Altman, ou à le réhabiliter au sein de la start-up.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': '« Je découvre ce que c’est que d’être intégrée dans une équipe » : quand le numérique permet aux personnes handicapées d’accéder à l’emploi', 'image': 'https://img.lemde.fr/2023/11/16/0/214/3351/2234/110/73/60/0/b4aa75a_1700130299050-hanslucas-hl-sbouillaud-1952833.jpg', 'description': 'Rencontre avec trois personnes handicapées qui ont retrouvé du travail dans ce domaine ou grâce aux services qu’il offre.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Handicap : le numérique, un vivier d’emplois à exploiter', 'image': 'https://img.lemde.fr/2023/11/16/5/0/3500/2333/110/73/60/0/671bf0e_1700130043196-pink-lef0232005.jpg', 'description': 'Ce secteur dynamique a de nombreuses opportunités professionnelles à offrir. Des formations destinées aux personnes handicapées commencent à émerger.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Estelle Peyrard, d’APF France handicap : « L’intelligence artificielle ouvre des perspectives énormes pour aider les personnes en situation de handicap »', 'image': 'https://img.lemde.fr/2023/09/19/0/0/5616/3744/110/73/60/0/3895645_1695116257426-pns-2629494.jpg', 'description': '«\xa0Rebond, vivre avec le handicap\xa0» (2/5). Grâce aux outils numériques, les personnes en situation de handicap voient leur quotidien facilité.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': '« Sam Altman contre Ilya Sutskever : le schisme de l’intelligence artificielle est consommé »', 'image': 'https://img.lemde.fr/2023/11/20/0/88/4269/2846/110/73/60/0/b6f3435_5927259-01-06.jpg', 'description': 'Le dernier volet du feuilleton sis en Silicon Valley et relancé par le limogeage du fondateur d’OpenAI oppose les «\xa0catastrophistes\xa0» et les «\xa0technoptimistes\xa0», relate la correspondante du «\xa0Monde\xa0» à San Francisco, Corine Lesnes, dans sa chronique.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Estelle Peyrard, APF France Handicap : « Il y a encore beaucoup à faire pour que le numérique soit accessible »', 'image': 'https://img.lemde.fr/2023/09/19/0/0/5616/3744/110/73/60/0/3895645_1695116257426-pns-2629494.jpg', 'description': '«\xa0Rebond, vivre avec le handicap\xa0» (2/5). Avec l’arrivée du numérique, outils, logiciels et applications facilitent le quotidien des personnes en situation de handicap.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Vidéosurveillance algorithmique : Gérald Darmanin annonce le lancement d’une enquête administrative', 'image': 'https://img.lemde.fr/2023/11/20/0/0/4927/3285/110/73/60/0/80f2521_1700511533370-000-1b2226.jpg', 'description': 'Le ministre de l’intérieur a réagi lundi aux révélations du site «\xa0Disclose\xa0», qui affirme que la police française utilise un logiciel de vidéosurveillance dite «\xa0intelligente\xa0», dont certaines fonctionnalités pourraient être illégales.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': '« Une course a débuté autour de l’application de l’intelligence artificielle aux systèmes d’armements nucléaires »', 'image': 'https://img.lemde.fr/2020/10/26/0/0/5086/3390/110/73/60/0/c6d7c1e_616619953-pns-4686998.jpg', 'description': 'Melissa Parke, à la tête d’une ONG de lutte contre l’arme nucléaire, alerte dans une tribune au «\xa0Monde\xa0» sur les risques de déclenchement d’un conflit atomique du fait de l’utilisation de l’intelligence artificielle dans les processus de décision.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'En Europe, ces amendes record que les champions des nouvelles technologies tardent à payer', 'image': 'https://img.lemde.fr/2023/11/20/258/0/6161/4107/110/73/60/0/0bfa253_1700476541354-sipa-01021286-000001.jpg', 'description': 'Appel, pourvoi en cassation… Google, Apple, Amazon, Meta et TikTok rechignent à se soumettre aux sanctions infligées ces dernières années par les régulateurs européens.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'OpenAI : de hauts cadres menacent de partir si le conseil d’administration ne démissionne pas', 'image': 'https://img.lemde.fr/2023/11/20/10/0/4744/3162/110/73/60/0/85aeb7a_2023-11-20t113522z-207365381-rc2yg4amvqux-rtrmadp-3-openai-altman-meeting-ceo.JPG', 'description': 'Selon une lettre publiée lundi par plusieurs médias américains, ces responsables annoncent qu’ils pourraient rejoindre Microsoft, qui vient de recruter l’ancien PDG d’OpenAI, Sam Altman, débarqué vendredi par le conseil d’administration à la surprise générale.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Sam Altman rejoint Microsoft, le chaos à OpenAI secoue le secteur de l’IA', 'image': 'https://img.lemde.fr/2023/11/20/0/0/4999/3333/110/73/60/0/9d1b6ed_1700464584892-217110.jpg', 'description': 'L’entreprise créatrice de ChatGPT a nommé lundi un nouveau patron après avoir limogé vendredi son directeur général. Ces rebondissements révèlent des divergences sur les questions financières et l’amorce d’un schisme parmi les experts de l’IA.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Sam Altman, l’ancien dirigeant d’OpenAI, rebondit chez Microsoft', 'image': 'https://img.lemde.fr/2023/11/20/0/0/4999/3333/110/73/60/0/eb9ab65_2023-11-20t052208z-2018035747-rc2ne4a7u5gl-rtrmadp-3-openai-ceo-altman.JPG', 'description': 'La star de la Silicon Valley a été démise de ses fonctions vendredi par le conseil d’administration d’OpenAI, qui lui reprochait de ne pas avoir été «\xa0franc dans ses communications\xa0». La start-up d’intelligence artificielle a nommé à sa place l’ancien dirigeant de Switch Emmett Shear.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Jean Deydier, We Tech Care : « 13 millions de Français ne maîtrisent pas les outils numériques »', 'image': 'https://img.lemde.fr/2023/07/05/2/0/5256/3504/110/73/60/0/9cc4ad4_1688560995536-pns-720090820.jpg', 'description': '«\xa0Rebond, vivre avec le handicap\xa0» (1/5). En France, l’illectronisme touche 20\xa0% de la population, avec des conséquences importantes sur la vie quotidienne et l’emploi.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'E-sport : « Faker », star coréenne, sacré champion du monde de « League of Legends » pour la quatrième fois', 'image': 'https://img.lemde.fr/2023/11/19/0/0/3499/2333/110/73/60/0/6197855_1700408328728-966173.jpg', 'description': 'L’équipe sud-coréenne T1, menée par son chef de file, à la popularité équivalente à une vedette de K-Pop, a remporté un quatrième titre planétaire, dimanche, à Séoul.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Accessibilité numérique : « Le handicap est source d’innovation »', 'image': 'https://img.lemde.fr/2023/11/15/776/0/2180/1453/110/73/60/0/69012fb_1700034463874-philippe-trotin-pro2.jpeg', 'description': 'Selon Philippe Trotin, le directeur inclusion de Microsoft France, les entreprises ont tout intérêt à intensifier leurs efforts d’adaptation de leurs produits.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'OpenAI : l’ex-PDG Sam Altman, tout juste limogé, est invité en France par le ministre délégué chargé du numérique', 'image': 'https://img.lemde.fr/2023/11/18/1/0/5000/3333/110/73/60/0/c9fd061_2023-11-18t005925z-734458878-rc2oe4a0ab8n-rtrmadp-3-openai-ceo.JPG', 'description': 'Cette invitation survient au lendemain de l’annonce de la création à Paris d’un laboratoire baptisé «\xa0Kyutai\xa0» et doté de 300\xa0millions d’euros.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': '« Si l’intelligence artificielle générative présente des atouts pour les entreprises, il ne faut pas oublier qu’elle reste une boîte noire »', 'image': 'https://img.lemde.fr/2023/11/06/0/2871/3975/2650/110/73/60/0/e3d6ed8_1699262625673-pns-6621945.jpg', 'description': 'Le professeur de stratégie Jérôme Barthélemy rapporte, dans une tribune au «\xa0Monde\xa0», une expérience d’utilisation de ChatGPT éclairante quant à ses effets sur l’emploi.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Xavier Niel, Rodolphe Saadé et l’ex-PDG de Google lancent un laboratoire d’intelligence artificielle', 'image': 'https://img.lemde.fr/2023/11/14/0/0/6000/4000/110/73/60/0/920bb96_2023-11-14t105853z-970403949-rc28ms9emm77-rtrmadp-3-proximus-stake-niel.JPG', 'description': 'Les patrons d’Iliad, de CMA-CGM et de Schmidt Ventures ont annoncé vendredi la création de Kyutai, doté de 300\xa0millions d’euros et destiné à publier ses recherches en accès libre.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Pourquoi Sam Altman, star de l’intelligence artificielle, a été débarqué d’OpenAI', 'image': 'https://img.lemde.fr/2023/11/18/0/0/7327/4885/110/73/60/0/25c631c_1700294833186-000-344283g.jpeg', 'description': 'Vendredi, le conseil d’administration de l’entreprise créatrice de ChatGPT a limogé son directeur général et cofondateur. Un séisme dans le monde de la tech, et un révélateur de divergences internes quant au modèle de cette structure atypique.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Le limogeage de Sam Altman, le patron d’OpenAI et prodige de l’intelligence artificielle, sidère la Silicon Valley', 'image': 'https://img.lemde.fr/2023/11/17/15/0/4967/3311/110/73/60/0/1253855_2023-11-17t003839z-52459001-rc2oe4agnfqg-rtrmadp-3-apec-usa.JPG', 'description': 'Le cofondateur de l’entreprise à l’origine du programme ChatGPT n’a plus la «\xa0confiance\xa0» de son conseil d’administration, selon un communiqué diffusé vendredi par cette instance.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'ChatGPT : Sam Altman débarqué de la direction d’OpenAI', 'image': 'https://img.lemde.fr/2023/11/17/0/84/5280/3520/110/73/60/0/ec1bd01_5904655-01-06.jpg', 'description': 'Le conseil d’administration de l’entreprise, à l’origine de la plate-forme d’intelligence artificielle générative ChatGPT, a annoncé, vendredi, n’avoir «\xa0plus confiance dans la capacité\xa0» du PDG à diriger la société.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Désinformation : la Commission européenne suspend toutes ses publicités sur le réseau social X', 'image': 'https://img.lemde.fr/2023/11/17/0/0/4200/2800/110/73/60/0/6ab592a_5900255-01-06.jpg', 'description': 'La Commission a constaté une «\xa0hausse alarmante de la désinformation et des discours de haine\xa0» sur la plate-forme. Le géant américain IBM avait déjà annoncé la suspension de ses campagnes jeudi.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'L’Europe doit se défaire de son addiction aux logiciels espions', 'image': 'https://img.lemde.fr/2023/10/25/67/0/2000/1333/110/73/60/0/5ae5955_1698248550474-ransomware-illu-ordi-chevalde3-v2.png', 'description': 'Les efforts européens pour encadrer ces «\xa0armes numériques\xa0» restent timides, car les chancelleries veulent pouvoir continuer d’utiliser ces outils tout en prônant la non-prolifération.'}
# 2023-11-28 16:37:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/education/> (referer: https://www.lemonde.fr)
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': '« Scott Pilgrim » adapté sur Netflix : geek et nostalgique, un héros en avance sur son temps', 'image': 'https://img.lemde.fr/2023/11/16/0/150/1620/1080/110/73/60/0/fd66026_1700147493935-scott-pilgrim-takes-off-maintrailer-02.jpg', 'description': 'La bande dessinée du canadien Bryan\xa0Lee\xa0O’Malley et son adaptation en film avec Michael Cera sont devenues des références de la pop culture des années 2000. Netflix a décidé de rejouer la partition près de vingt ans plus tard.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Interopérabilité des messageries : Apple entend déployer le standard RCS sur ses iPhone', 'image': 'https://img.lemde.fr/2020/11/12/0/0/3000/2000/110/73/60/0/861c683_719803075-ip1202.jpg', 'description': 'Mise sous pression par l’UE, Apple adoptera\xa0en\xa02024\xa0le\xa0standard de\xa0messages courts enrichis (RCS) sur ses smartphones, en plus de\xa0sa\xa0solution maison, iMessages. Une décision qui ouvre la voie à\xa0plusieurs améliorations lorsque des SMS sont échangés entre les mobiles Android et\xa0iOS.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': '« Avec l’intelligence artificielle, des bouleversements importants se profilent dans la communication scientifique »', 'image': 'https://img.lemde.fr/2023/04/27/0/0/4253/2835/110/73/60/0/a40be1e_1682585330590-2d85c17-1680106845701-le-monde-tribune-def-01.jpg', 'description': 'Alors que les outils d’IA vont profondément modifier la manière dont les connaissances scientifiques sont acquises et partagées, le journaliste allemand Carsten Könneker plaide, dans une tribune au «\xa0Monde\xa0», pour une contribution obligatoire des entreprises d’IA au financement d’un journalisme de qualité.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Le gouvernement veut réécrire partiellement la loi sur les influenceurs', 'image': 'https://img.lemde.fr/2023/03/16/0/0/5899/3933/110/73/60/0/075de4b_1679004326077-jmug230316001.jpg', 'description': 'Un nouveau projet de loi vise à donner au gouvernement le pouvoir de corriger ce texte, critiqué par Bruxelles, moins de six mois après son adoption.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Meta et TikTok contestent le DMA devant la justice européenne', 'image': 'https://img.lemde.fr/2023/11/16/0/0/5100/3400/110/73/60/0/3df3186_58ee691ca7a74a54aaaa01fc6f685f33-0-a451049373b8490aadc4257e631484fa.jpg', 'description': 'Le Digital Markets Act établit une liste de plates-formes qui devront en mars se conformer à de nouvelles obligations. Meta considère que sa messagerie Messenger et sa place de marché Facebook Marketplace ne devraient pas être concernées.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'Intelligence artificielle : le règlement européen menacé par le blocage des négociations', 'image': 'https://img.lemde.fr/2023/11/17/0/90/2820/1880/110/73/60/0/6480dd1_1700207832062-204900.jpg', 'description': 'Au nom de ses start-up nationales, la France, soutenue par l’Allemagne et l’Italie, s’oppose à la réglementation des grands modèles d’IA si leur usage n’est pas «\xa0risqué\xa0». Elle est accusée de faire le jeu du lobbying de la tech.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
#
# {'title': 'YouTube peut-il avoir la peau des bloqueurs de publicités ?', 'image': 'https://img.lemde.fr/2021/04/06/0/0/3499/2333/110/73/60/0/e95ad5f_fw1-alphabet-google-youtube-0406-11.JPG', 'description': 'La plus grande plate-forme de vidéos au monde a commencé à interdire l’accès à ses contenus aux spectateurs qui utilisent un bloqueur de publicités.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Agnès Buzyn : « Qui peut penser qu’un hypothétique refus de soins décourage l’immigration clandestine ? »', 'image': 'https://img.lemde.fr/2023/11/28/0/0/4678/3118/110/73/60/0/7abdabb_1701183281750-000-33qz69b.jpg', 'description': 'Voulue par le Sénat, la transformation de l’aide médicale d’Etat revient à faire peser la lutte contre l’immigration clandestine sur le budget des hôpitaux et sa responsabilité sur les médecins hospitaliers, en espérant qu’ils oublieront le serment d’Hippocrate, déplore, dans une tribune au «\xa0Monde\xa0», l’ancienne ministre de la santé.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Tabagisme : « Il faut avancer sur la voie de la réduction des risques »', 'image': 'https://img.lemde.fr/2023/04/27/0/0/4253/2835/110/73/60/0/a40be1e_1682585330590-2d85c17-1680106845701-le-monde-tribune-def-01.jpg', 'description': 'Alors que les politiques publiques semblent perdre en efficacité avec le temps, des spécialistes des addictions appellent, dans une tribune au «\xa0Monde\xa0», à tenter une nouvelle stratégie d’accompagnement des fumeurs.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Narcotrafic : devant le Sénat, le portrait d’une France où « aucun territoire n’est épargné »', 'image': 'https://img.lemde.fr/2023/11/28/0/0/5722/3814/110/73/60/0/3b1a4e5_1701167982825-953661.jpg', 'description': 'Les premières auditions de la commission d’enquête sur l’impact du narcotrafic ont eu lieu lundi. Les faits d’homicides ou de tentatives d’homicides liés aux trafics de stupéfiants ont augmenté de 57\xa0% depuis le début de l’année 2023, par rapport à 2022.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Hausse modérée du prix des cigarettes, plus de lieux publics sans tabac, interdiction des puffs : le gouvernement présente son plan contre le tabagisme', 'image': 'https://img.lemde.fr/2023/11/17/0/0/5860/3906/110/73/60/0/5b10d1d_1700234764531-940190.jpg', 'description': 'L’objectif est d’atteindre un prix du paquet de cigarettes à 13\xa0euros à l’horizon 2027, avec une étape à 12\xa0euros en\xa02025, a annoncé le ministre de la santé. Les «\xa0espaces sans tabac\xa0» vont être généralisés aux plages, forêts et parcs publics, ainsi qu’aux abords des établissements scolaires.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'Les Assises de la pédiatrie, attendues depuis un an, désormais annoncées pour janvier', 'image': 'https://img.lemde.fr/2023/11/27/0/0/4644/3096/110/73/60/0/cda3db3_1701067752039-000-336c2ep.jpg', 'description': 'Une rencontre préparatoire a eu lieu avec le ministre de la santé, Aurélien Rousseau, vendredi 24 novembre. La pression monte de nouveau dans les hôpitaux.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': '« Que sait-on du travail ? » : des pistes de soutenabilité pour travailler à tout âge', 'image': 'https://img.lemde.fr/2023/11/24/0/139/832/555/110/73/60/0/450c6ec_1700845387440-media-appel-soutenabilite-travail-3x.png', 'description': 'Près d’un actif sur deux de 55\xa0à 61\xa0ans, ni à la retraite ni en emploi, est dans cette situation pour raison de santé. Dans le cadre du projet de médiation scientifique «\xa0Que sait-on du travail\xa0? \xa0», lancé au mois de mai par le Laboratoire interdisciplinaire d’évaluation des politiques publiques (Liepp) de Sciences Po, et diffusé en collaboration avec «\xa0Le Monde\xa0», l’ergonome Catherine Delgoulet développe une nouvelle approche de la relation entre santé et travail.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# {'title': 'A l’hôpital Necker-Enfants malades, temple de l’excellence de la pédiatrie à l’épreuve de la crise', 'image': 'https://img.lemde.fr/2023/11/26/0/0/4999/3333/110/73/60/0/8e51232_1701026946389-ad008necker-dsc02502.jpg', 'description': 'Dans cet établissement pédiatrique de l’Assistance publique-Hôpitaux de Paris où exercent les meilleurs spécialistes du pays, des lits sont fermés, comme ailleurs, par manque de personnels. Avec parfois des conséquences dramatiques, quand des opérations doivent être reportées.'}
# 2023-11-28 16:37:26 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/sante/>
#
# ...
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'En Israël, le rêve de pionniers des Weissmann', 'image': 'https://img.lemde.fr/2023/11/21/276/0/2598/1732/110/73/60/0/411175d_313817-3347580.jpg', 'description': 'Le 7\xa0octobre, les vingt-trois membres de la famille Weissmann ont échappé au massacre du Hamas dans leur village agricole de Netiv Haasara. Depuis, ils ont trouvé refuge près de Tel-Aviv. Un nouvel exil pour ce clan fondé par deux enfants de déportés venus de France à la fin des années 1950\xa0cultiver une terre à l’abri des persécutions.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'La Palestine, patrie introuvable de la famille Redwan', 'image': 'https://img.lemde.fr/2023/11/21/79/0/1500/1000/110/73/60/0/e2eec39_313825-3348010.jpg', 'description': 'Depuis Ramallah, en Cisjordanie, où elles poursuivent leurs études, Sewar et Zaina portent avec leur mère, Reem, le deuil de leurs grands-parents, tués dans un bombardement israélien, le 10\xa0octobre, à Gaza. Chassés de leur foyer en\xa01948, installés un temps en Arabie saoudite, leurs aïeuls n’ont jamais cessé de cultiver leur identité palestinienne.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'L’espoir retrouvé de la famille de Marah Bakir, sur la liste des prisonniers palestiniens devant être libérés', 'image': 'https://img.lemde.fr/2023/11/23/0/0/6000/4000/110/73/60/0/eea30be_1700701445008-asurp-israel-108330.jpg', 'description': 'La jeune femme de 23\xa0ans est emprisonnée en Israël depuis huit ans. Son nom fait partie de la liste des 33\xa0premiers détenus devant être échangés contre des otages israéliens, selon l’accord scellé entre le Hamas et l’Etat hébreu.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Le Qatar, acteur-clé dans les discussions entre Israël et le Hamas', 'image': 'https://img.lemde.fr/2023/11/22/0/0/3193/2129/110/73/60/0/e607779_1700671913337-000-33zu7qj.jpg', 'description': 'L’émirat s’est imposé depuis une dizaine d’années comme le médiateur privilégié entre l’Etat hébreu et le mouvement islamiste, qu’il finance en partie dans la bande de Gaza avec l’accord des autorités israéliennes.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : ce que l’on sait de l’accord conclu pour la libération d’otages', 'image': 'https://img.lemde.fr/2023/11/22/0/0/6000/4000/110/73/60/0/5e763a2_1700618223301-asurp-israel-107136.jpg', 'description': 'Les otages concernés par l’accord sont des femmes et des enfants enlevés par le Hamas lors de l’attaque du 7\xa0octobre. Les premières libérations\xa0et le début de la trêve de quatre jours sont intervenus vendredi.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : à Rafah, des rescapés de Gaza sous le choc et des tonnes d’aide humanitaire en attente', 'image': 'https://img.lemde.fr/2023/11/22/0/0/5961/3974/110/73/60/0/cb25a43_5942271-01-06.jpg', 'description': 'Depuis le 21\xa0octobre, près de 9\xa0000\xa0personnes ont été évacuées par le poste-frontière avec l’Egypte, unique échappatoire de l’enclave palestinienne.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'A São Paulo, la concorde entre juifs et musulmans ébranlée', 'image': 'https://img.lemde.fr/2023/11/21/0/0/1500/1000/110/73/60/0/830b0a0_313932-3348232.jpg', 'description': 'Le modèle brésilien de coexistence pacifique entre les religions est mis à mal par la guerre entre le Hamas et Israël. Face à l’essor des actes antisémites et islamophobes, les clercs tentent de préserver le dialogue interreligieux.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : tout comprendre à l’accord sur les otages', 'image': 'https://img.lemde.fr/2023/11/22/0/0/1800/1200/110/73/60/0/9653e6f_1700646514333-photo-accord-otage3.png', 'description': 'Après des semaines de négociations, le gouvernement israélien et le mouvement islamiste ont conclu, mercredi, un accord prévoyant la libération de 50\xa0otages en échange d’une trêve limitée et de prisonniers palestiniens. Quelles sont les modalités de ce texte\xa0? Comment les deux camps sont-ils parvenus à cet accord\xa0? Réponses dans ce podcast avec Benjamin Barthe, journaliste au «\xa0Monde\xa0».'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'A Tel-Aviv, les espoirs et les craintes des familles d’otages du Hamas dans l’attente des premières libérations', 'image': 'https://img.lemde.fr/2023/11/22/0/0/6000/4000/110/73/60/0/02cc707_1700666626393-asurp-israel-108198.jpg', 'description': 'Le chef du Conseil national de sécurité israélien, Tzachi Hanegbi, a déclaré que les libérations n’interviendraient «\xa0pas avant vendredi\xa0» et que les négociations «\xa0se\xa0poursuivaient sans cesse\xa0».'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Les Etats-Unis ont intercepté des drones d’attaque lancés depuis le Yémen', 'image': 'https://img.lemde.fr/2021/04/03/0/3/3493/2329/110/73/60/0/fbe6a46_navy-ho-001-egypt-suezcanal-ship-us-navy-0403-11.JPG', 'description': '«\xa0Le “USS Thomas Hudner” a tiré et détruit de nombreux drones d’attaque lancés depuis la région du Yémen contrôlée par les houthistes\xa0» a expliqué le commandement militaire américain au Moyen-Orient.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'A Paris, une instagrameuse jugée pour apologie du terrorisme', 'image': 'https://img.lemde.fr/2023/11/22/0/0/5229/3486/110/73/60/0/360464d_1700667986630-000-33yl7gq.jpg', 'description': 'Dans deux vidéos devenues virales, Warda\xa0A. avait ironisé sur la mort d’un bébé israélien et affirmé que le Hamas «\xa0n’est pas un mouvement terroriste\xa0». Le procureur a requis dix mois d’emprisonnement avec sursis.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : quatre Libanais, dont deux journalistes, tués dans des frappes israéliennes', 'image': 'https://img.lemde.fr/2023/11/22/0/85/5638/3759/110/73/60/0/bc0d068_1700641183480-220460.jpg', 'description': 'Depuis le 7\xa0octobre, cinquante-trois professionnels des médias ont été tués. Parmi eux figurent trois Libanais, quatre Israéliens et quarante-six Palestiniens.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : récit des cinq semaines de discussions qui ont abouti à un accord pour des premières libérations d’otages', 'image': 'https://img.lemde.fr/2023/11/22/0/0/6000/4000/110/73/60/0/5e763a2_1700618223301-asurp-israel-107136.jpg', 'description': 'Cinquante femmes et enfants détenus par le Hamas à Gaza devraient être libérés en échange de cent cinquante prisonniers palestiniens et d’une trêve limitée.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Les BRICS+ ne parviennent pas à s’accorder sur la guerre à Gaza face à l’Occident', 'image': 'https://img.lemde.fr/2023/11/22/0/46/3039/2026/110/73/60/0/4082b6e_1700640604803-921861.jpg', 'description': 'Aucune déclaration commune n’est sortie du sommet par visioconférence des dirigeants du forum de pays émergents, qui s’est contenté d’appeler à une «\xa0trêve humanitaire immédiate\xa0» conduisant à un cessez-le-feu et à «\xa0la protection des civils et la fourniture d’aide humanitaire\xa0» dans l’enclave.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'A Tel-Aviv, l’insupportable attente des familles d’otages', 'image': 'https://img.lemde.fr/2023/11/22/0/0/6000/4000/110/73/60/0/dff4a1e_1700618171413-asurp-israel-107086.jpg', 'description': 'Hadas Kalderon, mère de deux enfants enlevés par le Hamas le 7\xa0octobre, ignore s’ils feront partie des otages qui seront libérés dans le cadre de l’accord voté mercredi par le gouvernement de Benyamin Nétanyahou.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Joe Biden et Israël : une amitié à l’épreuve du feu', 'image': 'https://img.lemde.fr/2023/11/21/0/0/1800/1200/110/73/60/0/f8a1c2d_1700564532431-biden-et-israel.png', 'description': 'Depuis le 7\xa0octobre, le président américain a fait preuve d’un soutien indéfectible à Israël. Une position critiquée depuis que l’Etat hébreu bombarde sans relâche la bande de Gaza au prix de nombreuses vies civiles. Piotr Smolar est le correspondant du «\xa0Monde\xa0» à Washington, il explique la position de Joe Biden et ses répercussions politiques possibles.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : la question des prisonniers palestiniens au cœur du conflit', 'image': 'https://img.lemde.fr/2023/11/19/387/0/4628/3085/110/73/60/0/fb3dea9_1700389582890-13112023-l3140238.jpg', 'description': 'L’accord validé, dans la nuit de mardi à mercredi, par Israël impliquerait la libération de 150\xa0prisonniers palestiniens en échange de celle de 50\xa0femmes et enfants otages du Hamas. Au total, 6\xa0700\xa0Palestiniens seraient en prison dans l’Etat hébreu, plusieurs d’entre eux y sont morts depuis l’attaque du 7\xa0octobre.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'L’Union européenne poursuit son aide au développement en faveur de la Palestine', 'image': 'https://img.lemde.fr/2023/11/21/0/0/5472/3648/110/73/60/0/91576ca_1700590530398-000-344a3em.jpg', 'description': 'La Commission européenne a donné son aval après avoir procédé, depuis le 7\xa0octobre, à une analyse du mécanisme d’aide au développement. Elle estime qu’aucun élément n’indique que des fonds de l’UE auraient bénéficié au Hamas.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Au Maroc, les groupes Carrefour et McDonald’s ciblés par un boycott sur fond de guerre à Gaza', 'image': 'https://img.lemde.fr/2023/11/21/0/0/1024/682/110/73/60/0/b355ed2_1700575647391-000-app2003052684484.jpg', 'description': 'Les deux enseignes sont accusées de soutenir l’armée israélienne, notamment par des dons alimentaires, ou de commercer dans les colonies.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : suspendues aux négociations, les familles d’otages entre angoisse et colère', 'image': 'https://img.lemde.fr/2023/11/21/0/126/5874/3916/110/73/60/0/429c885_1700555544965-asurp-israel-105335.jpg', 'description': 'Les tractations pour récupérer une cinquantaine d’otages kidnappés par le Hamas en échange d’une trêve de quelques jours et de la libération de prisonniers palestiniens détenus en Israël seraient sur le point d’aboutir. Leurs proches, comme la Franco-Israélienne Hadas Kalderon, attendent des nouvelles, rassemblés sur une place de Tel-Aviv.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : « Il nous faut désormais résister au vertige et à l’ivresse de la vengeance »', 'image': 'https://img.lemde.fr/2023/11/20/0/190/3189/2126/110/73/60/0/38bae52_5926154-01-06.jpg', 'description': 'L’ancien ministre chargé de l’eau de l’Autorité palestinienne Shaddad Attili répond, dans une tribune au «\xa0Monde\xa0», au président du Forum international pour la paix et la réconciliation au Moyen-Orient, Ofer Bronchtein, auteur d’une «\xa0lettre à un ami palestinien\xa0» publiée le 23\xa0octobre dans laquelle il déplorait l’absence de compassion de certains militants pacifistes à l’égard des victimes israéliennes du Hamas.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Sommet des BRICS : l’Afrique du Sud accuse Israël de « crimes de guerre » et « génocide » à Gaza', 'image': 'https://img.lemde.fr/2023/11/21/0/0/3868/2578/110/73/60/0/c2d0783_1700577056273-000-344839t.jpg', 'description': 'Le président Ramaphosa demande, en plus d’un cessez-le-feu, le déploiement d’une force rapide de l’ONU pour «\xa0surveiller la cessation des hostilités\xa0» et «\xa0protéger les civils\xa0».'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Guerre Israël-Hamas : à Paris, le drame personnel de l’ambassadrice palestinienne, Hala Abou Hassira', 'image': 'https://img.lemde.fr/2023/11/21/507/0/7613/5075/110/73/60/0/df45b2e_1700555810159-ll-hala-abou-hassira-02.jpg', 'description': 'Native de Gaza, la représentante en France de l’Autorité palestinienne depuis deux ans a perdu soixante membres de sa famille dans les bombardements israéliens.'}
# 2023-11-28 16:37:27 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/attaque-du-hamas-contre-israel/>
#
# {'title': 'Vidéo : les rebelles houthistes du Yémen se sont emparés d’un navire en mer Rouge', 'image': 'https://img.lemde.fr/2023/11/21/0/0/1620/1080/110/73/60/0/daa324e_ae4d7f9f6cad407da609d926fe2c14cc-0-160067ee41d849bbad582ec10ba3da44.jpg', 'description': 'Les houthistes ont affirmé avoir saisi ce navire, propriété d’un homme d’affaires israélien, en représailles à la guerre menée par l’Etat hébreu contre le Hamas dans la bande de Gaza.'}
# 2023-11-28 16:37:27 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-11-28 16:37:27 [scrapy.extensions.feedexport] INFO: Stored csv feed (1522 items) in: ../data/lbc.csv
# 2023-11-28 16:37:27 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 12252,
#  'downloader/request_count': 31,
#  'downloader/request_method_count/GET': 31,
#  'downloader/response_bytes': 2540812,
#  'downloader/response_count': 31,
#  'downloader/response_status_count/200': 31,
#  'elapsed_time_seconds': 1.630569,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 11, 28, 15, 37, 27, 143344, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 10103384,
#  'httpcompression/response_count': 31,
#  'item_scraped_count': 1522,
#  'log_count/DEBUG': 1554,
#  'log_count/ERROR': 3,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'request_depth_max': 1,
#  'response_received_count': 31,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 30,
#  'scheduler/dequeued/memory': 30,
#  'scheduler/enqueued': 30,
#  'scheduler/enqueued/memory': 30,
#  'spider_exceptions/IndexError': 3,
#  'start_time': datetime.datetime(2023, 11, 28, 15, 37, 25, 512775, tzinfo=datetime.timezone.utc)}
# 2023-11-28 16:37:27 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ## Votre premier Item
#
# La classe `Item` permet de structurer les données que l'on souhaite
# récupérer sous la forme d'un modèle. Les items doivent être définis dans
# le fichier `items.py` créé par la commande `scrapy startproject`. Les
# `Item` héritent de la class `scrapy.Item`.
#
# On veut structurer les données avec deux champs : le titre et le prix de
# l'annonce. Scrapy utilise une classe `scrapy.Field` permettant de
# 'déclarer' ces champs. Dans notre cas :

# %%
# %load newscrawler/newscrawler/items.py

# Define here the models for your scraped items
#
# See documentation in:
# https://docs.scrapy.org/en/latest/topics/items.html

import scrapy

class ArticleItem(scrapy.Item):
    title = scrapy.Field()
    image = scrapy.Field()
    description = scrapy.Field()

# %% [markdown]
# Utiliser la classe `scrapy.Item` plutôt qu'un simple dictionnaire permet
# plus de contrôle sur la structure des données. En effet, on ne peut
# insérer dans les items que des données avec des clés 'déclarées'. Ce qui
# assure une plus grande cohérence au sein d'un projet.
#
# On peut instancier un item de plusieurs façons :

# %%
article_item = ArticleItem(title="Gilets Jaunes", image=None, description="Un samedi de manifestations")

# %%
print(article_item)
# Out:
# {'description': 'Un samedi de manifestations',
#  'image': None,
#  'title': 'Gilets Jaunes'}

# %%
article_item = ArticleItem()
article_item["title"] = 'Gilets Jaunes'
article_item["description"] = 'Un samedi de manifestations'

# %%
print(article_item)
# Out:
# {'description': 'Un samedi de manifestations', 'title': 'Gilets Jaunes'}

# %% [markdown]
# La définition d'un item permet de palier toutes les erreurs de typo dans
# les champs.

# %%
article_item = ArticleItem()
article_item["titelkjwnxvmnscbvmknxc"] = 'Gilets Jaunes'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-f12882ec7441> in <module>
#       1 article_item = ArticleItem()
# ----> 2 article_item["titelkjwnxvmnscbvmknxc"] = 'Gilets Jaunes'
#
# //anaconda3/lib/python3.7/site-packages/scrapy/item.py in __setitem__(self, key, value)
#      96         else:
#      97             raise KeyError("%s does not support field: %s" %
# ---> 98                 (self.__class__.__name__, key))
#      99
#     100     def __delitem__(self, key):
#
# KeyError: 'ArticleItem does not support field: titelkjwnxvmnscbvmknxc'

# %% [markdown]
# Les items héritent des dictionnaires Python, et possèdent donc toutes
# les méthodes de ceux-ci:

# %%
article_item = ArticleItem(title="Gilets Jaunes")
print(article_item["title"]) # Méthode __getitem__()
print(article_item.get("description", "no description provided")) # Méthode get()
# Out:
# Gilets Jaunes
# no description provided

# %% [markdown]
# On peut transformer un `Item` en dictionnaire très facilement, en le
# passant au constructeur:

# %%
article_item = ArticleItem(title="Drone DJI")
print(type(article_item))
dict_item = dict(article_item)
print(type(dict_item))
print(dict_item)
# Out:
# <class '__main__.ArticleItem'>
# <class 'dict'>
# {'title': 'Drone DJI'}

# %% [markdown]
# On intègre maintenant cet item dans notre spider.

# %%
# -*- coding: utf-8 -*-
import scrapy
from scrapy import Request
from ..items import ArticleItem
class LemondeSpider(scrapy.Spider):
    name = "lemonde"
    allowed_domains = ["www.lemonde.fr"]
    start_urls = ['https://www.lemonde.fr']

    def parse(self, response):
        title = response.css('title::text').extract_first()
        all_links = {
            name:response.urljoin(url) for name, url in zip(
            response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
            response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
        }
        for link in all_links.values():
            yield Request(link, callback=self.parse_category)

    def parse_category(self, response):
        for article in response.css(".fleuve")[0].css("article"):
            title = self.clean_spaces(article.css("h3 a::text").extract_first())
            image = article.css("img::attr(data-src)").extract_first()
            description = article.css(".txt3::text").extract_first()

            yield ArticleItem(
                title=title,
                image=image,
                description=description
            )

    def clean_spaces(self, string):
        if string:
            return " ".join(string.split())

# %% [markdown]
# On voit bien que le générateur retourne maintenant un `Item`.

# %% [markdown]
# ### Exercice :
#
# Relancer la spider pour vérifier le bon déroulement de l'extraction.

# %%
# !cd newscrawler/ && scrapy crawl lemondev4
# Out:
# 2019-11-25 13:25:01 [scrapy.utils.log] INFO: Scrapy 1.8.0 started (bot: newscrawler)
# 2019-11-25 13:25:01 [scrapy.utils.log] INFO: Versions: lxml 4.4.1.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.10.0, Python 3.7.3 (default, Mar 27 2019, 16:54:48) - [Clang 4.0.1 (tags/RELEASE_401/final)], pyOpenSSL 19.0.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Darwin-18.6.0-x86_64-i386-64bit
# 2019-11-25 13:25:01 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'newscrawler', 'NEWSPIDER_MODULE': 'newscrawler.spiders', 'ROBOTSTXT_OBEY': True, 'SPIDER_MODULES': ['newscrawler.spiders']}
# 2019-11-25 13:25:01 [scrapy.extensions.telnet] INFO: Telnet Password: 7be3f6903eae0090
# 2019-11-25 13:25:01 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2019-11-25 13:25:01 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2019-11-25 13:25:01 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2019-11-25 13:25:01 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2019-11-25 13:25:01 [scrapy.core.engine] INFO: Spider opened
# 2019-11-25 13:25:01 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2019-11-25 13:25:01 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2019-11-25 13:25:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2019-11-25 13:25:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: None)
# 2019-11-25 13:25:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/disparitions/> (referer: https://www.lemonde.fr)
# 2019-11-25 13:25:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/afrique/> (referer: https://www.lemonde.fr)
# 2019-11-25 13:25:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/big-browser/> (referer: https://www.lemonde.fr)
# 2019-11-25 13:25:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/pixels/> (referer: https://www.lemonde.fr)
# 2019-11-25 13:25:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/podcasts/> (referer: https://www.lemonde.fr)
# 2019-11-25 13:25:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/actualite-medias/> (referer: https://www.lemonde.fr)
# 2019-11-25 13:25:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/campus/> (referer: https://www.lemonde.fr)
# 2019-11-25 13:25:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sante/> (referer: https://www.lemonde.fr)
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/25/305/0/2587/1723/110/74/60/0/7027259_3UefBJe3ffQFu9QjgbKBF8Qq.jpg',
#  'title': 'Mort de Norodom Bopha Devi, danseuse étoile cambodgienne'}
# 2019-11-25 13:25:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/les-decodeurs/> (referer: https://www.lemonde.fr)
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/25/551/2692/2491/1660/110/74/60/0/c21be44_Gy7zL8DPPKRDu5OcihQzZo5j.jpg',
#  'title': 'Jean Morel, un des derniers survivants du commando Kieffer, est '
#           'mort'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/0/106/4563/3042/110/74/60/0/c20be21_5082997-01-06.jpg',
#  'title': 'Jake Burton, le « père du snowboard », est mort'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/21/984/933/1063/708/110/74/60/0/db13068_zyipGZzsNQ8sb5dbG8eHzcIV.jpg',
#  'title': 'Colette Senghor, épouse et muse de l’ancien président du Sénégal, '
#           'est morte'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/20/350/0/630/420/110/74/60/0/97f4e8d_eLByjf5jTPmjPzuZkqHGEOlT.jpg',
#  'title': 'La mort du traducteur Bernard Kreiss'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/17/0/20/2859/1906/110/74/60/0/a799683_UJBMhHUUM3UMnAFh08d2z_L-.jpg',
#  'title': 'Mort de Fred Mella, soliste du groupe vocal très populaire les '
#           'Compagnons de la chanson'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/16/365/0/1634/1088/110/74/60/0/9414729_5048231-01-06.jpg',
#  'title': 'Mort d’Eric Morena, l’interprète de « Oh ! mon bateau »'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/13/0/0/4896/3264/110/74/60/0/a8aaa5e_5029634-01-06.jpg',
#  'title': 'Le créateur Josephus Thimister, ancien directeur artistique de '
#           'Balenciaga, est mort'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/13/682/1093/3002/2001/110/74/60/0/33a7a47_mHlu5llnzmlQL974XOVtqB0J.jpg',
#  'title': 'Mort de Raymond Poulidor : retour en images sur la carrière d’une '
#           'légende du vélo'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/13/74/0/4050/2700/110/74/60/0/6069075_5025498-01-06.jpg',
#  'title': 'La petite reine pleure la mort de Raymond Poulidor'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/17/193/0/1609/1071/110/74/60/0/c6d71c0_HUR_a41Q__BhwAqAZWwGVNdi.jpg',
#  'title': 'Raymond Poulidor : « Je me demande si un jour le cyclisme va '
#           'redevenir sérieux »'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/13/682/1093/3002/2001/110/74/60/0/33a7a47_mHlu5llnzmlQL974XOVtqB0J.jpg',
#  'title': 'Raymond Poulidor, pas qu’un éternel second'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/14/329/12/1509/1005/110/74/60/0/8ff576a_b-caWTVia533ycASNpJtk5aN.jpg',
#  'title': 'L’ancien champion cycliste Raymond Poulidor est mort'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/12/136/0/2188/1457/110/74/60/0/b16318e_5019774-01-06.jpg',
#  'title': '« Jacky le Mat », ancienne figure de la pègre marseillaise, est '
#           'mort à 89 ans'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/11/19/0/3000/2000/110/74/60/0/5b11ab8_diERNywxSdDMVYtSRD3SrT2T.jpg',
#  'title': 'La mort d’Ernest Gaines, écrivain américain'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2018/07/19/164/0/3000/2000/110/74/60/0/6ee0b94_5bd22fe140ef446db57ce7e8a6381804-5bd22fe140ef446db57ce7e8a6381804-0.jpg',
#  'title': 'Mort de Robert Freeman, photographe emblématique des Beatles'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/08/627/687/2964/1976/110/74/60/0/d40916f__-cP6CVM3LNaXlcjWAnGtWZB.jpg',
#  'title': 'Témoignage : « La vie de Lucette Destouches fut un roman »'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/08/437/0/4961/3296/110/74/60/0/d40916f__-cP6CVM3LNaXlcjWAnGtWZB.jpg',
#  'title': 'Lucette Destouches, veuve de Céline, est morte'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2018/06/06/240/825/2624/1749/110/74/60/0/698430c_5700558-01-06.jpg',
#  'title': 'Mort de Gilles Bertin, braqueur repenti et punk des années 1980'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/05/0/0/4500/3000/110/74/60/0/3807ecd_77-lxBWLV7vYxC_wOMMEJNiP.jpg',
#  'title': 'La mort du professeur Louis Lareng, fondateur du SAMU'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/05/0/0/3888/2592/110/74/60/0/57464b9_IL5O7P5x9f-KF3ttcXLVffy_.jpg',
#  'title': 'La mort d’Yvette Lundy, figure de la Résistance et déportée'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/05/0/16/3609/2406/110/74/60/0/20f0d84_CbVa686NcPxL61fiTG8xCC5z.jpg',
#  'title': 'Bernard Féron, ancien journaliste au « Monde », est mort'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/04/0/0/3519/2346/110/74/60/0/04286be_ybnT-Yv3sC2PBkiO_TnkOacs.jpg',
#  'title': 'L’actrice et chanteuse populaire Marie Laforêt est morte'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/03/246/2849/2334/1556/110/74/60/0/dff191a_5965804-01-06.jpg',
#  'title': 'Yvette Lundy, figure de la Résistance, est morte'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/03/0/0/4500/3000/110/74/60/0/8d7f914_5965189-01-06.jpg',
#  'title': 'Louis Lareng, le fondateur du SAMU, est mort'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/03/703/768/5001/3334/110/74/60/0/4a95bb1_5964167-01-06.jpg',
#  'title': 'Les 6 chansons qui ont marqué la carrière de Marie Laforêt'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/04/0/12/6201/4134/110/74/60/0/5fc9758_i6kkHXpRMIH6uc2I5Lzx46ql.jpg',
#  'title': 'Marie Laforêt, la « Fille aux yeux d’or », est morte'}
# 2019-11-25 13:25:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/0/0/5516/3677/110/74/60/0/b265092__RNlNjnlYxywasKTKx3UpfQj.jpg',
#  'title': 'Ghana : le quartier de Bokum, fabrique de boxeurs'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2015/11/16/0/0/3500/2333/110/74/60/0/bf1793c_PXP33_HEALTH-TOILETS-WIDERIMAGE_1116_11.JPG',
#  'title': 'Journée mondiale des toilettes : un nouveau revêtement pour '
#           'économiser l’eau ?'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/31/11/0/3510/2340/110/74/60/0/34adbf9_njEaOmByaAtEyHG1XpLcHsju.jpg',
#  'title': 'Robert Evans, producteur de « Rosemary’s Baby » et du « Parrain », '
#           'est mort'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/30/34/137/1910/1273/110/74/60/0/21808d8_gze6bpc-1emvGfiE_9h4FwLk.jpg',
#  'title': 'Sadako Ogata, ancienne haut-commissaire de l’ONU pour les réfugiés, '
#           'est morte'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/29/0/3/4249/2833/110/74/60/0/aaaf670__vBs3rBnLPGSPpJuTVW70RNA.jpg',
#  'title': '« On ne saura jamais à quoi les Mémoires de Prince auraient '
#           'ressemblé s’il avait été en vie »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/29/516/0/1983/1321/110/74/60/0/429f475_dIBPuL-T2YAwLgyoVFgr8EqB.jpg',
#  'title': 'La mort de Vladimir Boukovski, dissident soviétique et mémoire de '
#           'la répression'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/28/455/0/3023/2015/110/74/60/0/f064fea_6dc3KpMP6fVhHxXflVFCOkLt.jpg',
#  'title': 'La mort de l’essayiste Carlo Strenger'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/28/0/4/2191/1461/110/74/60/0/63df133_5923480-01-06.jpg',
#  'title': 'Vladimir Boukovski, plus célèbre prisonnier politique soviétique de '
#           'son époque, est mort'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/27/43/0/2104/1402/110/74/60/0/25b8020_5916136-01-06.jpg',
#  'title': 'Mort de la comédienne Pascale Roberts, figure de « Plus belle la '
#           'vie »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/24/0/0/4896/3264/110/74/60/0/ca6a21c_KpmXH3-LFjUUpQas4sr2YyLI.jpg',
#  'title': 'L’historien Santos Julia, spécialiste de l’Espagne contemporaine, '
#           'est mort'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/23/560/0/4000/2661/110/74/60/0/80ce384_Lv-vVITQjHChdtmt4B9pGBQh.jpg',
#  'title': '« Magicien de la lumière », le designer Ingo Maurer est mort'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/23/0/0/4999/3333/110/74/60/0/fc17a6d_HFPz1BVjOMSePWqrskuuq7ZR.jpg',
#  'title': 'Marieke Vervoort, athlète paralympique souffrant d’une maladie '
#           'incurable, est morte par euthanasie'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/22/0/0/3543/2362/110/74/60/0/8c009de_YkQiQMnlqWPRdwhdXrHCBIe6.jpg',
#  'title': 'Mort de Nick Tosches, l’écrivain qui fit du rock’n’roll un roman'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/21/279/0/970/646/110/74/60/0/5b230f9_bnxk3O6Vdwl00H6s2s0L_nrp.jpg',
#  'title': 'L’ancien président de Médecins du monde, le docteur Jacques Lebas, '
#           'est mort'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/21/0/0/5184/3456/110/74/60/0/13afebe_YYYejI27o1HRWZVMXpq4azmM.jpg',
#  'title': 'La mort de l’artiste contemporain Huang Yong Ping'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/21/435/0/1178/779/110/74/60/0/8e15417_-PtmmjlKz1UuLQ8tVyHGSOSO.jpg',
#  'title': 'Biographe et historien du rock, l’écrivain américain Nick Tosches '
#           'est mort à 69 ans'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/19/686/0/1842/1228/110/74/60/0/1841577__0tUqRB49Yrez2VD-tgLxfoX.jpg',
#  'title': 'Alicia Alonso, créatrice du style classique cubain, est morte'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/19/26/0/5239/3492/110/74/60/0/f121387_mbLgVXoFrfvfljG9WsgKrWwW.jpg',
#  'title': 'Mort de l’architecte Pierre Parat, concepteur du Palais omnisports '
#           'de Paris-Bercy'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/17/10/0/499/332/110/74/60/0/876a9ff_KzW0yTl2TehPCQjFfSCJfHzj.jpg',
#  'title': 'Jacques Chirac et les timbres, une vieille histoire'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/16/519/0/1556/1036/110/74/60/0/b6d924a_IUJManQnQzF1qTOA33611nBt.jpg',
#  'title': 'Harold Bloom, universitaire et critique littéraire américain, est '
#           'mort'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/17/70/5/1134/756/110/74/60/0/fcc44e1_OY7MMRiUKYowVVqWCNiHaBjx.jpg',
#  'title': 'Pierre Kalfon, ancien correspondant du « Monde » au Chili, est mort'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/16/15/0/6720/4474/110/74/60/0/164488a_Ne4xg8Cnef_XpKrR1QM777A9.jpg',
#  'title': '« Giscard et Balladur peuvent mourir, ils ont enterré leur pire '
#           'ennemi » : dans les coulisses des obsèques de Jacques Chirac'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/16/164/0/575/383/110/74/60/0/70f0eac_qzOxL2NZnVPjqeDCBPg3Lrrv.jpg',
#  'title': 'Le poète Lorand Gaspar est mort'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/14/0/4/3000/2000/110/74/60/0/7dae224_2GCJtKPGCsgu84sGph92ctpc.jpg',
#  'title': 'John Giorno, poète et figure de l’underground, est mort'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/14/0/25/2616/1744/110/74/60/0/1dc0228_5831279-01-06.jpg',
#  'title': 'La star de K-pop Sulli retrouvée morte à son domicile'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/14/142/0/1080/718/110/74/60/0/9fbb5ed_EcqrA1OYWRZ7-E0FewdLRWTD.jpg',
#  'title': 'La mort du peintre Ettore Spalletti'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/25/24/0/3000/2000/110/74/60/0/2c4b3b5_iaiIpGaSXZL6WgoSdkHPpSil.jpg',
#  'title': 'La Mairie de Paris veut maîtriser et taxer les livraisons d’Amazon'}
# 2019-11-25 13:25:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/politique/> (referer: https://www.lemonde.fr)
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/25/0/0/5120/3413/110/74/60/0/b665a4d_7GM27o_Mf2y79q_QCyMB8pWn.jpg',
#  'title': 'Côte d’Ivoire : avec le « de Funès africain », « Le Gendarme de '
#           'Abobo » fait rire Abidjan'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/25/0/0/3577/2384/110/74/60/0/4578344_P5F0Aenk0mWu61qYBwQJz7mj.jpg',
#  'title': 'République démocratique du Congo : nouveau massacre de civils dans '
#           'l’Est'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/25/0/0/5760/3840/110/74/60/0/81e3d4a_YyyzYO2aCulJgxSy_haF5Ixh.jpg',
#  'title': 'En Algérie, mandat de dépôt pour un chef d’une association active '
#           'dans la contestation'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/25/0/0/960/639/110/74/60/0/44bd811_4TuNoNOITMnLB4Xab9MLiQW_.jpg',
#  'title': 'Les Carthagos Eagles, première équipe de football américain en '
#           'Tunisie'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/25/153/218/1486/990/110/74/60/0/34ca786_EK2x2fi0mGdn9Qc4vpRGx4C7.jpeg',
#  'title': '« Tous les cinéastes algériens sont solidaires du mouvement de '
#           'contestation »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/25/0/0/3600/2400/110/74/60/0/c9f7557_YiL0lEFM3vydjz9JY56nZiFp.jpg',
#  'title': 'En Namibie, des élections promises au régime malgré la crise'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/24/146/0/3500/2333/110/74/60/0/0f85917_GGGBIS02_BISSAU-ELECTION-_1124_11.JPG',
#  'title': 'Présidentielle en Guinée-Bissau : le scrutin terni par des bagarres '
#           'et accusations de fraude'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/24/36/0/3500/2333/110/74/60/0/10f0265_GGGAFR102_CONGO-CRASH-_1124_11.JPG',
#  'title': 'Accident d’avion en République démocratique du Congo : le bilan '
#           's’alourdit à 29 morts'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/0/0/3888/2592/110/74/60/0/b9eb914_tFkSNbrizhz4Tbxpbm9ht70Y.jpg',
#  'title': 'La stabilité, enjeu majeur de l’élection présidentielle dimanche en '
#           'Guinée-Bissau'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/19/1/343/1254/835/110/74/60/0/c73c388_NRt-K6fKuP1pWUGXNDcQPBQW.jpg',
#  'title': 'Rose Mutiso, la Kényane qui ouvre au grand public les portes de la '
#           'physique'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/84/0/2016/1344/110/74/60/0/cf4078c_vDgxoc4BDEHXVDemr3er5gyl.JPG',
#  'title': 'Au Kenya, une plate-forme numérique pour aider les jeunes filles à '
#           'prévenir leurs grossesses'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/0/68/733/489/110/74/60/0/34bf839_h14o1cWJo5DglHot1xBJ4H3N.png',
#  'title': 'Adama Paris : « Dire “luxe” et “Afrique” dans la même phrase, ça ne '
#           'devrait pas choquer »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/20/0/0/6000/4000/110/74/60/0/3135760_4EiN0Ju_Zj05fQIKYFK4fXud.jpg',
#  'title': 'Art africain : une vente aux enchères solidaire pour « restituer '
#           'autrement »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/0/0/3499/2333/110/74/60/0/725a835_GGG-DZA02_ALGERIA-PROTESTS-_1122_11.JPG',
#  'title': 'Les Algériens manifestent contre le régime en place pour le 40e '
#           'vendredi consécutif'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/21/168/0/4032/2688/110/74/60/0/b333fd7_wW6jEkBlwHqu2hq44FodlTh0.jpg',
#  'title': 'Rabia Sa’id, la Nigériane qui passe au crible les changements '
#           'environnementaux'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/489/0/3215/2134/110/74/60/0/300ccfd_vF44lDGCrkvH-7nq_WtBAiBi.jpg',
#  'title': 'Alpha Barry : « Au Sahel, le terrorisme gagne du terrain et la '
#           'gangrène s’installe »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/0/0/5472/3648/110/74/60/0/46c40b9_Dh1Z19dl_dzM6R8SrEPHQzsP.jpg',
#  'title': 'L’ONU appelle la communauté internationale à soutenir le G5 Sahel'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/0/55/703/469/110/74/60/0/db38abd_n3bX_ISptjh-TGeMMxTnz4n3.JPG',
#  'title': 'Au Burundi, quatre journalistes d’un journal indépendant incarcérés '
#           'depuis un mois'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/0/0/3900/2600/110/74/60/0/e74d6ce_conkmbz_9UOjF-0u2hh-qLI0.jpg',
#  'title': 'L’organisation de la COP25, un défi pour Madrid'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/0/0/5824/3882/110/74/60/0/e501b4c_337PFX515AZ91o9NbW2qrjiX.jpg',
#  'title': 'La banane ivoirienne de plus en plus menacée par la concurrence '
#           'latino-américaine en Europe'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/0/25/5040/3360/110/74/60/0/7dd76a1_P6GZDoHU798EoCx3C-XpdmbI.jpg',
#  'title': 'Au Mozambique, le président Filipe Nyusi accusé d’avoir touché des '
#           'pots-de-vin'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/0/44/2965/1977/110/74/60/0/39f5ad1_8qagDohm9DMMCC8CD1m1muec.jpg',
#  'title': 'La Libye, nouveau théâtre d’intervention des mercenaires russes'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/20/1/0/1890/1260/110/74/60/0/d6a41cc_2019112345.0.2379170099AddisAbaba_11_web.jpg',
#  'title': 'La folie du pari sportif gagne l’Ethiopie'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/20/0/0/3499/2333/110/74/60/0/735dae0_QLlm0OtGOq6P1zKcH_W2Rgh3.jpg',
#  'title': 'Au Maroc, l’anglais s’affirme face à l’enseignement en français'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/afrique/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/21/168/0/4032/2688/110/74/60/0/8473196_oQUP_48MoruKzpBMGyNPh6qd.jpeg',
#  'title': 'Cameroun : « J’ai été sauvée par l’igname »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/podcasts/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/0/0/4840/3226/110/74/60/0/0b1e221_CXONxTExGCJczxMi9ywDadGe.jpg',
#  'title': 'Ariane Ascaride : « Ma victoire, ce n’est pas d’être au goût de '
#           'l’époque, c’est d’être incontournable avec ce que je suis »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/14/0/2/4476/2984/110/74/60/0/f59bcbb_AbQc44AM3u60zCHI8RKn8yuH.jpg',
#  'title': 'En ville, les pigeons estropiés sont victimes de la pollution (et '
#           'des coiffeurs)'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/13/33/0/784/522/110/74/60/0/67e79b4_LrwiqN230sQnF4Na6sv4c_Is.png',
#  'title': 'Un sous-marin américain retrouvé 75 ans après sa disparition au '
#           'large du Japon'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/07/225/0/4456/2970/110/74/60/0/de655ca__crFjKpK8HiXnb0IFXd2eG1c.jpg',
#  'title': 'Le corps d’un général de Napoléon identifié en Russie, deux cents '
#           'ans après sa mort'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/05/0/42/4012/2675/110/74/60/0/60c4c55_Zoc9z4ftSRJBRfnHCrVIKABT.jpg',
#  'title': 'L’île Ernst Thälmann, utopie tropicale de la RDA'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/22/80/0/3157/2100/110/74/60/0/8883af7_SHN101_MCDONALDS-RESULTS-_1022_11.JPG',
#  'title': 'La filiale portugaise de McDonald’s retire la publicité pour son « '
#           'Sundae Bloody Sundae »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/29/0/150/3636/2424/110/74/60/0/5403759_9NOGmC0KeU-KtPVOLG58-Ioa.jpg',
#  'title': 'Grâce à une Américaine de 6 ans, les figurines militaires '
#           'compteront des femmes dans leurs rangs'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/29/0/3/4249/2833/110/74/60/0/aaaf670__vBs3rBnLPGSPpJuTVW70RNA.jpg',
#  'title': '« On ne saura jamais à quoi les Mémoires de Prince auraient '
#           'ressemblé s’il avait été en vie »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2018/09/24/88/0/1539/1026/110/74/60/0/3e2ab53_HBNXJhhr9S7L0wvINdtL8nhG.jpg',
#  'title': '« Les balles traçantes décrivent un arc au-dessus de notre proue » '
#           ': un reportage radio du Débarquement entre au musée'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/10/0/141/1398/932/110/74/60/0/fd7659a_EQ99eytdzXot6wYliqT-0Y0n.PNG',
#  'title': 'Quand la pieuvre dort'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/07/8/0/2403/1602/110/74/60/0/338dc4f_5785501-01-06.jpg',
#  'title': 'Les perruches argentines n’ont plus droit de cité à Madrid'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/24/0/7/1555/1037/110/74/60/0/6bfc2e6__2zsvBxUfedl3qrNbr1lDThD.jpg',
#  'title': 'Brexit : la présidente de la Cour suprême a-t-elle fait passer un '
#           'message en arborant une broche araignée ?'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/24/1102/0/1800/1200/110/74/60/0/7d2975c_gypya3vSFZPK22TC3gVl0F3Y.jpg',
#  'title': 'Le Caravage volé, la mafia et le bout de tableau coupé'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/20/9/182/1122/748/110/74/60/0/6c0fa8c_CRaPAxiwnTwnE-W7mLp2WxUH.JPG',
#  'title': 'Une pub pour des serviettes hygiéniques montrant du sang provoque '
#           '600 plaintes en Australie'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/12/78/0/3066/2044/110/74/60/0/b94375b_uQuCicDOxIaGuz6irfbQ8-rz.jpg',
#  'title': 'Cinquante ans après « Abbey Road », l’enregistrement « qui réécrit '
#           'à peu près tout ce que nous pensions savoir » sur les Beatles'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/10/87/165/2511/1674/110/74/60/0/ee9ca83_9NROn7QJMg0hiq-sxWYQuMtn.jpg',
#  'title': 'Pourquoi le chant des baleines bleues devient-il de plus en plus '
#           'grave ?'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/04/489/1032/2104/1402/110/74/60/0/6d039a6_3sbkAWUVUHa81hxZZu4389bV.jpg',
#  'title': 'Le Nord-Coréen Han Kwang-song, nouveau missile de l’équipe B de la '
#           'Juve ?'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/04/481/0/2388/1592/110/74/60/0/df54a6d_5540753-01-06.jpg',
#  'title': 'En plein débat sur le Brexit, le président de la Chambre des '
#           'communes s’offre une sieste'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/02/26/0/3600/2400/110/74/60/0/d6350f0_e3ecb37f2bc24f9ab35237c5324e7dc5-e3ecb37f2bc24f9ab35237c5324e7dc5-0.jpg',
#  'title': '« Montrez la photo de mon corps » : des lycéens américains '
#           's’engagent contre les armes à feu'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2014/10/16/0/0/5184/3456/110/74/60/0/f09ec0e_26014-hbwqmq.jpg',
#  'title': 'Le succès foudroyant de l’eau alcoolisée, « boisson de 2019 »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/08/24/141/0/2360/1569/110/74/60/0/96534b3_44f44de47c7b444198ff2a799e4b2bb6-44f44de47c7b444198ff2a799e4b2bb6-0.jpg',
#  'title': 'L’histoire oubliée de la première championne de tennis '
#           'afro-américaine, Althea Gibson'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/08/28/0/0/4604/3067/110/74/60/0/ab55c17_zj595KTUGWZ5wkMjDdrU2yeN.jpg',
#  'title': 'Pour la première fois, des écoles catholiques irlandaises s’ouvrent '
#           'à d’autres religions'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/08/05/0/0/3499/2333/110/74/60/0/852fe04_GGGEGC04_TEXAS-SHOOTING-MEXICO_0805_11.JPG',
#  'title': 'La circulation des armes aux Etats-Unis provoque aussi des tueries '
#           'dans les pays voisins'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2015/09/01/0/69/3681/2454/110/74/60/0/a59fbeb_27877-xuayuk.jpg',
#  'title': 'Aux Etats-Unis, 80 personnes poursuivies pour l’une des arnaques en '
#           'ligne les plus importantes de l’histoire du pays'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/08/23/60/0/3500/2333/110/74/60/0/d17a66e_1h8HqPCtRftWdUAhCUaHSTD-.jpg',
#  'title': 'Le Real Kashmir Football Club, une lueur d’espoir dans un Cachemire '
#           'en perpétuel conflit'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/big-browser/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/08/22/0/82/963/642/110/74/60/0/bd234ab_p3HtKq3klhJuVaaKYlvjCK8x.JPG',
#  'title': 'Amber Galloway Gallego, l’interprète en langue des signes qui rappe '
#           'plus vite que son ombre'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/11/0/0/750/499/110/74/60/0/31cf507_-c-yoK9lbCXVnLiVO_qapPAv.jpg',
#  'title': 'La mort du journaliste Pierre Bocev'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/14/76/0/3000/1997/110/74/60/0/3bc2ec0_uYLUU3bpbeAy6Mp88ZeLeDoG.jpg',
#  'title': 'L’acteur Robert Forster est mort'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/14/0/0/2048/1363/110/74/60/0/1810b90_KQckzk1_rRN3UQtvQMtFklNi.jpg',
#  'title': 'La mort de l’architecte François Seigneur'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/09/332/0/1240/825/110/74/60/0/d8d999c_2019101245.0.2367160181VIEU_CHARIER_09_web.jpg',
#  'title': 'Catherine Vieu-Charier, à la recherche d’une avenue Jacques-Chirac'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/26/0/57/3078/2052/110/74/60/0/4a913ad_dbd82193281d44f999a3434b92af5111-dbd82193281d44f999a3434b92af5111-0.jpg',
#  'title': '« Jacques Chirac fut moins l’ami des Arabes que celui de leurs '
#           'dirigeants »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/12/187/0/4480/2986/110/74/60/0/5137a27_5818077-01-06.jpg',
#  'title': 'Scandale Nobel : décès de l’ex-secrétaire perpétuelle de l’Académie '
#           'suédoise Sara Danius'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/12/26/0/3000/2000/110/74/60/0/e746b8d_6ucMTDf382IZRk8ig0wP9zCM.jpg',
#  'title': 'L’acteur américain Robert Forster, éternel amoureux de « Jackie '
#           'Brown », est mort'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/11/43/0/4335/2890/110/74/60/0/793bc74_5811380-01-06.jpg',
#  'title': 'Mort d’Alexeï Leonov, premier homme à être sorti dans l’espace'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/disparitions/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/10/0/0/5616/3744/110/74/60/0/5410ae5_5805144-01-06.jpg',
#  'title': 'L’actrice Marie-José Nat est morte'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/25/0/100/1080/720/110/74/60/0/078086c_zWnNeG75E2jV5ZfmM2mgCqAe.jpg',
#  'title': 'Jeu vidéo : « Pokémon Epée & Bouclier », des épisodes qui '
#           'n’arrivent jamais à surprendre'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/25/155/0/4799/3199/110/74/60/0/303898a_-gehgUPexud9wbSvw-1y1kp6.jpg',
#  'title': 'Polanski boycotté, pièce annulée, conférences empêchées : « Il faut '
#           'résister aux nouveaux censeurs »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/20/0/5/5118/3412/110/74/60/0/b449ffe__eAH-HYrrKMjvKNoJuDk5jOD.jpg',
#  'title': '« Les étudiants sont demandeurs d’une interdiction des écrans, pour '
#           'éviter les tentations »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/0/0/5604/3736/110/74/60/0/51171fc_qI7lMfU5GW0n5CLyKtH7_NoX.jpg',
#  'title': 'Black Friday : « Le principe du pollueur payeur doit aussi '
#           's’appliquer au e-commerce »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/0/0/5098/3398/110/74/60/0/642531c_ezRfLVGiizauH89c_DrF0I7J.jpg',
#  'title': 'Alexis Lévrier : « L’expression “tribunal médiatique” est un piège '
#           '»'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/24/0/0/5230/3486/110/74/60/0/cbedf65_r1ioFhUdE5FjOIMVKJzmh1DB.jpg',
#  'title': 'Attribution de la 5G : le prix minimal à 2,17 milliards d’euros '
#           'déçoit les opérateurs'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/0/0/5669/3779/110/74/60/0/4ba438d_xu5DYcioxhyI44jQf3B3_q6O.jpg',
#  'title': '« L’intelligence artificielle est bien aujourd’hui une escroquerie '
#           '! »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/20/0/141/997/665/110/74/60/0/e9a2b96_PUXU96NZiti7lh1PFuDcCD8p.png',
#  'title': '« Bee Simulator » : le jeu vidéo où l’on se prend pour une abeille'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/23/151/0/3500/2333/110/74/60/0/b87781c_aTcJdHV2Yw2QMpv_PcgX-ZoW.jpg',
#  'title': 'La protection des communications en ligne a du plomb dans l’aile en '
#           'Europe'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/21/0/0/1284/856/110/74/60/0/f904f81_KmQbfDikVqC8iqoaD01rQEK1.png',
#  'title': 'Derrière de pseudo-sites politiques français, un vaste réseau venu '
#           'd’Ukraine'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/65/230/343/228/110/74/60/0/b9e65b2_nX-7_Ly07-TbV4otA27HZ6-n.jpg',
#  'title': '« Sigma Theory », passionnant jeu vidéo entre « Civilization » et « '
#           'Le Bureau des légendes »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/22/1/0/7684/5122/110/74/60/0/f05d70b_tKGLQRn5EgPcsEXxI2C0jWA8.jpg',
#  'title': 'Début des enchères pour l’attribution des fréquences 5G en France'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/20/0/0/1800/1200/110/74/60/0/51af9db_UtJXf16_7Qdm0cwhStbtGocH.jpg',
#  'title': 'Six assistants vocaux pour des fêtes high-tech'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/19/74/0/444/296/110/74/60/0/68c1994_8uObH6XhaTakKhbtFyv4dUyL.jpg',
#  'title': 'Peut-on se passer d’un agent immobilier pour vendre son logement ?'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/21/0/0/3500/2333/110/74/60/0/145b864_FW1_TWITTER-REPLIES-_1121_11.JPG',
#  'title': 'Twitter lance une nouvelle fonction pour masquer des réponses '
#           'indésirables à un message'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/20/0/84/3574/2383/110/74/60/0/26e95e1_5068677-01-06.jpg',
#  'title': 'Pour Amnesty, le modèle économique de Facebook et Google menace les '
#           '« droits humains »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/17/0/99/5238/3492/110/74/60/0/75d668c_5050606-01-06.jpg',
#  'title': 'Jeu vidéo : Google Stadia, une stratégie de lancement '
#           'incompréhensible'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/20/0/0/900/600/110/74/60/0/953c45e_4wZtGJaE_92GN_MFFXCPZZjk.jpg',
#  'title': 'Attention aux concours sur Facebook qui promettent de « doubler '
#           'votre salaire »'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/19/38/0/3609/2406/110/74/60/0/543689e_a11e8db60c1a4305939f2af98a8d1bab-a11e8db60c1a4305939f2af98a8d1bab-0.jpg',
#  'title': 'Amazon : aux Etats-Unis, les vidéos des sonnettes Ring peuvent être '
#           'gardées indéfiniment par la police'}
# 2019-11-25 13:25:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/pixels/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/11/20/22/0/4213/2808/110/74/60/0/4d9b6f5_bce89a6def664d469d9415cdc8376e80-bce89a6def664d469d9415cdc8376e80-0.jpg',
# ...
#           'l’exécutif, Carrie Lam'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/hongkong/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/16/1/300/1619/1079/110/74/60/0/05b93fe_YZ1fkahy6P4OjGQzOeOf5mTV.jpg',
#  'title': 'Hongkong : un des chefs de file de la contestation violemment '
#           'agressé'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/hongkong/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/16/0/0/3547/2364/110/74/60/0/cd63a02_7b2cc1fcdb9f48ce9eed21bd3da7da2e-7b2cc1fcdb9f48ce9eed21bd3da7da2e-0.jpg',
#  'title': 'A Hongkong, Carrie Lam humiliée au Parlement'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/hongkong/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/14/0/4/4920/3280/110/74/60/0/93575f8_JZMVpW5yFU8zPiZFhtnlECDj.jpg',
#  'title': 'Comment les manifestations prodémocratie à Hongkong altèrent le '
#           'cliché de la « Kong girl »'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/hongkong/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/12/798/1336/3446/2297/110/74/60/0/e050a5b_21382f96ca42459397eaac51c5222739-21382f96ca42459397eaac51c5222739-0.jpg',
#  'title': 'Du Cachemire à Hongkong, l’Inde et la Chine érodent les différences '
#           'de leurs régions autonomes'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/hongkong/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/11/0/0/3600/2400/110/74/60/0/ea00f6f_H6a-w1rZqLVUh4JXab8rvjVQ.jpg',
#  'title': 'L’économie de Hongkong pénalisée par la crise politique'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/hongkong/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/11/0/0/3499/2333/110/74/60/0/7eb7508_AP01_HONGKONG-PROTESTS-_1011_11.JPG',
#  'title': 'A Hongkong, les ruses des manifestants pour contourner la loi « '
#           'antimasque »'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/hongkong/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/11/2/0/3500/2333/110/74/60/0/418e7cf_SIN32_HONGKONG-PROTEST-_1011_11.JPG',
#  'title': 'Hongkong : Google supprime une application du PlayStore d’Android'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/moyen-orient-irak/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/01/0/157/4014/2676/110/74/60/0/af8a47a_5737178-01-06.jpg',
#  'title': 'Irak : des manifestations contre la corruption réprimées, au moins '
#           'deux morts'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/moyen-orient-irak/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/19/1442/0/3462/2308/110/74/60/0/12cbff8_jD7XMuaMmC2zr25XkNYAYPbG.JPG',
#  'title': 'Juliette Duclos-Valois : « Les yézidis ont vécu le départ des '
#           'peshmergas comme une trahison »'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/moyen-orient-irak/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/19/2/0/2995/1996/110/74/60/0/d4ad14d_TMcZw4ursgsfSt6NNGTByf5z.jpg',
#  'title': 'Le périlleux retour des yézidis en Irak'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/moyen-orient-irak/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/18/33/0/1632/1088/110/74/60/0/7cacc1f_I5vAEfDvQYeLrEqxaEevG_uD.jpg',
#  'title': '« L’objectif qui était de vaincre Daech n’est pas atteint » : '
#           'retour sur cinq ans d’engagement de la France en Irak et en Syrie'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/moyen-orient-irak/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/11/0/98/3304/2203/110/74/60/0/3230db2_G40EpkJqk_UmG1FcIKfbFbsu.jpg',
#  'title': 'Une trentaine de morts lors d’une bousculade au pèlerinage chiite '
#           'd’Achoura, en Irak'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/moyen-orient-irak/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/02/0/0/1023/682/110/74/60/0/9f1134c_S7hJP0ok209oY87xw_GtOlXv.jpg',
#  'title': 'L’ONU dénonce le transfert de familles irakiennes vers l’ancien '
#           'territoire de l’Etat islamique'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/moyen-orient-irak/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/08/31/2449/0/6000/4000/110/74/60/0/28a500d_wyl7yI6XMElDg5zQjH8S6Rbp.jpg',
#  'title': 'Bagdad peine à contrôler les milices pro-iraniennes'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/moyen-orient-irak/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/08/23/0/0/3499/2333/110/74/60/0/4845fbb_f2f9c02ba79847a69b7b7e445a8bb0b5-f2f9c02ba79847a69b7b7e445a8bb0b5-0.jpg',
#  'title': 'L’armée israélienne accusée d’avoir frappé en Irak'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/moyen-orient-irak/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2018/03/26/0/0/5760/3840/110/74/60/0/951a3d2_10203-1ypiud7.u35ui.jpg',
#  'title': 'Paris et Bagdad démentent le versement de contreparties'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/moyen-orient-irak/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/08/12/20/0/2542/1694/110/74/60/0/67ff769_7rMM9FDYTQd1salYNjLByovU.jpg',
#  'title': 'L’ONU interpelle la France sur le transfert « illégal » de '
#           'djihadistes français en Irak'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/moyen-orient-irak/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/07/31/887/78/1459/972/110/74/60/0/c08fdb3_2019080345.0.2335503380Nimrud_01_web.jpg',
#  'title': 'A la recherche de la lionne de Nimroud'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/moyen-orient-irak/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/07/17/0/0/3499/2333/110/74/60/0/ca8efcf_GGGBAG570_IRAQ-SECURITY-_0717_11.JPG',
#  'title': 'La Turquie riposte en Irak après l’attaque qui a causé la mort d’un '
#           'de ses diplomates'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/moyen-orient-irak/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/07/08/88/0/2708/1805/110/74/60/0/f946237_wQvAAcGS_4CivTjb44cLAIkL.jpg',
#  'title': 'Envers les enfants de djihadistes, « les pays doivent prendre leurs '
#           'responsabilités »'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/moyen-orient-irak/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/05/26/55/0/2285/1523/110/74/60/0/75d3f78_2b6f69a663f44203a4c1119c9534d7b4-2b6f69a663f44203a4c1119c9534d7b4-0.jpg',
#  'title': 'Des djihadistes français condamnés à mort en Irak mettent en cause '
#           'Paris'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/feminicides/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/04/0/0/5235/3490/110/74/60/0/b7c2cca_D7Yt6LfAwJMnzB3T8BYzgeqX.jpg',
#  'title': 'Violences conjugales : « Même si ça a été dur, je veux dire que '
#           'c’est possible de s’en sortir »'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/feminicides/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/07/06/0/0/5760/3840/110/74/60/0/ea1fce3_EsVyyF0pNOr5XINsRSMJ4xes.jpg',
#  'title': 'Des milieux militants au terrain politique, histoire de la notion « '
#           'féminicide »'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/feminicides/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/01/0/11/4878/3252/110/74/60/0/6a26547_5523502-01-06.jpg',
#  'title': 'Grenelle sur les violences conjugales : « La France dispose d’un '
#           'arsenal judiciaire plutôt solide, mais il est inégalement appliqué '
#           '»'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/feminicides/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/02/1/0/5224/3482/110/74/60/0/feff894_5532806-01-06.jpg',
#  'title': 'Grenelle des violences conjugales : « Il existe encore des '
#           'dysfonctionnements sur toute la chaîne de prise en charge »'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/feminicides/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/01/0/12/4323/2882/110/74/60/0/c24c653_5523499-01-06.jpg',
#  'title': 'A Annecy, la justice tente d’éclaircir un mystérieux féminicide'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/feminicides/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/03/3/96/4602/3066/110/74/60/0/82df790_nS5L0lqtFrxC5gAfyc1-zHA7.jpg',
#  'title': 'Grenelle des violences conjugales : les associations « confiantes '
#           '», mais « vigilantes »'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/feminicides/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/02/0/0/4845/3230/110/74/60/0/d956675_8lAkX_JRJrZzwPJHBeTS6Ooa.jpg',
#  'title': 'L’IGPN saisie après la découverte du corps d’une jeune femme à '
#           'Cagnes-sur-Mer'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/feminicides/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/09/01/0/4/4216/2811/110/74/60/0/6a181d1_5523500-01-06.jpg',
#  'title': 'Rassemblement à Paris pour dénoncer « le 100e féminicide » de '
#           'l’année'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/feminicides/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/08/28/460/0/1280/851/110/74/60/0/c8145bd_2019083145.0.2346224158Fremiot01_web.jpg',
#  'title': 'Luc Frémiot, virulent combattant des violences contre les femmes'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/feminicides/>
# {'description': None,
#  'image': None,
#  'title': '« Papa, il a tué maman, Gilles et lui » : enquête sur cinq '
#           'féminicides à La Réunion'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/feminicides/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/08/29/1250/0/3000/2000/110/74/60/0/5df2e39_L5IOk6JN3OxWtJqXFd0IudIz.jpg',
#  'title': 'L’enquête du « Monde » sur les féminicides en France'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/referendum-sur-le-brexit/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/17/0/159/1059/706/110/74/60/0/e2d9a0f_WssH3iAZUNsG55VVnz9YqlOy.png',
#  'title': 'Parti par parti, comment vont voter les députés britanniques sur le '
#           'Brexit ?'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/referendum-sur-le-brexit/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/16/415/0/1596/1062/110/74/60/0/a8827c9_2019101945.0.2371327681actu_rocher_422_web.jpg',
#  'title': 'Un lieu dans l’actu : le rocher Rockall'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/referendum-sur-le-brexit/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/18/467/131/4061/2707/110/74/60/0/01f13c6_L4OJT5A-Z0gmLU92O0zzpjP1.jpg',
#  'title': 'Brexit : amer compromis pour l’Europe'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/referendum-sur-le-brexit/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/18/108/0/4488/2992/110/74/60/0/31ce62a_l7Yf-XE6f0_4M2kfsL7559kT.jpg',
#  'title': 'Espoir le matin, coup de pompe à midi… la dernière ligne pas tout à '
#           'fait droite du Brexit'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/referendum-sur-le-brexit/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/17/35/0/2035/1356/110/74/60/0/70edfad_GDN5264_EU-SUMMIT-_1017_11.JPG',
#  'title': 'Brexit : le miracle de Bruxelles se reproduira-t-il à Westminster ?'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/referendum-sur-le-brexit/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/17/0/0/4999/3333/110/74/60/0/1aac6aa_c9e113d07873431f9398de033d5348a0-c9e113d07873431f9398de033d5348a0-0.jpg',
#  'title': 'Brexit : « Si Boris Johnson n’arrive pas à faire le plein des voix '
#           'des brexiters, son accord est mort »'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/referendum-sur-le-brexit/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/19/37/0/1800/1200/110/74/60/0/37b6dce_REni11shSjyHFZ2GApURX9TQ.png',
#  'title': 'Le Brexit en schéma : que peut-il se passer après le nouvel accord '
#           'conclu entre Londres et Bruxelles ?'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/referendum-sur-le-brexit/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/17/87/0/5017/3344/110/74/60/0/73140fc_3Y0mv6WPaK6qytPbGV6Z7zyf.jpg',
#  'title': 'De l’Irlande du Nord au régime de TVA, les points-clés du nouvel '
#           'accord du Brexit'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/referendum-sur-le-brexit/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/17/0/0/5472/3648/110/74/60/0/58b5e9a_f870503bb7cc470682f5e4904a2996aa-f870503bb7cc470682f5e4904a2996aa-0.jpg',
#  'title': 'Les cinq jours qui ont permis d’arracher un nouvel accord sur le '
#           'Brexit'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/referendum-sur-le-brexit/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/17/87/0/5017/3344/110/74/60/0/73140fc_3Y0mv6WPaK6qytPbGV6Z7zyf.jpg',
#  'title': '« Que le deal Boris soit ratifié à Westminster tiendrait du miracle '
#           '»'}
# 2019-11-25 13:25:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/referendum-sur-le-brexit/>
# {'description': None,
#  'image': 'https://img.lemde.fr/2019/10/17/0/230/4494/2996/110/74/60/0/ce780de_306b0373c3fc4059b3242a91c5e9b198-306b0373c3fc4059b3242a91c5e9b198-0.jpg',
#  'title': 'Brexit : l’Union européenne et le Royaume-Uni parviennent à un '
#           'deuxième accord'}
# 2019-11-25 13:25:03 [scrapy.core.engine] INFO: Closing spider (finished)
# 2019-11-25 13:25:03 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 7830,
#  'downloader/request_count': 27,
#  'downloader/request_method_count/GET': 27,
#  'downloader/response_bytes': 1238532,
#  'downloader/response_count': 27,
#  'downloader/response_status_count/200': 27,
#  'elapsed_time_seconds': 2.091801,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2019, 11, 25, 12, 25, 3, 228001),
#  'item_scraped_count': 1374,
#  'log_count/DEBUG': 1401,
#  'log_count/ERROR': 1,
#  'log_count/INFO': 10,
#  'memusage/max': 50950144,
#  'memusage/startup': 50941952,
#  'request_depth_max': 1,
#  'response_received_count': 27,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 26,
#  'scheduler/dequeued/memory': 26,
#  'scheduler/enqueued': 26,
#  'scheduler/enqueued/memory': 26,
#  'spider_exceptions/IndexError': 1,
#  'start_time': datetime.datetime(2019, 11, 25, 12, 25, 1, 136200)}
# 2019-11-25 13:25:03 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ## Postprocessing
#
# Si l'on se réfère au diagramme d'architecture de Scrapy, on voit qu'il
# est possible d'insérer des composants supplémentaires dans le flux de
# traitement. Ces composants s'appellent `Pipelines`.
#
# Par défaut, tous les `Item` générés au sein d'un projet Scrapy passent
# par les `Pipelines`. Les pipelines sont utilisés la plupart du temps
# pour :
#
# -   Nettoyer du contenu HTML ;
# -   Valider les données scrapées ;
# -   Supprimer les items qu'on ne souhaite pas stocker ;
# -   Stocker ces objets dans des bases de données.
#
# Les pipelines doivent être définis dans le fichier `pipelines.py`.
#
# Dans notre cas on peut vouloir nettoyer le champ `title` pour enlever
# les caractères superflus.
#
# Nous allons alors transferer la fonction de nettoyage du code html dans
# une Pipeline.

# %%
# %load newscrawler/newscrawler/pipelines.py

# Define your item pipelines here
#
# Don't forget to add your pipeline to the ITEM_PIPELINES setting
# See: https://docs.scrapy.org/en/latest/topics/item-pipeline.html

from scrapy.exceptions import DropItem

class TextPipeline(object):

    def process_item(self, item, spider):
        if item['title']:
            item["title"] = clean_spaces(item["title"])
            return item
        else:
            raise DropItem("Missing title in %s" % item)


def clean_spaces(string):
    if string:
        return " ".join(string.split())

# %% [markdown]
# Pour dire au process Scrapy de faire transiter les items par ces
# pipelines. Il faut le spécifier dans le fichier de paramétrage
# `settings.py`.

# %%
ITEM_PIPELINES = {
     'newscrawler.pipelines.TextPipeline': 300,
 }

# %% [markdown]
# On peut maintenant supprimer la fonction `clean_spaces()` de
# l'extraction des données et laisser le Pipeline faire son travail. La
# valeur entière définie permet de déterminer l'ordre dans lequel les
# pipelines vont être appelés. Ces entiers peuvent être compris entre 0 et
# 1000.
#
# On relance notre spider :

# %%
scrapy crawl lemonde -o ../data/articles.json

# %% [markdown]
# On peut aussi utiliser les Pipelines pour stocker les données récupérées
# dans une base de données. Pour stocker les items dans des documents
# mongo :

# %%
import pymongo

class MongoPipeline(object):

    collection_name = 'scrapy_items'

    def open_spider(self, spider):
        self.client = pymongo.MongoClient()
        self.db = self.client["lemonde"]

    def close_spider(self, spider):
        self.client.close()

    def process_item(self, item, spider):
        self.db[self.collection_name].insert_one(dict(item))
        return item

# %% [markdown]
# Ici on redéfinit deux autres méthodes: `open_spider()`et
# `close_spider()`, ces méthodes sont appelées comme leur nom l'indique,
# lorsque la Spider est instanciée et fermée.
#
# Ces méthodes nous permettent d'ouvrir la connexion Mongo et de la fermer
# lorsque le scraping se termine. La méthode `process_item()` est appelé à
# chaque fois qu'un item passe dans le mécanisme interne de scrapy. Ici,
# la méthode permet d'insérer l'item en tant que document mongo.
#
# Pour que ce pipeline soit appelé il faut l'ajouter dans les settings du
# projet.

# %%
ITEM_PIPELINES = {
    'newscrawler.pipelines.TextPipeline': 100,
    'newscrawler.pipelines.MongoPipeline': 300
}

# %% [markdown]
# Le pipeline est ajoutée à la fin du process pour profiter des deux
# précédents.
#
# ## Settings
#
# Scrapy permet de gérer le comportement des spiders avec certains
# paramètres. Comme expliqué dans le premier cours, il est important de
# suivre des règles en respectant la structure des différents sites. Il
# existe énormément de paramètres mais nous allons (dans le cadre de ce
# cours) aborder les plus utilisés :
#
# -   DOWNLOAD\_DELAY : Le temps de téléchargement entre chaque requête
#     sur le même domaine ;
# -   CONCURRENT\_REQUESTS\_PER\_DOMAIN : Nombre de requêtes simultanées
#     par domaine ;
# -   CONCURRENT\_REQUESTS\_PER\_IP : Nombre de requêtes simultanées par
#     IP ;
# -   DEFAULT\_REQUEST\_HEADERS : Headers HTTP utilisés pour les requêtes
#     ;
# -   ROBOTSTXT\_OBEY : Scrapy récupère le robots.txt et adapte le
#     scraping en fonction des règles trouvées ;
# -   USER\_AGENT : UserAgent utilisé pour faire les requêtes ;
# -   BOT\_NAME : Nom du bot annoncé lors des requêtes
# -   HTTPCACHE\_ENABLED : Utilisation du cache HTTP, utile lors du
#     parcours multiple de la même page.
#
# Le fichiers `settings.py` permet de définir les paramètres globaux d'un
# projet. Si votre projet contient un grand nombre de spiders, il peut
# être intéressant d'avoir des paramètres distincts pour chaque spider. Un
# moyen simple est d'ajouter un attribut `custom_settings` à votre spider
# :

# %%
class LeMondeSpider(scrapy.Spider):
        name = "lemonde"
        allowed_domains = ["lemonde.fr"]
        start_urls = ['http://lemonde.fr/']
        custom_settings = {
            "HTTPCACHE_ENABLED":True, 
            "CONCURRENT_REQUESTS_PER_DOMAIN":100
        }
